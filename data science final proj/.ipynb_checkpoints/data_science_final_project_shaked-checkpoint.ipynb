# %%
from bs4 import BeautifulSoup
import re
import requests
import pandas as pd
import numpy as np
import os
from csv import writer
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.support.ui import Select
import time
import json
import urllib
from csv import DictWriter
                      
from sklearn import linear_model
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
PATH = "C:\Program Files (x86)\chromedriver.exe"

# %%
#df_2020 = pd.DataFrame()
df_2019 = pd.DataFrame()
df_2018 = pd.DataFrame()
df_2017 = pd.DataFrame()
df_2016 = pd.DataFrame()

dic_years = {'2019':df_2019, '2018':df_2018, '2017':df_2017, '2016':df_2016}

# %%
#/////////////////////fix duplicates columns////////////////////////////////////////////////////////////////////////////////

def get_tables():
    i = 0
    arr = []
    driver.execute_script("""
    document.querySelectorAll("a[aria-hidden=true],span[aria-hidden=true]").forEach(function(e) {
        e.parentElement.removeChild(e);
    });
    """)
    time.sleep(5)
    temp_html = driver.find_element(By.CSS_SELECTOR, "html").get_attribute('outerHTML')
    df_school = pd.read_html(temp_html, attrs = {'class':'zebraTable ng-scope'})[0]
    for columns in df_school:
        arr.append(df_school.columns[i][0])
        i = i + 1
    df_school.columns = arr
    return df_school

# %%
def GetYearsDemography(fileName,url):
    try:
        driver.get(url)
        driver.implicitly_wait(20)
        driver.maximize_window()
        selectSubtext = driver.find_element(By.ID, "select2-chosen-4")
        selectSubtext.click()
        driver.find_element(By.XPATH, "//*[@id=\"select2-results-4\"]/li[" + "7" + "]").click()
        time.sleep(10)
        selectCity = driver.find_element(By.ID, "select2-chosen-8")
        selectCity.click()
        time.sleep(1)
        options = driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]")
        AllOpt = options.find_elements_by_css_selector("li")

        countOpt=len(AllOpt)
        driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]/li[" + "1" + "]").click()

        dfData = pd.DataFrame()
        firstTime = True
        for i in range(1, countOpt):

            driver.find_element(By.ID, "select2-chosen-4").click()
            driver.find_element(By.XPATH, "//*[@id=\"select2-results-4\"]/li[" + "7" + "]").click()
            selectCity = driver.find_element(By.ID, "select2-chosen-8")
            selectCity.click()
            driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]/li[" + str(i) + "]").click()
            year = selectCity.text
            temp = get_tables()
            temp.insert(0, "Years", year, True)
            print(temp)
            dfData = dfData.append(temp, ignore_index=True)
            if firstTime:
                temp.to_csv(fileName, mode='a', encoding='utf-8-sig',index=False)
                firstTime = False
            else:
                temp.to_csv(fileName, mode='a', encoding='utf-8-sig',index=False, header=False)


    except BaseException as e:
        print("Invalid URL")
    driver.quit()
    return dfData

# %%
#/////////////education status//////////////////////////////////////////////////////////////////////////////////////////////

options = webdriver.ChromeOptions() 
options.add_argument("--enable-webgl-developer-extensions") 
options.add_argument("--enable-webgl-draft-extensions") 
driver = webdriver.Chrome(PATH,options=options)
driver.vars = {}
url = "https://boardsgenerator.cbs.gov.il/pages/WebParts/YishuvimPage.aspx?level_1=%D7%A9%D7%9B%D7%A8%20/%20%D7%94%D7%9B%D7%A0%D7%A1%D7%95%D7%AA"
driver.get(url)
element = driver.find_element(By.ID, "select2-chosen-4")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
element = driver.find_element(By.CSS_SELECTOR, "body")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
element = driver.find_element(By.ID, "select2-chosen-4")
actions = ActionChains(driver)
actions.move_to_element(element).click_and_hold().perform()
element = driver.find_element(By.ID, "select2-drop-mask")
actions = ActionChains(driver)
actions.move_to_element(element).release().perform()
driver.find_element(By.XPATH, "//*[@id=\"select2-results-4\"]/li[10]").click()
time.sleep(5)
for i in range(2, 6):
    selectCity = driver.find_element(By.ID, "select2-chosen-8")
    selectCity.click()
    time.sleep(10)
    driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]/li[" + str(i) + "]").click()
    time.sleep(10)
    df_temp = get_tables()
    year = selectCity.text
    #print(year)
    dic_years[year] = df_temp
    
    dic_years[year].insert(0, "year", year, True)
driver.quit()
dic_years[year]
# Out:
#      year  סמל היישוב      שם יישוב  \
# 0    2016         472       אבו גוש
# 1    2016         473      אבו סנאן
# 2    2016         182     אבן יהודה
# 3    2016        2710    אום אל-פחם
# 4    2016          31        אופקים
# ..    ...         ...           ...
# 196  2016         538           שעב
# 197  2016        8800         שפרעם
# 198  2016        5000  תל אביב -יפו
# 199  2016         154       תל מונד
# 200  2016        1054        תל שבע
#
#      ילדים בגנים של משרד החינוך סה"כ תשע"ו 2015/16  \
# 0                                              375
# 1                                              670
# 2                                              740
# 3                                             3588
# 4                                             1754
# ..                                             ...
# 196                                            427
# 197                                           2012
# 198                                          17327
# 199                                            625
# 200                                           1725
#
#      ילדים בגנים של משרד החינוך גיל 3 תשע"ו 2015/16  \
# 0                                               148
# 1                                               224
# 2                                               215
# 3                                              1151
# 4                                               566
# ..                                              ...
# 196                                             149
# 197                                             634
# 198                                            5168
# 199                                             171
# 200                                             538
#
#      ילדים בגנים של משרד החינוך גיל 4 תשע"ו 2015/16  \
# 0                                               113
# 1                                               207
# 2                                               244
# 3                                              1144
# 4                                               553
# ..                                              ...
# 196                                             148
# 197                                             665
# 198                                            5786
# 199                                             200
# 200                                             573
#
#      ילדים בגנים של משרד החינוך גיל 5 תשע"ו 2015/16  \
# 0                                               112
# 1                                               230
# 2                                               255
# 3                                              1183
# 4                                               525
# ..                                              ...
# 196                                             127
# 197                                             676
# 198                                            5733
# 199                                             223
# 200                                             573
#
#     ילדים בגנים של משרד החינוך גיל 6 תשע"ו 2015/16 בתי ספר סה"כ תשע"ו 2015/16  \
# 0                                               ..                          5
# 1                                                9                          6
# 2                                               26                          8
# 3                                              110                         29
# 4                                              110                         25
# ..                                             ...                        ...
# 196                                              3                          3
# 197                                             37                         24
# 198                                            640                        163
# 199                                             31                          5
# 200                                             41                         11
#
#     בתי ספר יסודיים (כולל חינוך מיוחד) תשע"ו 2015/16  ...  \
# 0                                                  4  ...
# 1                                                  4  ...
# 2                                                  6  ...
# 3                                                 18  ...
# 4                                                 18  ...
# ..                                               ...  ...
# 196                                               ..  ...
# 197                                               15  ...
# 198                                              103  ...
# 199                                                4  ...
# 200                                                8  ...
#
#     תלמידים בבתי ספר על-יסודיים תשע"ו 2015/16  \
# 0                                         700
# 1                                        1384
# 2                                        1906
# 3                                        7292
# 4                                        1978
# ..                                        ...
# 196                                       756
# 197                                      4238
# 198                                     23370
# 199                                      1751
# 200                                      2674
#
#     תלמידים בחטיבות ביניים תשע"ו 2015/16  \
# 0                                    323
# 1                                    723
# 2                                    613
# 3                                   3563
# 4                                    582
# ..                                   ...
# 196                                  427
# 197                                 1853
# 198                                10333
# 199                                  725
# 200                                 1554
#
#     תלמידים בבתי ספר תיכוניים תשע"ו 2015/16  \
# 0                                       377
# 1                                       661
# 2                                      1293
# 3                                      3729
# 4                                      1396
# ..                                      ...
# 196                                     329
# 197                                    2385
# 198                                   13037
# 199                                    1026
# 200                                    1120
#
#      ממוצע תלמידים לכיתה סה"כ תשע"ו 2015/16  \
# 0                                     20.00
# 1                                     23.00
# 2                                     28.00
# 3                                     25.79
# 4                                     20.42
# ..                                      ...
# 196                                   25.00
# 197                                   26.14
# 198                                   24.03
# 199                                   31.00
# 200                                   26.00
#
#      ממוצע תלמידים לכיתה בבתי ספר יסודיים (כולל חינוך מיוחד) תשע"ו 2015/16  \
# 0                                                19.00
# 1                                                22.00
# 2                                                27.00
# 3                                                24.85
# 4                                                19.95
# ..                                                 ...
# 196                                              24.00
# 197                                              25.56
# 198                                              23.63
# 199                                              28.00
# 200                                              24.00
#
#      ממוצע תלמידים לכיתה בבתי ספר על-יסודיים תשע"ו 2015/16  \
# 0                                                20.00
# 1                                                25.00
# 2                                                31.00
# 3                                                26.81
# 4                                                21.27
# ..                                                 ...
# 196                                              26.00
# 197                                              26.82
# 198                                              24.57
# 199                                              35.00
# 200                                              28.00
#
#      ממוצע תלמידים לכיתה בחטיבות ביניים תשע"ו 2015/16  \
# 0                                                  27
# 1                                                  26
# 2                                                  34
# 3                                                  29
# 4                                                  22
# ..                                                ...
# 196                                                27
# 197                                                29
# 198                                                27
# 199                                                38
# 200                                                30
#
#      ממוצע תלמידים לכיתה בבתי ספר תיכוניים תשע"ו 2015/16  \
# 0                                                16.00
# 1                                                24.00
# 2                                                29.00
# 3                                                25.20
# 4                                                20.84
# ..                                                 ...
# 196                                              25.00
# 197                                              25.11
# 198                                              22.87
# 199                                              33.00
# 200                                              26.00
#
#      אחוז זכאים לתעודת בגרות מבין תלמידי כיתות יב תשע"ו 2015/16  \
# 0                                                49.20
# 1                                                56.10
# 2                                                81.10
# 3                                                52.90
# 4                                                51.70
# ..                                                 ...
# 196                                                 64
# 197                                              47.70
# 198                                                 74
# 199                                              89.40
# 200                                              37.90
#
#      אחוז זכאים לתעודת בגרות שעמדו בדרישות הסף של האוניברסיטאות מבין תלמידי כיתות יב תשע"ו 2015/16
# 0                                                35.80
# 1                                                39.20
# 2                                                71.70
# 3                                                32.40
# 4                                                34.80
# ..                                                 ...
# 196                                              52.30
# 197                                              41.20
# 198                                              65.40
# 199                                              84.30
# 200                                              25.90
#
# [201 rows x 30 columns]

# %%
df_years_temp = pd.DataFrame(columns=['year', 'city', 'number_of_high_schools', 'number_of_bachelor_graduates_in_percent', 'number_of_high_school_graduates_in_percent', 'number_of_high_school_students', 'Registration_for_higher_education_within_8_years_in_percent', 'number_of_students_in_percent'])
df_education = pd.DataFrame()
for i in dic_years:
    #print(i)
    if(i == '2015'):
        break
    df_temp = dic_years[i]
    df_years_temp['year'] = df_temp.iloc[:,0].values
    df_years_temp['city'] = df_temp.iloc[:,2].values
    df_years_temp['number_of_high_schools'] =  df_temp.iloc[:,12].values
    df_years_temp['number_of_bachelor_graduates_in_percent'] = df_temp.iloc[:,29].values
    df_years_temp['number_of_high_school_graduates_in_percent'] = df_temp.iloc[:,27].values
    df_years_temp['number_of_high_school_students'] = df_temp.iloc[:,22].values
    if(i != '2016'):
        df_years_temp['Registration_for_higher_education_within_8_years_in_percent'] = df_temp.iloc[:,30].values
        df_years_temp['number_of_students_in_percent'] = df_temp.iloc[:,32].values
    df_education = df_education.append(df_years_temp)
df_education.to_csv('data/dfEducation.csv', mode='w+', encoding='utf-8-sig',index=False)    
df_education
# Out:
# C:\Users\netanel.m\AppData\Local\Temp\ipykernel_1528\4027247028.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_education = df_education.append(df_years_temp)
# C:\Users\netanel.m\AppData\Local\Temp\ipykernel_1528\4027247028.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_education = df_education.append(df_years_temp)
#      year          city number_of_high_schools  \
# 0    2019       אבו גוש                      3
# 1    2019      אבו סנאן                      3
# 2    2019     אבן יהודה                      3
# 3    2019    אום אל-פחם                     13
# 4    2019        אופקים                     11
# ..    ...           ...                    ...
# 196  2016           שעב                     ..
# 197  2016         שפרעם                      9
# 198  2016  תל אביב -יפו                     64
# 199  2016       תל מונד                     ..
# 200  2016        תל שבע                      5
#
#     number_of_bachelor_graduates_in_percent  \
# 0                                     13.03
# 1                                     12.09
# 2                                     55.59
# 3                                      8.52
# 4                                     12.26
# ..                                      ...
# 196                                   52.30
# 197                                   41.20
# 198                                   65.40
# 199                                   84.30
# 200                                   25.90
#
#     number_of_high_school_graduates_in_percent number_of_high_school_students  \
# 0                                        59.29                            361
# 1                                        65.81                            592
# 2                                        83.96                           1087
# 3                                        59.40                           3838
# 4                                        50.24                           1551
# ..                                         ...                            ...
# 196                                       25.0                            329
# 197                                      25.11                           2385
# 198                                      22.87                          13037
# 199                                       33.0                           1026
# 200                                       26.0                           1120
#
#     Registration_for_higher_education_within_8_years_in_percent  \
# 0                                                   ..
# 1                                                28.50
# 2                                                46.10
# 3                                                23.30
# 4                                                26.60
# ..                                                 ...
# 196                                                8.5
# 197                                                9.7
# 198                                               41.1
# 199                                               51.3
# 200                                                6.3
#
#      number_of_students_in_percent
# 0                             3.74
# 1                             2.32
# 2                             3.03
# 3                             2.11
# 4                             1.84
# ..                             ...
# 196                          14.40
# 197                          11.90
# 198                          20.80
# 199                          13.60
# 200                           7.50
#
# [804 rows x 8 columns]

# %%
options = webdriver.ChromeOptions() 
options.add_argument("--enable-webgl-developer-extensions") 
options.add_argument("--enable-webgl-draft-extensions") 
driver = webdriver.Chrome(PATH,options=options)
driver.vars = {}
url = "https://boardsgenerator.cbs.gov.il/pages/WebParts/YishuvimPage.aspx?level_1=%D7%A9%D7%9B%D7%A8%20/%20%D7%94%D7%9B%D7%A0%D7%A1%D7%95%D7%AA"
driver.get(url)
time.sleep(2)
element = driver.find_element(By.ID, "select2-chosen-4")
actions = ActionChains(driver)
time.sleep(2)
actions.move_to_element(element).perform()
element = driver.find_element(By.CSS_SELECTOR, "body")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
element = driver.find_element(By.ID, "select2-chosen-4")
actions = ActionChains(driver)
time.sleep(2)
actions.move_to_element(element).click_and_hold().perform()
element = driver.find_element(By.ID, "select2-drop-mask")
actions = ActionChains(driver)
time.sleep(2)
actions.move_to_element(element).release().perform()
driver.find_element(By.XPATH, "//*[@id=\"select2-results-4\"]/li[8]").click()
time.sleep(5)
for i in range(1, 6):
    selectCity = driver.find_element(By.ID, "select2-chosen-8")
    selectCity.click()
    time.sleep(10)
    driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]/li[" + str(i) + "]").click()
    time.sleep(10)
    df_temp = get_tables()
    year = selectCity.text
    #print(year)
    dic_years[year] = df_temp
    dic_years[year].insert(0, "year", year, True)
driver.quit()
dic_years[year]
# Out:
#      year  סמל היישוב      שם יישוב  \
# 0    2015         472       אבו גוש
# 1    2015         473      אבו סנאן
# 2    2015         182     אבן יהודה
# 3    2015        2710    אום אל-פחם
# 4    2015          31        אופקים
# ..    ...         ...           ...
# 219  2015         538           שעב
# 220  2015        8800         שפרעם
# 221  2015        5000  תל אביב -יפו
# 222  2015         154       תל מונד
# 223  2015        1054        תל שבע
#
#      שכר ממוצע לחודש של שכירים (ש"ח) כלל השכירים  \
# 0                                        6275.59
# 1                                        6060.40
# 2                                       13502.86
# 3                                        5289.00
# 4                                        9496.00
# ..                                           ...
# 219                                      5312.02
# 220                                      6142.00
# 221                                     10808.00
# 222                                     14056.74
# 223                                      5083.17
#
#      שכר ממוצע לחודש של שכירים (ש"ח) גברים  \
# 0                                  6928.63
# 1                                  7314.21
# 2                                 16816.52
# 3                                  6096.00
# 4                                 12155.00
# ..                                     ...
# 219                                6020.50
# 220                                7286.00
# 221                               12888.00
# 222                               17904.35
# 223                                5869.36
#
#      שכר ממוצע לחודש של שכירים (ש"ח) נשים  \
# 0                                 5240.03
# 1                                 4302.60
# 2                                10097.43
# 3                                 3811.00
# 4                                 7006.00
# ..                                    ...
# 219                               4112.21
# 220                               4489.00
# 221                               8667.00
# 222                              10202.37
# 223                               3530.30
#
#      אחוז שינוי ריאלי לעומת השנה הקודמת של שכר ממוצע לחודש של שכירים כלל השכירים  \
# 0                                                  4.7
# 1                                                  4.3
# 2                                                  5.2
# 3                                                  3.0
# 4                                                  6.4
# ..                                                 ...
# 219                                                4.7
# 220                                                3.7
# 221                                                5.8
# 222                                                4.1
# 223                                               -0.3
#
#      אחוז שינוי ריאלי לעומת השנה הקודמת של שכר ממוצע לחודש של שכירים גברים  \
# 0                                                  3.9
# 1                                                  5.3
# 2                                                  3.6
# 3                                                  2.4
# 4                                                  6.7
# ..                                                 ...
# 219                                                4.1
# 220                                                4.8
# 221                                                6.0
# 222                                                4.3
# 223                                               -1.2
#
#      אחוז שינוי ריאלי לעומת השנה הקודמת של שכר ממוצע לחודש של שכירים נשים  \
# 0                                                  6.3
# 1                                                  2.3
# 2                                                  5.7
# 3                                                  5.9
# 4                                                  5.0
# ..                                                 ...
# 219                                                6.9
# 220                                                2.2
# 221                                                4.5
# 222                                                2.9
# 223                                                2.2
#
#      מספר השכירים  אחוז השכירים המשתכרים עד שכר מינימום  מספר העצמאים  \
# 0            2728                                  42.2           130
# 1            4900                                  49.7           435
# 2            6077                                  27.6           660
# 3           16739                                  56.9          1487
# 4            2967                                  38.1           231
# ..            ...                                   ...           ...
# 219          2443                                  52.6           150
# 220         15471                                  48.8          1109
# 221        224083                                  31.9         23222
# 222          5699                                  28.5           603
# 223          3954                                  55.7           135
#
#      הכנסה ממוצעת לחודש של העצמאים (ש"ח)  \
# 0                                6656.52
# 1                                7940.37
# 2                               12913.98
# 3                                7864.00
# 4                                9128.00
# ..                                   ...
# 219                              6452.12
# 220                              8546.00
# 221                             11685.00
# 222                             13015.24
# 223                             11588.19
#
#      אחוז שינוי ריאלי של הכנסה ממוצעת לחודש של העצמאים לעומת השנה הקודמת  \
# 0                                                 -0.8
# 1                                                  9.8
# 2                                                 -1.3
# 3                                                  3.0
# 4                                                 19.6
# ..                                                 ...
# 219                                                3.8
# 220                                                7.1
# 221                                                6.2
# 222                                                5.9
# 223                                                1.2
#
#      אחוז העצמאים המשתכרים עד מחצית השכר הממוצע  \
# 0                                          53.1
# 1                                          44.6
# 2                                          32.3
# 3                                          44.5
# 4                                          39.4
# ..                                          ...
# 219                                        60.0
# 220                                        41.8
# 221                                        37.5
# 222                                        31.0
# 223                                        38.5
#
#      מדד אי-השוויון שכירים (מדד ג'יני, 0 שוויון מלא)
# 0                                               0.34
# 1                                               0.39
# 2                                               0.48
# 3                                               0.38
# 4                                               0.45
# ..                                               ...
# 219                                             0.35
# 220                                             0.38
# 221                                             0.47
# 222                                             0.50
# 223                                             0.36
#
# [224 rows x 16 columns]

# %%
df_employees_info = pd.DataFrame()
df_years_temp = pd.DataFrame(columns=['year', 'city','number_of_self_employees', 'number_of_employees', 'employees_average_monthly_wage', 'employees_average_monthly_wage_change_in_percent', 'self_employees_average_monthly_wage', 'self_employees_average_monthly_wage_change_in_percent'])
for i in dic_years:
    #print(i)
    if(i == '2015'):
        break
    df_temp = dic_years[i]
    df_years_temp['year'] = df_temp.iloc[:,0].values
    df_years_temp['city'] = df_temp.iloc[:,2].values
    df_years_temp['number_of_self_employees'] =  df_temp.iloc[:,11].values
    df_years_temp['number_of_employees'] = df_temp.iloc[:,9].values
    df_years_temp['employees_average_monthly_wage'] = df_temp.iloc[:,3].values
    df_years_temp['employees_average_monthly_wage_change_in_percent'] = df_temp.iloc[:,6].values
    df_years_temp['self_employees_average_monthly_wage'] = df_temp.iloc[:,12].values
    df_years_temp['self_employees_average_monthly_wage_change_in_percent'] = df_temp.iloc[:,13].values
    df_employees_info = df_employees_info.append(df_years_temp)
df_employees_info.to_csv('data/dfEmployees.csv', mode='w+', encoding='utf-8-sig',index=False)
df_employees_info
# Out:
# C:\Users\netanel.m\AppData\Local\Temp\ipykernel_1528\1643590336.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_employees_info = df_employees_info.append(df_years_temp)
# C:\Users\netanel.m\AppData\Local\Temp\ipykernel_1528\1643590336.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_employees_info = df_employees_info.append(df_years_temp)
#      year          city  number_of_self_employees  number_of_employees  \
# 0    2019       אבו גוש                       151                 3393
# 1    2019      אבו סנאן                       626                 5841
# 2    2019     אבן יהודה                       899                 6265
# 3    2019    אום אל-פחם                      1918                22149
# 4    2019        אופקים                       295                 3342
# ..    ...           ...                       ...                  ...
# 219  2016           שעב                      4032                 4032
# 220  2016         שפרעם                      1161                16307
# 221  2016  תל אביב -יפו                     24447               223935
# 222  2016       תל מונד                       660                 5819
# 223  2016        תל שבע                       149                 4543
#
#      employees_average_monthly_wage  \
# 0                           7294.03
# 1                           7071.17
# 2                          14054.00
# 3                           5869.82
# 4                           9398.05
# ..                              ...
# 219                         4032.00
# 220                         6236.00
# 221                        11017.00
# 222                        13983.03
# 223                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 219                                           4032.00
# 220                                              2.00
# 221                                              2.50
# 222                                             -0.02
# 223                                             -1.46
#
#      self_employees_average_monthly_wage  \
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 219                              4032.00
# 220                              8996.00
# 221                             11908.00
# 222                             13735.86
# 223                             11631.40
#
#      self_employees_average_monthly_wage_change_in_percent
# 0                                                -7.67
# 1                                                -0.75
# 2                                                -1.72
# 3                                                -0.83
# 4                                                -1.31
# ..                                                 ...
# 219                                            4032.00
# 220                                               5.79
# 221                                               2.42
# 222                                               6.07
# 223                                               0.88
#
# [896 rows x 8 columns]

# %%
#final_DataFrame = pd.DataFrame(columns=['year', 'city', 'population', 'potential_student_count', 'number_of_self_employees', 'number_of_employees', 'employees_average_monthly_wage', 'employees_average_monthly_wage_change_in_percent', 'self_employees_average_monthly_wage', 'self_employees_average_monthly_wage_change_in_percent', 'number_of_high_schools', 'number_of_bachelor_graduates_in_percent', 'number_of_high_school_graduates_in_percent', 'number_of_high_school_students', 'Registration_for_higher_education_within_8_years_in_percent', 'number_of_students_in_percent'])

#df_temp = pd.DataFrame(columns=['year', 'city','number_of_self_employees', 'number_of_employees', 'employees_average_monthly_wage', 'employees_average_monthly_wage_change_in_percent', 'self_employees_average_monthly_wage', 'self_employees_average_monthly_wage_change_in_percent'])
df_education = pd.read_csv('data/dfEducation.csv')
df_employees_info = pd.read_csv('data/dfEmployees.csv')

df_eduoEmplo = [df_education, df_employees_info]
df_eduoEmplo = pd.merge(df_education, df_employees_info,  how='left', left_on=['year','city'], right_on = ['year','city'])
#df_temp = df_temp.loc[:,~df_temp.columns.duplicated()].copy()
#print(df_temp)
df_eduoEmplo
#final_DataFrame = pd.merge(final_DataFrame, df_temp, how='inner')#, left_on=['year','city'], right_on = ['year','city'])
#final_DataFrame
# Out:
#      year          city number_of_high_schools  \
# 0    2019       אבו גוש                      3
# 1    2019      אבו סנאן                      3
# 2    2019     אבן יהודה                      3
# 3    2019    אום אל-פחם                     13
# 4    2019        אופקים                     11
# ..    ...           ...                    ...
# 799  2016           שעב                     ..
# 800  2016         שפרעם                      9
# 801  2016  תל אביב -יפו                     64
# 802  2016       תל מונד                     ..
# 803  2016        תל שבע                      5
#
#     number_of_bachelor_graduates_in_percent  \
# 0                                     13.03
# 1                                     12.09
# 2                                     55.59
# 3                                      8.52
# 4                                     12.26
# ..                                      ...
# 799                                   52.30
# 800                                   41.20
# 801                                   65.40
# 802                                   84.30
# 803                                   25.90
#
#     number_of_high_school_graduates_in_percent number_of_high_school_students  \
# 0                                        59.29                            361
# 1                                        65.81                            592
# 2                                        83.96                           1087
# 3                                        59.40                           3838
# 4                                        50.24                           1551
# ..                                         ...                            ...
# 799                                       25.0                            329
# 800                                      25.11                           2385
# 801                                      22.87                          13037
# 802                                       33.0                           1026
# 803                                       26.0                           1120
#
#     Registration_for_higher_education_within_8_years_in_percent  \
# 0                                                   ..
# 1                                                28.50
# 2                                                46.10
# 3                                                23.30
# 4                                                26.60
# ..                                                 ...
# 799                                                8.5
# 800                                                9.7
# 801                                               41.1
# 802                                               51.3
# 803                                                6.3
#
#      number_of_students_in_percent  number_of_self_employees  \
# 0                             3.74                       151
# 1                             2.32                       626
# 2                             3.03                       899
# 3                             2.11                      1918
# 4                             1.84                       295
# ..                             ...                       ...
# 799                          14.40                      4032
# 800                          11.90                      1161
# 801                          20.80                     24447
# 802                          13.60                       660
# 803                           7.50                       149
#
#      number_of_employees  employees_average_monthly_wage  \
# 0                   3393                         7294.03
# 1                   5841                         7071.17
# 2                   6265                        14054.00
# 3                  22149                         5869.82
# 4                   3342                         9398.05
# ..                   ...                             ...
# 799                 4032                         4032.00
# 800                16307                         6236.00
# 801               223935                        11017.00
# 802                 5819                        13983.03
# 803                 4543                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 799                                           4032.00
# 800                                              2.00
# 801                                              2.50
# 802                                             -0.02
# 803                                             -1.46
#
#      self_employees_average_monthly_wage  \
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 799                              4032.00
# 800                              8996.00
# 801                             11908.00
# 802                             13735.86
# 803                             11631.40
#
#      self_employees_average_monthly_wage_change_in_percent
# 0                                                -7.67
# 1                                                -0.75
# 2                                                -1.72
# 3                                                -0.83
# 4                                                -1.31
# ..                                                 ...
# 799                                            4032.00
# 800                                               5.79
# 801                                               2.42
# 802                                               6.07
# 803                                               0.88
#
# [804 rows x 14 columns]

# %%
fileName="data/YearsDemography.csv"

if os.path.isfile(fileName):
    dfDemography = pd.read_csv(fileName)
else:
#     PATH = "C:/Users/shake/chromedriver.exe"
    url = "https://boardsgenerator.cbs.gov.il/pages/WebParts/YishuvimPage.aspx?level_1=%D7%A9%D7%9B%D7%A8%20/%20%D7%94%D7%9B%D7%A0%D7%A1%D7%95%D7%AA"
    driver = webdriver.Chrome(PATH)
    dfDemography = GetYearsDemography(fileName,url)
    
dfDemography
# Out:
#       Years      שם יישוב  סמל היישוב  \
# 0      2020       אבו גוש         472
# 1      2020      אבו סנאן         473
# 2      2020     אבן יהודה         182
# 3      2020    אום אל-פחם        2710
# 4      2020        אופקים          31
# ...     ...           ...         ...
# 3592   2003           שעב         538
# 3593   2003         שפרעם        8800
# 3594   2003  תל אביב -יפו        5000
# 3595   2003       תל מונד         154
# 3596   2003        תל שבע        1054
#
#      צפיפות אוכלוסייה לקמ''ר ביישובים שמנו 5,000 תושבים ויותר  \
# 0                                                4114.4
# 1                                                2136.9
# 2                                                1696.2
# 3                                                2187.4
# 4                                                1990.8
# ...                                                 ...
# 3592                                                2.9
# 3593                                               15.7
# 3594                                              173.8
# 3595                                                  4
# 3596                                                5.9
#
#       סה"כ אוכלוסייה בסוף השנה יהודים ואחרים (אחוזים)  \
# 0                       7771.0                      -
# 1                      14306.0                      -
# 2                      14020.0                    100
# 3                      56777.0                      -
# 4                      32555.0                   99.3
# ...                        ...                    ...
# 3592                       2.8                  14.04
# 3593                      15.5                   13.2
# 3594                     189.6                      7
# 3595                       3.9                  11.43
# 3596                       6.0                  24.35
#
#      יהודים (אחוזים מתוך יהודים ואחרים) ערבים (אחוזים)  \
# 0                                     -           98.9
# 1                                     -           99.8
# 2                                  98.4              -
# 3                                     -           99.9
# 4                                  93.4              -
# ...                                 ...            ...
# 3592                              13.56          13.17
# 3593                               12.5           10.9
# 3594                                5.5            4.8
# 3595                              10.62           9.73
# 3596                              17.33          14.33
#
#      מוסלמים (אחוזים מתוך האוכלוסייה הערבית)  \
# 0                                       99.8
# 1                                       54.6
# 2                                          -
# 3                                        100
# 4                                          -
# ...                                      ...
# 3592                                    9.43
# 3593                                    8.33
# 3594                                     5.2
# 3595                                    7.77
# 3596                                   10.57
#
#      נוצרים (אחוזים מתוך האוכלוסייה הערבית)  ...  \
# 0                                         -  ...
# 1                                      15.2  ...
# 2                                         -  ...
# 3                                         -  ...
# 4                                         -  ...
# ...                                     ...  ...
# 3592                                  17.07  ...
# 3593                                  16.22  ...
# 3594                                   18.5  ...
# 3595                                  12.77  ...
# 3596                                  16.44  ...
#
#      נישאים שיעור ל-1,000 תושבים לא נשואים בני 15 ומעלה 2019  \
# 0                                                  44.6
# 1                                                  42.2
# 2                                                    20
# 3                                                  53.7
# 4                                                  44.5
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       מתגרשים סה"כ גברים ונשים 2019  \
# 0                                26
# 1                                29
# 2                                40
# 3                               104
# 4                               119
# ...                             ...
# 3592                            NaN
# 3593                            NaN
# 3594                            NaN
# 3595                            NaN
# 3596                            NaN
#
#       מתגרשים שיעור ל-1,000 תושבים נשואים בני 15 ומעלה 2019  \
# 0                                                   8.1
# 1                                                   4.7
# 2                                                     7
# 3                                                   4.5
# 4                                                  10.7
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) סך מוסדות דיור משותף ברשות  \
# 0                                                     4
# 1                                                     -
# 2                                                     5
# 3                                                    ..
# 4                                                     6
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) סך דיירי דיור משותף ברשות  \
# 0                                                    31
# 1                                                     -
# 2                                                   347
# 3                                                    ..
# 4                                                   559
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים בבתי אבות ובדיור מוגן  \
# 0                                                     -
# 1                                                     -
# 2                                                  1.35
# 3                                                    ..
# 4                                                  0.87
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות חינוך  \
# 0                                                   0.3
# 1                                                     -
# 2                                                   0.3
# 3                                                    ..
# 4                                                  0.58
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות דת  \
# 0                                                  0.04
# 1                                                     -
# 2                                                     -
# 3                                                    ..
# 4                                                  0.17
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות אשפוז כולל הוסטלים  \
# 0                                                  0.06
# 1                                                     -
# 2                                                  0.83
# 3                                                    ..
# 4                                                     -
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות אחרים
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                    ..
# 4                                                  0.09
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
# [3597 rows x 68 columns]

# %%
dfDemography=dfDemography.rename(columns={"Years":"year"})
dfDemography=dfDemography.rename(columns={"שם יישוב":"city"})
dfDemography=dfDemography.rename(columns={'סה"כ אוכלוסייה בסוף השנה':"population"})
dfDemography=dfDemography.rename(columns={'אחוז באוכלוסייה בסוף השנה בני 19-15':"Percentage of population at the end of the year aged 19-15"})
dfDemography=dfDemography.rename(columns={'אחוז באוכלוסייה בסוף השנה בני 29-20':"Percentage of population at the end of the year aged 20-29"})
dfDemography=dfDemography.rename(columns={'אחוז באוכלוסייה בסוף השנה בני 44-30':"Percentage of population at the end of the year aged 30-44"})

dfYearsCityPop=dfDemography

populationList = dfYearsCityPop['population'].tolist()
for i in range(len(populationList)):
    if (populationList[i] <= 1000) :
            populationList[i] = populationList[i] * 1000

dfYearsCityPop['population'] = populationList
dfYearsCityPop.to_csv('data/dfYearsCityPop.csv', mode='w+', encoding='utf-8-sig',index=False)
dfYearsCityPop
# Out:
#       year          city  סמל היישוב  \
# 0     2020       אבו גוש         472
# 1     2020      אבו סנאן         473
# 2     2020     אבן יהודה         182
# 3     2020    אום אל-פחם        2710
# 4     2020        אופקים          31
# ...    ...           ...         ...
# 3592  2003           שעב         538
# 3593  2003         שפרעם        8800
# 3594  2003  תל אביב -יפו        5000
# 3595  2003       תל מונד         154
# 3596  2003        תל שבע        1054
#
#      צפיפות אוכלוסייה לקמ''ר ביישובים שמנו 5,000 תושבים ויותר  population  \
# 0                                                4114.4            7771.0
# 1                                                2136.9           14306.0
# 2                                                1696.2           14020.0
# 3                                                2187.4           56777.0
# 4                                                1990.8           32555.0
# ...                                                 ...               ...
# 3592                                                2.9            2800.0
# 3593                                               15.7           15500.0
# 3594                                              173.8          189600.0
# 3595                                                  4            3900.0
# 3596                                                5.9            6000.0
#
#      יהודים ואחרים (אחוזים) יהודים (אחוזים מתוך יהודים ואחרים) ערבים (אחוזים)  \
# 0                         -                                  -           98.9
# 1                         -                                  -           99.8
# 2                       100                               98.4              -
# 3                         -                                  -           99.9
# 4                      99.3                               93.4              -
# ...                     ...                                ...            ...
# 3592                  14.04                              13.56          13.17
# 3593                   13.2                               12.5           10.9
# 3594                      7                                5.5            4.8
# 3595                  11.43                              10.62           9.73
# 3596                  24.35                              17.33          14.33
#
#      מוסלמים (אחוזים מתוך האוכלוסייה הערבית)  \
# 0                                       99.8
# 1                                       54.6
# 2                                          -
# 3                                        100
# 4                                          -
# ...                                      ...
# 3592                                    9.43
# 3593                                    8.33
# 3594                                     5.2
# 3595                                    7.77
# 3596                                   10.57
#
#      נוצרים (אחוזים מתוך האוכלוסייה הערבית)  ...  \
# 0                                         -  ...
# 1                                      15.2  ...
# 2                                         -  ...
# 3                                         -  ...
# 4                                         -  ...
# ...                                     ...  ...
# 3592                                  17.07  ...
# 3593                                  16.22  ...
# 3594                                   18.5  ...
# 3595                                  12.77  ...
# 3596                                  16.44  ...
#
#      נישאים שיעור ל-1,000 תושבים לא נשואים בני 15 ומעלה 2019  \
# 0                                                  44.6
# 1                                                  42.2
# 2                                                    20
# 3                                                  53.7
# 4                                                  44.5
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       מתגרשים סה"כ גברים ונשים 2019  \
# 0                                26
# 1                                29
# 2                                40
# 3                               104
# 4                               119
# ...                             ...
# 3592                            NaN
# 3593                            NaN
# 3594                            NaN
# 3595                            NaN
# 3596                            NaN
#
#       מתגרשים שיעור ל-1,000 תושבים נשואים בני 15 ומעלה 2019  \
# 0                                                   8.1
# 1                                                   4.7
# 2                                                     7
# 3                                                   4.5
# 4                                                  10.7
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) סך מוסדות דיור משותף ברשות  \
# 0                                                     4
# 1                                                     -
# 2                                                     5
# 3                                                    ..
# 4                                                     6
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) סך דיירי דיור משותף ברשות  \
# 0                                                    31
# 1                                                     -
# 2                                                   347
# 3                                                    ..
# 4                                                   559
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים בבתי אבות ובדיור מוגן  \
# 0                                                     -
# 1                                                     -
# 2                                                  1.35
# 3                                                    ..
# 4                                                  0.87
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות חינוך  \
# 0                                                   0.3
# 1                                                     -
# 2                                                   0.3
# 3                                                    ..
# 4                                                  0.58
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות דת  \
# 0                                                  0.04
# 1                                                     -
# 2                                                     -
# 3                                                    ..
# 4                                                  0.17
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות אשפוז כולל הוסטלים  \
# 0                                                  0.06
# 1                                                     -
# 2                                                  0.83
# 3                                                    ..
# 4                                                     -
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות אחרים
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                    ..
# 4                                                  0.09
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
# [3597 rows x 68 columns]

# %%
dfYearsCityPop = pd.read_csv("data/dfYearsCityPop.csv")

Sum_filterdfDemograph =dfYearsCityPop.iloc[:, [16,17,18]]
Sum_filterdfDemograph['precent count Age 15-44 '] = Sum_filterdfDemograph.sum(axis=1, numeric_only= True)
Sum_filterdfDemograph.insert(loc=0, column='year', value=dfYearsCityPop['year'].values)
Sum_filterdfDemograph.insert(loc=1, column='city', value=dfYearsCityPop['city'].values)
Sum_filterdfDemograph.insert(loc=2, column='population', value=dfYearsCityPop['population'].values)
#final_DataFrame.insert()
Sum_filterdfDemograph
# Out:
# C:\Users\netanel.m\AppData\Local\Temp\ipykernel_1528\555356140.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sum_filterdfDemograph['precent count Age 15-44 '] = Sum_filterdfDemograph.sum(axis=1, numeric_only= True)
#       year          city  population  \
# 0     2020       אבו גוש      7771.0
# 1     2020      אבו סנאן     14306.0
# 2     2020     אבן יהודה     14020.0
# 3     2020    אום אל-פחם     56777.0
# 4     2020        אופקים     32555.0
# ...    ...           ...         ...
# 3592  2003           שעב      2800.0
# 3593  2003         שפרעם     15500.0
# 3594  2003  תל אביב -יפו    189600.0
# 3595  2003       תל מונד      3900.0
# 3596  2003        תל שבע      6000.0
#
#       Percentage of population at the end of the year aged 19-15  \
# 0                                                  8.89
# 1                                                  9.60
# 2                                                  8.29
# 3                                                 10.97
# 4                                                  7.06
# ...                                                 ...
# 3592                                             171.00
# 3593                                             846.00
# 3594                                            6338.00
# 3595                                             149.00
# 3596                                             645.00
#
#       Percentage of population at the end of the year aged 20-29  \
# 0                                                 16.97
# 1                                                 18.01
# 2                                                 10.17
# 3                                                 18.67
# 4                                                 16.04
# ...                                                 ...
# 3592                                               9.00
# 3593                                              75.00
# 3594                                            3627.00
# 3595                                              25.00
# 3596                                              29.00
#
#       Percentage of population at the end of the year aged 30-44  \
# 0                                                 20.11
# 1                                                 20.42
# 2                                                 16.93
# 3                                                 17.91
# 4                                                 18.55
# ...                                                 ...
# 3592                                             162.00
# 3593                                             771.00
# 3594                                            2711.00
# 3595                                             124.00
# 3596                                             616.00
#
#       precent count Age 15-44
# 0                        45.97
# 1                        48.03
# 2                        35.39
# 3                        47.55
# 4                        41.65
# ...                        ...
# 3592                    342.00
# 3593                   1692.00
# 3594                  12676.00
# 3595                    298.00
# 3596                   1290.00
#
# [3597 rows x 7 columns]

# %%
      
final_DataFrame = pd.merge(Sum_filterdfDemograph,df_eduoEmplo, how='inner', left_on=['year','city'], right_on = ['year','city'])

final_DataFrame.to_csv('data/finalDataFrame.csv', mode='w+', encoding='utf-8-sig',index=False)  
final_DataFrame
# Out:
#      year          city  population  \
# 0    2019       אבו גוש      7698.0
# 1    2019      אבו סנאן     14099.0
# 2    2019     אבן יהודה     13826.0
# 3    2019    אום אל-פחם     56109.0
# 4    2019        אופקים     30662.0
# ..    ...           ...         ...
# 799  2016           שעב      6700.0
# 800  2016         שפרעם     40500.0
# 801  2016  תל אביב -יפו    438800.0
# 802  2016       תל מונד     12200.0
# 803  2016        תל שבע     19200.0
#
#      Percentage of population at the end of the year aged 19-15  \
# 0                                                 9.31
# 1                                                10.13
# 2                                                 8.38
# 3                                                11.35
# 4                                                 6.92
# ..                                                 ...
# 799                                              10.40
# 800                                              10.10
# 801                                               4.80
# 802                                              11.00
# 803                                              15.00
#
#      Percentage of population at the end of the year aged 20-29  \
# 0                                                17.33
# 1                                                17.80
# 2                                                 9.63
# 3                                                18.19
# 4                                                16.53
# ..                                                 ...
# 799                                              10.80
# 800                                              10.30
# 801                                               4.20
# 802                                              10.20
# 803                                              12.90
#
#      Percentage of population at the end of the year aged 30-44  \
# 0                                                20.12
# 1                                                20.31
# 2                                                17.90
# 3                                                17.91
# 4                                                18.23
# ..                                                 ...
# 799                                              18.30
# 800                                              16.50
# 801                                              14.20
# 802                                              11.90
# 803                                              16.20
#
#      precent count Age 15-44  number_of_high_schools  \
# 0                       46.76                      3
# 1                       48.24                      3
# 2                       35.91                      3
# 3                       47.45                     13
# 4                       41.68                     11
# ..                        ...                    ...
# 799                     39.50                     ..
# 800                     36.90                      9
# 801                     23.20                     64
# 802                     33.10                     ..
# 803                     44.10                      5
#
#     number_of_bachelor_graduates_in_percent  \
# 0                                     13.03
# 1                                     12.09
# 2                                     55.59
# 3                                      8.52
# 4                                     12.26
# ..                                      ...
# 799                                   52.30
# 800                                   41.20
# 801                                   65.40
# 802                                   84.30
# 803                                   25.90
#
#     number_of_high_school_graduates_in_percent number_of_high_school_students  \
# 0                                        59.29                            361
# 1                                        65.81                            592
# 2                                        83.96                           1087
# 3                                        59.40                           3838
# 4                                        50.24                           1551
# ..                                         ...                            ...
# 799                                       25.0                            329
# 800                                      25.11                           2385
# 801                                      22.87                          13037
# 802                                       33.0                           1026
# 803                                       26.0                           1120
#
#     Registration_for_higher_education_within_8_years_in_percent  \
# 0                                                   ..
# 1                                                28.50
# 2                                                46.10
# 3                                                23.30
# 4                                                26.60
# ..                                                 ...
# 799                                                8.5
# 800                                                9.7
# 801                                               41.1
# 802                                               51.3
# 803                                                6.3
#
#      number_of_students_in_percent  number_of_self_employees  \
# 0                             3.74                       151
# 1                             2.32                       626
# 2                             3.03                       899
# 3                             2.11                      1918
# 4                             1.84                       295
# ..                             ...                       ...
# 799                          14.40                      4032
# 800                          11.90                      1161
# 801                          20.80                     24447
# 802                          13.60                       660
# 803                           7.50                       149
#
#      number_of_employees  employees_average_monthly_wage  \
# 0                   3393                         7294.03
# 1                   5841                         7071.17
# 2                   6265                        14054.00
# 3                  22149                         5869.82
# 4                   3342                         9398.05
# ..                   ...                             ...
# 799                 4032                         4032.00
# 800                16307                         6236.00
# 801               223935                        11017.00
# 802                 5819                        13983.03
# 803                 4543                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 799                                           4032.00
# 800                                              2.00
# 801                                              2.50
# 802                                             -0.02
# 803                                             -1.46
#
#      self_employees_average_monthly_wage  \
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 799                              4032.00
# 800                              8996.00
# 801                             11908.00
# 802                             13735.86
# 803                             11631.40
#
#      self_employees_average_monthly_wage_change_in_percent
# 0                                                -7.67
# 1                                                -0.75
# 2                                                -1.72
# 3                                                -0.83
# 4                                                -1.31
# ..                                                 ...
# 799                                            4032.00
# 800                                               5.79
# 801                                               2.42
# 802                                               6.07
# 803                                               0.88
#
# [804 rows x 19 columns]

# %%
# final_DataFrame = pd.read_csv('data/finalDataFrame.csv')
# final_DataFrame = final_DataFrame.replace( '..', np.nan )
# final_DataFrame = final_DataFrame.replace( 'NaN', np.nan )
# final_DataFrame = final_DataFrame.replace( '-', np.nan )

# final_DataFrame

# %%
final_DataFrame = pd.read_csv('data/finalDataFrame.csv')
tempValue=-9999999999
final_DataFrame = final_DataFrame.drop(columns=['city'])
final_DataFrame = final_DataFrame.drop(columns=['year'])

final_DataFrame = final_DataFrame.replace( '..', tempValue )
final_DataFrame = final_DataFrame.replace( 'NaN', tempValue )
final_DataFrame = final_DataFrame.replace( '-', tempValue )
final_DataFrame = final_DataFrame.astype(float)
final_DataFrame = final_DataFrame.replace( tempValue, np.nan)
final_DataFrame
for column in final_DataFrame:
    #Finding the mean of the column having NaN
    mean_value=final_DataFrame[column].mean() 
    final_DataFrame[column].fillna(value=mean_value, inplace=True)
final_DataFrame
# Out:
#      population  Percentage of population at the end of the year aged 19-15  \
# 0        7698.0                                               9.31
# 1       14099.0                                              10.13
# 2       13826.0                                               8.38
# 3       56109.0                                              11.35
# 4       30662.0                                               6.92
# ..          ...                                                ...
# 799      6700.0                                              10.40
# 800     40500.0                                              10.10
# 801    438800.0                                               4.80
# 802     12200.0                                              11.00
# 803     19200.0                                              15.00
#
#      Percentage of population at the end of the year aged 20-29  \
# 0                                                17.33
# 1                                                17.80
# 2                                                 9.63
# 3                                                18.19
# 4                                                16.53
# ..                                                 ...
# 799                                              10.80
# 800                                              10.30
# 801                                               4.20
# 802                                              10.20
# 803                                              12.90
#
#      Percentage of population at the end of the year aged 30-44  \
# 0                                                20.12
# 1                                                20.31
# 2                                                17.90
# 3                                                17.91
# 4                                                18.23
# ..                                                 ...
# 799                                              18.30
# 800                                              16.50
# 801                                              14.20
# 802                                              11.90
# 803                                              16.20
#
#      precent count Age 15-44   number_of_high_schools  \
# 0                       46.76                3.000000
# 1                       48.24                3.000000
# 2                       35.91                3.000000
# 3                       47.45               13.000000
# 4                       41.68               11.000000
# ..                        ...                     ...
# 799                     39.50               11.704745
# 800                     36.90                9.000000
# 801                     23.20               64.000000
# 802                     33.10               11.704745
# 803                     44.10                5.000000
#
#      number_of_bachelor_graduates_in_percent  \
# 0                                      13.03
# 1                                      12.09
# 2                                      55.59
# 3                                       8.52
# 4                                      12.26
# ..                                       ...
# 799                                    52.30
# 800                                    41.20
# 801                                    65.40
# 802                                    84.30
# 803                                    25.90
#
#      number_of_high_school_graduates_in_percent  \
# 0                                         59.29
# 1                                         65.81
# 2                                         83.96
# 3                                         59.40
# 4                                         50.24
# ..                                          ...
# 799                                       25.00
# 800                                       25.11
# 801                                       22.87
# 802                                       33.00
# 803                                       26.00
#
#      number_of_high_school_students  \
# 0                             361.0
# 1                             592.0
# 2                            1087.0
# 3                            3838.0
# 4                            1551.0
# ..                              ...
# 799                           329.0
# 800                          2385.0
# 801                         13037.0
# 802                          1026.0
# 803                          1120.0
#
#      Registration_for_higher_education_within_8_years_in_percent  \
# 0                                            24.730698
# 1                                            28.500000
# 2                                            46.100000
# 3                                            23.300000
# 4                                            26.600000
# ..                                                 ...
# 799                                           8.500000
# 800                                           9.700000
# 801                                          41.100000
# 802                                          51.300000
# 803                                           6.300000
#
#      number_of_students_in_percent  number_of_self_employees  \
# 0                             3.74                     151.0
# 1                             2.32                     626.0
# 2                             3.03                     899.0
# 3                             2.11                    1918.0
# 4                             1.84                     295.0
# ..                             ...                       ...
# 799                          14.40                    4032.0
# 800                          11.90                    1161.0
# 801                          20.80                   24447.0
# 802                          13.60                     660.0
# 803                           7.50                     149.0
#
#      number_of_employees  employees_average_monthly_wage  \
# 0                 3393.0                         7294.03
# 1                 5841.0                         7071.17
# 2                 6265.0                        14054.00
# 3                22149.0                         5869.82
# 4                 3342.0                         9398.05
# ..                   ...                             ...
# 799               4032.0                         4032.00
# 800              16307.0                         6236.00
# 801             223935.0                        11017.00
# 802               5819.0                        13983.03
# 803               4543.0                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 799                                           4032.00
# 800                                              2.00
# 801                                              2.50
# 802                                             -0.02
# 803                                             -1.46
#
#      self_employees_average_monthly_wage  \
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 799                              4032.00
# 800                              8996.00
# 801                             11908.00
# 802                             13735.86
# 803                             11631.40
#
#      self_employees_average_monthly_wage_change_in_percent
# 0                                                -7.67
# 1                                                -0.75
# 2                                                -1.72
# 3                                                -0.83
# 4                                                -1.31
# ..                                                 ...
# 799                                            4032.00
# 800                                               5.79
# 801                                               2.42
# 802                                               6.07
# 803                                               0.88
#
# [804 rows x 17 columns]

# %%
def generateGragh(columnsName,color1,color2):
    x = reshapeCol(final_DataFrame,columnsName)
    plt.scatter(x=x,y=y,c=color1,marker='s',label=columnsName)
    m = lr.fit(X=x, y=y)
    plt.plot(x,m.predict(x),color2,linewidth=3)

# %%
# final_DataFrame = pd.read_csv('data/finalDataFrame.csv')
# final_DataFrame

# %%
#/////////////////////////////////////////test 1////////////////////////////////////////////////////

def reshapeCol(final_DataFrame,str):
  return final_DataFrame[[str]].values.reshape(final_DataFrame[str].shape[0],1)  



columns_names =['number_of_bachelor_graduates_in_percent', 'number_of_high_school_graduates_in_percent', 'Registration_for_higher_education_within_8_years_in_percent', 'number_of_students_in_percent']



# final_DataFrame = pd.read_csv('data/finalDataFrame.csv')
# final_DataFrame = final_DataFrame.replace( '..', np.nan )
# final_DataFrame = final_DataFrame.replace( 'NaN', np.nan )
# final_DataFrame = final_DataFrame.replace( '-', np.nan )
# final_DataFrame = final_DataFrame.drop(columns=['city'])
# final_DataFrame = final_DataFrame.filter(columns_names,axis=1)
# final_DataFrame = final_DataFrame.dropna()
# final_DataFrame = final_DataFrame.astype(float)

print(final_DataFrame)


number_of_students='number_of_students_in_percent'

number_of_bachelor_graduates_in_percent='number_of_bachelor_graduates_in_percent'
number_of_high_school_graduates_in_percent='number_of_high_school_graduates_in_percent'
Registration_for_higher_education_within_8_years_in_percent='Registration_for_higher_education_within_8_years_in_percent'

lr = linear_model.LinearRegression() # create a linear regression object

y = final_DataFrame[[number_of_students]].values.reshape(final_DataFrame[number_of_students].shape[0],1)


generateGragh(number_of_bachelor_graduates_in_percent,'r','tomato')
generateGragh(number_of_high_school_graduates_in_percent,'yellow','y')
generateGragh(Registration_for_higher_education_within_8_years_in_percent,'blue','darkblue')


#take all columns for next blocks
x = final_DataFrame[['number_of_bachelor_graduates_in_percent', 'number_of_high_school_graduates_in_percent', 'Registration_for_higher_education_within_8_years_in_percent']]#plt.scatter(x=x,y=y,c='b',marker='s',label='all')
m = lr.fit(X=x, y=y);


plt.xlabel('Referance columns')
plt.ylabel(number_of_students)
plt.show()
# Out:
#      population  Percentage of population at the end of the year aged 19-15  \
# 0        7698.0                                               9.31
# 1       14099.0                                              10.13
# 2       13826.0                                               8.38
# 3       56109.0                                              11.35
# 4       30662.0                                               6.92
# ..          ...                                                ...
# 799      6700.0                                              10.40
# 800     40500.0                                              10.10
# 801    438800.0                                               4.80
# 802     12200.0                                              11.00
# 803     19200.0                                              15.00
#
#      Percentage of population at the end of the year aged 20-29  \
# 0                                                17.33
# 1                                                17.80
# 2                                                 9.63
# 3                                                18.19
# 4                                                16.53
# ..                                                 ...
# 799                                              10.80
# 800                                              10.30
# 801                                               4.20
# 802                                              10.20
# 803                                              12.90
#
#      Percentage of population at the end of the year aged 30-44  \
# 0                                                20.12
# 1                                                20.31
# 2                                                17.90
# 3                                                17.91
# 4                                                18.23
# ..                                                 ...
# 799                                              18.30
# 800                                              16.50
# 801                                              14.20
# 802                                              11.90
# 803                                              16.20
#
#      precent count Age 15-44   number_of_high_schools  \
# 0                       46.76                3.000000
# 1                       48.24                3.000000
# 2                       35.91                3.000000
# 3                       47.45               13.000000
# 4                       41.68               11.000000
# ..                        ...                     ...
# 799                     39.50               11.704745
# 800                     36.90                9.000000
# 801                     23.20               64.000000
# 802                     33.10               11.704745
# 803                     44.10                5.000000
#
#      number_of_bachelor_graduates_in_percent  \
# 0                                      13.03
# 1                                      12.09
# 2                                      55.59
# 3                                       8.52
# 4                                      12.26
# ..                                       ...
# 799                                    52.30
# 800                                    41.20
# 801                                    65.40
# 802                                    84.30
# 803                                    25.90
#
#      number_of_high_school_graduates_in_percent  \
# 0                                         59.29
# 1                                         65.81
# 2                                         83.96
# 3                                         59.40
# 4                                         50.24
# ..                                          ...
# 799                                       25.00
# 800                                       25.11
# 801                                       22.87
# 802                                       33.00
# 803                                       26.00
#
#      number_of_high_school_students  \
# 0                             361.0
# 1                             592.0
# 2                            1087.0
# 3                            3838.0
# 4                            1551.0
# ..                              ...
# 799                           329.0
# 800                          2385.0
# 801                         13037.0
# 802                          1026.0
# 803                          1120.0
#
#      Registration_for_higher_education_within_8_years_in_percent  \
# 0                                            24.730698
# 1                                            28.500000
# 2                                            46.100000
# 3                                            23.300000
# 4                                            26.600000
# ..                                                 ...
# 799                                           8.500000
# 800                                           9.700000
# 801                                          41.100000
# 802                                          51.300000
# 803                                           6.300000
#
#      number_of_students_in_percent  number_of_self_employees  \
# 0                             3.74                     151.0
# 1                             2.32                     626.0
# 2                             3.03                     899.0
# 3                             2.11                    1918.0
# 4                             1.84                     295.0
# ..                             ...                       ...
# 799                          14.40                    4032.0
# 800                          11.90                    1161.0
# 801                          20.80                   24447.0
# 802                          13.60                     660.0
# 803                           7.50                     149.0
#
#      number_of_employees  employees_average_monthly_wage  \
# 0                 3393.0                         7294.03
# 1                 5841.0                         7071.17
# 2                 6265.0                        14054.00
# 3                22149.0                         5869.82
# 4                 3342.0                         9398.05
# ..                   ...                             ...
# 799               4032.0                         4032.00
# 800              16307.0                         6236.00
# 801             223935.0                        11017.00
# 802               5819.0                        13983.03
# 803               4543.0                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 799                                           4032.00
# 800                                              2.00
# 801                                              2.50
# 802                                             -0.02
# 803                                             -1.46
#
#      self_employees_average_monthly_wage  \
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 799                              4032.00
# 800                              8996.00
# 801                             11908.00
# 802                             13735.86
# 803                             11631.40
#
#      self_employees_average_monthly_wage_change_in_percent
# 0                                                -7.67
# 1                                                -0.75
# 2                                                -1.72
# 3                                                -0.83
# 4                                                -1.31
# ..                                                 ...
# 799                                            4032.00
# 800                                               5.79
# 801                                               2.42
# 802                                               6.07
# 803                                               0.88
#
# [804 rows x 17 columns]

# %%
print("R2:",lr.score(x,y))
print("R2:",r2_score(y,lr.predict(x)))
# Out:
# R2: 0.5900176076939934
# R2: 0.5900176076939934

# %%
print(final_DataFrame.corr())
pd.plotting.scatter_matrix(final_DataFrame, figsize=(10,10), diagonal='kde')
plt.show()
# Out:
#                                                     population  \
# population                                            1.000000
# Percentage of population at the end of the year...   -0.204716
# Percentage of population at the end of the year...   -0.118825
# Percentage of population at the end of the year...   -0.014624
# precent count Age 15-44                              -0.141227
# number_of_high_schools                                0.882670
# number_of_bachelor_graduates_in_percent              -0.044590
# number_of_high_school_graduates_in_percent            0.008622
# number_of_high_school_students                        0.951853
# Registration_for_higher_education_within_8_year...    0.029342
# number_of_students_in_percent                        -0.026193
# number_of_self_employees                              0.905619
# number_of_employees                                   0.972841
# employees_average_monthly_wage                        0.059808
# employees_average_monthly_wage_change_in_percent     -0.014116
# self_employees_average_monthly_wage                   0.063074
# self_employees_average_monthly_wage_change_in_p...   -0.015098
#
#                                                     Percentage of population at the end of the year aged 19-15  \
# population                                                                                  -0.204716
# Percentage of population at the end of the year...                                           1.000000
# Percentage of population at the end of the year...                                           0.319200
# Percentage of population at the end of the year...                                          -0.153154
# precent count Age 15-44                                                                      0.433433
# number_of_high_schools                                                                      -0.022729
# number_of_bachelor_graduates_in_percent                                                     -0.237441
# number_of_high_school_graduates_in_percent                                                  -0.067819
# number_of_high_school_students                                                              -0.085150
# Registration_for_higher_education_within_8_year...                                          -0.277644
# number_of_students_in_percent                                                               -0.078934
# number_of_self_employees                                                                    -0.305611
# number_of_employees                                                                         -0.299233
# employees_average_monthly_wage                                                              -0.397868
# employees_average_monthly_wage_change_in_percent                                             0.023695
# self_employees_average_monthly_wage                                                         -0.231031
# self_employees_average_monthly_wage_change_in_p...                                           0.022921
#
#                                                     Percentage of population at the end of the year aged 20-29  \
# population                                                                                  -0.118825
# Percentage of population at the end of the year...                                           0.319200
# Percentage of population at the end of the year...                                           1.000000
# Percentage of population at the end of the year...                                           0.503538
# precent count Age 15-44                                                                      0.919961
# number_of_high_schools                                                                      -0.090035
# number_of_bachelor_graduates_in_percent                                                     -0.428001
# number_of_high_school_graduates_in_percent                                                   0.436367
# number_of_high_school_students                                                              -0.042173
# Registration_for_higher_education_within_8_year...                                          -0.121637
# number_of_students_in_percent                                                               -0.319021
# number_of_self_employees                                                                    -0.119898
# number_of_employees                                                                         -0.150747
# employees_average_monthly_wage                                                              -0.285990
# employees_average_monthly_wage_change_in_percent                                            -0.013915
# self_employees_average_monthly_wage                                                         -0.230499
# self_employees_average_monthly_wage_change_in_p...                                          -0.023282
#
#                                                     Percentage of population at the end of the year aged 30-44  \
# population                                                                                  -0.014624
# Percentage of population at the end of the year...                                          -0.153154
# Percentage of population at the end of the year...                                           0.503538
# Percentage of population at the end of the year...                                           1.000000
# precent count Age 15-44                                                                      0.704206
# number_of_high_schools                                                                      -0.066687
# number_of_bachelor_graduates_in_percent                                                     -0.267294
# number_of_high_school_graduates_in_percent                                                   0.365886
# number_of_high_school_students                                                              -0.027456
# Registration_for_higher_education_within_8_year...                                          -0.154221
# number_of_students_in_percent                                                               -0.159994
# number_of_self_employees                                                                     0.072972
# number_of_employees                                                                          0.002148
# employees_average_monthly_wage                                                              -0.231904
# employees_average_monthly_wage_change_in_percent                                             0.014316
# self_employees_average_monthly_wage                                                         -0.264465
# self_employees_average_monthly_wage_change_in_p...                                           0.008296
#
#                                                     precent count Age 15-44   \
# population                                                         -0.141227
# Percentage of population at the end of the year...                  0.433433
# Percentage of population at the end of the year...                  0.919961
# Percentage of population at the end of the year...                  0.704206
# precent count Age 15-44                                             1.000000
# number_of_high_schools                                             -0.090655
# number_of_bachelor_graduates_in_percent                            -0.449043
# number_of_high_school_graduates_in_percent                          0.402786
# number_of_high_school_students                                     -0.064190
# Registration_for_higher_education_within_8_year...                 -0.229378
# number_of_students_in_percent                                      -0.285987
# number_of_self_employees                                           -0.133743
# number_of_employees                                                -0.182183
# employees_average_monthly_wage                                     -0.399592
# employees_average_monthly_wage_change_in_percent                    0.005759
# self_employees_average_monthly_wage                                -0.329149
# self_employees_average_monthly_wage_change_in_p...                 -0.002754
#
#                                                     number_of_high_schools  \
# population                                                        0.882670
# Percentage of population at the end of the year...               -0.022729
# Percentage of population at the end of the year...               -0.090035
# Percentage of population at the end of the year...               -0.066687
# precent count Age 15-44                                          -0.090655
# number_of_high_schools                                            1.000000
# number_of_bachelor_graduates_in_percent                          -0.089616
# number_of_high_school_graduates_in_percent                       -0.077086
# number_of_high_school_students                                    0.961026
# Registration_for_higher_education_within_8_year...               -0.047674
# number_of_students_in_percent                                    -0.026014
# number_of_self_employees                                          0.673923
# number_of_employees                                               0.769259
# employees_average_monthly_wage                                   -0.019236
# employees_average_monthly_wage_change_in_percent                  0.000034
# self_employees_average_monthly_wage                              -0.014758
# self_employees_average_monthly_wage_change_in_p...                0.000215
#
#                                                     number_of_bachelor_graduates_in_percent  \
# population                                                                        -0.044590
# Percentage of population at the end of the year...                                -0.237441
# Percentage of population at the end of the year...                                -0.428001
# Percentage of population at the end of the year...                                -0.267294
# precent count Age 15-44                                                           -0.449043
# number_of_high_schools                                                            -0.089616
# number_of_bachelor_graduates_in_percent                                            1.000000
# number_of_high_school_graduates_in_percent                                        -0.459242
# number_of_high_school_students                                                    -0.096349
# Registration_for_higher_education_within_8_year...                                 0.361946
# number_of_students_in_percent                                                      0.719637
# number_of_self_employees                                                           0.031188
# number_of_employees                                                               -0.000640
# employees_average_monthly_wage                                                     0.570089
# employees_average_monthly_wage_change_in_percent                                   0.006367
# self_employees_average_monthly_wage                                                0.445886
# self_employees_average_monthly_wage_change_in_p...                                 0.012344
#
#                                                     number_of_high_school_graduates_in_percent  \
# population                                                                            0.008622
# Percentage of population at the end of the year...                                   -0.067819
# Percentage of population at the end of the year...                                    0.436367
# Percentage of population at the end of the year...                                    0.365886
# precent count Age 15-44                                                               0.402786
# number_of_high_schools                                                               -0.077086
# number_of_bachelor_graduates_in_percent                                              -0.459242
# number_of_high_school_graduates_in_percent                                            1.000000
# number_of_high_school_students                                                        0.017318
# Registration_for_higher_education_within_8_year...                                    0.278959
# number_of_students_in_percent                                                        -0.565720
# number_of_self_employees                                                              0.058872
# number_of_employees                                                                   0.025291
# employees_average_monthly_wage                                                        0.121245
# employees_average_monthly_wage_change_in_percent                                     -0.019013
# self_employees_average_monthly_wage                                                   0.091079
# self_employees_average_monthly_wage_change_in_p...                                   -0.026703
#
#                                                     number_of_high_school_students  \
# population                                                                0.951853
# Percentage of population at the end of the year...                       -0.085150
# Percentage of population at the end of the year...                       -0.042173
# Percentage of population at the end of the year...                       -0.027456
# precent count Age 15-44                                                  -0.064190
# number_of_high_schools                                                    0.961026
# number_of_bachelor_graduates_in_percent                                  -0.096349
# number_of_high_school_graduates_in_percent                                0.017318
# number_of_high_school_students                                            1.000000
# Registration_for_higher_education_within_8_year...                       -0.012722
# number_of_students_in_percent                                            -0.062501
# number_of_self_employees                                                  0.770054
# number_of_employees                                                       0.867523
# employees_average_monthly_wage                                            0.014914
# employees_average_monthly_wage_change_in_percent                         -0.013638
# self_employees_average_monthly_wage                                       0.027803
# self_employees_average_monthly_wage_change_in_p...                       -0.014599
#
#                                                     Registration_for_higher_education_within_8_years_in_percent  \
# population                                                                                   0.029342
# Percentage of population at the end of the year...                                          -0.277644
# Percentage of population at the end of the year...                                          -0.121637
# Percentage of population at the end of the year...                                          -0.154221
# precent count Age 15-44                                                                     -0.229378
# number_of_high_schools                                                                      -0.047674
# number_of_bachelor_graduates_in_percent                                                      0.361946
# number_of_high_school_graduates_in_percent                                                   0.278959
# number_of_high_school_students                                                              -0.012722
# Registration_for_higher_education_within_8_year...                                           1.000000
# number_of_students_in_percent                                                                0.092454
# number_of_self_employees                                                                     0.134989
# number_of_employees                                                                          0.073917
# employees_average_monthly_wage                                                               0.827927
# employees_average_monthly_wage_change_in_percent                                            -0.041393
# self_employees_average_monthly_wage                                                          0.706626
# self_employees_average_monthly_wage_change_in_p...                                          -0.041637
#
#                                                     number_of_students_in_percent  \
# population                                                              -0.026193
# Percentage of population at the end of the year...                      -0.078934
# Percentage of population at the end of the year...                      -0.319021
# Percentage of population at the end of the year...                      -0.159994
# precent count Age 15-44                                                 -0.285987
# number_of_high_schools                                                  -0.026014
# number_of_bachelor_graduates_in_percent                                  0.719637
# number_of_high_school_graduates_in_percent                              -0.565720
# number_of_high_school_students                                          -0.062501
# Registration_for_higher_education_within_8_year...                       0.092454
# number_of_students_in_percent                                            1.000000
# number_of_self_employees                                                 0.005762
# number_of_employees                                                     -0.006726
# employees_average_monthly_wage                                           0.163781
# employees_average_monthly_wage_change_in_percent                         0.019089
# self_employees_average_monthly_wage                                      0.134765
# self_employees_average_monthly_wage_change_in_p...                       0.025226
#
#                                                     number_of_self_employees  \
# population                                                          0.905619
# Percentage of population at the end of the year...                 -0.305611
# Percentage of population at the end of the year...                 -0.119898
# Percentage of population at the end of the year...                  0.072972
# precent count Age 15-44                                            -0.133743
# number_of_high_schools                                              0.673923
# number_of_bachelor_graduates_in_percent                             0.031188
# number_of_high_school_graduates_in_percent                          0.058872
# number_of_high_school_students                                      0.770054
# Registration_for_higher_education_within_8_year...                  0.134989
# number_of_students_in_percent                                       0.005762
# number_of_self_employees                                            1.000000
# number_of_employees                                                 0.958023
# employees_average_monthly_wage                                      0.158796
# employees_average_monthly_wage_change_in_percent                    0.029445
# self_employees_average_monthly_wage                                 0.141071
# self_employees_average_monthly_wage_change_in_p...                  0.028282
#
#                                                     number_of_employees  \
# population                                                     0.972841
# Percentage of population at the end of the year...            -0.299233
# Percentage of population at the end of the year...            -0.150747
# Percentage of population at the end of the year...             0.002148
# precent count Age 15-44                                       -0.182183
# number_of_high_schools                                         0.769259
# number_of_bachelor_graduates_in_percent                       -0.000640
# number_of_high_school_graduates_in_percent                     0.025291
# number_of_high_school_students                                 0.867523
# Registration_for_higher_education_within_8_year...             0.073917
# number_of_students_in_percent                                 -0.006726
# number_of_self_employees                                       0.958023
# number_of_employees                                            1.000000
# employees_average_monthly_wage                                 0.111443
# employees_average_monthly_wage_change_in_percent              -0.014290
# self_employees_average_monthly_wage                            0.106304
# self_employees_average_monthly_wage_change_in_p...            -0.015361
#
#                                                     employees_average_monthly_wage  \
# population                                                                0.059808
# Percentage of population at the end of the year...                       -0.397868
# Percentage of population at the end of the year...                       -0.285990
# Percentage of population at the end of the year...                       -0.231904
# precent count Age 15-44                                                  -0.399592
# number_of_high_schools                                                   -0.019236
# number_of_bachelor_graduates_in_percent                                   0.570089
# number_of_high_school_graduates_in_percent                                0.121245
# number_of_high_school_students                                            0.014914
# Registration_for_higher_education_within_8_year...                        0.827927
# number_of_students_in_percent                                             0.163781
# number_of_self_employees                                                  0.158796
# number_of_employees                                                       0.111443
# employees_average_monthly_wage                                            1.000000
# employees_average_monthly_wage_change_in_percent                         -0.060822
# self_employees_average_monthly_wage                                       0.829152
# self_employees_average_monthly_wage_change_in_p...                       -0.059436
#
#                                                     employees_average_monthly_wage_change_in_percent  \
# population                                                                                 -0.014116
# Percentage of population at the end of the year...                                          0.023695
# Percentage of population at the end of the year...                                         -0.013915
# Percentage of population at the end of the year...                                          0.014316
# precent count Age 15-44                                                                     0.005759
# number_of_high_schools                                                                      0.000034
# number_of_bachelor_graduates_in_percent                                                     0.006367
# number_of_high_school_graduates_in_percent                                                 -0.019013
# number_of_high_school_students                                                             -0.013638
# Registration_for_higher_education_within_8_year...                                         -0.041393
# number_of_students_in_percent                                                               0.019089
# number_of_self_employees                                                                    0.029445
# number_of_employees                                                                        -0.014290
# employees_average_monthly_wage                                                             -0.060822
# employees_average_monthly_wage_change_in_percent                                            1.000000
# self_employees_average_monthly_wage                                                        -0.091326
# self_employees_average_monthly_wage_change_in_p...                                          0.999044
#
#                                                     self_employees_average_monthly_wage  \
# population                                                                     0.063074
# Percentage of population at the end of the year...                            -0.231031
# Percentage of population at the end of the year...                            -0.230499
# Percentage of population at the end of the year...                            -0.264465
# precent count Age 15-44                                                       -0.329149
# number_of_high_schools                                                        -0.014758
# number_of_bachelor_graduates_in_percent                                        0.445886
# number_of_high_school_graduates_in_percent                                     0.091079
# number_of_high_school_students                                                 0.027803
# Registration_for_higher_education_within_8_year...                             0.706626
# number_of_students_in_percent                                                  0.134765
# number_of_self_employees                                                       0.141071
# number_of_employees                                                            0.106304
# employees_average_monthly_wage                                                 0.829152
# employees_average_monthly_wage_change_in_percent                              -0.091326
# self_employees_average_monthly_wage                                            1.000000
# self_employees_average_monthly_wage_change_in_p...                            -0.088592
#
#                                                     self_employees_average_monthly_wage_change_in_percent
# population                                                                                  -0.015098
# Percentage of population at the end of the year...                                           0.022921
# Percentage of population at the end of the year...                                          -0.023282
# Percentage of population at the end of the year...                                           0.008296
# precent count Age 15-44                                                                     -0.002754
# number_of_high_schools                                                                       0.000215
# number_of_bachelor_graduates_in_percent                                                      0.012344
# number_of_high_school_graduates_in_percent                                                  -0.026703
# number_of_high_school_students                                                              -0.014599
# Registration_for_higher_education_within_8_year...                                          -0.041637
# number_of_students_in_percent                                                                0.025226
# number_of_self_employees                                                                     0.028282
# number_of_employees                                                                         -0.015361
# employees_average_monthly_wage                                                              -0.059436
# employees_average_monthly_wage_change_in_percent                                             0.999044
# self_employees_average_monthly_wage                                                         -0.088592
# self_employees_average_monthly_wage_change_in_p...                                           1.000000

# %%
# Out:
# R2: 0.5900176076939934
# R2: 0.5900176076939934

# %%
# def sse(Y, Y_HAT):  
#     sse = sum([(y - y_hat)**2 for y,y_hat in zip(Y, Y_HAT)])
#     return sse

# print(final_DataFrame.iloc[:,0:1])
# SSE = sse(final_DataFrame.number_of_students_in_percent.tolist(),m.predict(df_test.iloc[:,0:1]).flatten())

# print(SSE)
# Out:
#                                                         year  population  \
# year                                                1.000000   -0.061111
# population                                         -0.061111    1.000000
# Percentage of population at the end of the year... -0.072305    0.957705
# Percentage of population at the end of the year...  0.080362    0.927924
# Percentage of population at the end of the year...  0.016768    0.970436
# precent count Age 15-44                             0.018015    0.977690
# number_of_high_schools                             -0.046849    0.909857
# number_of_bachelor_graduates_in_percent            -0.181059    0.868109
# number_of_high_school_graduates_in_percent          0.157593    0.858997
# number_of_high_school_students                     -0.056666    0.955238
# Registration_for_higher_education_within_8_year...  0.034871    0.864781
# number_of_students_in_percent                      -0.210976    0.834258
# number_of_self_employees                           -0.000853    0.901801
# number_of_employees                                -0.053654    0.971994
# employees_average_monthly_wage                      0.107812    0.124395
# employees_average_monthly_wage_change_in_percent   -0.085848    0.795498
# self_employees_average_monthly_wage                 0.051471    0.122542
# self_employees_average_monthly_wage_change_in_p... -0.291445    0.685466
#
#                                                     Percentage of population at the end of the year aged 19-15  \
# year                                                                                        -0.072305
# population                                                                                   0.957705
# Percentage of population at the end of the year...                                           1.000000
# Percentage of population at the end of the year...                                           0.922222
# Percentage of population at the end of the year...                                           0.903853
# precent count Age 15-44                                                                      0.954230
# number_of_high_schools                                                                       0.977378
# number_of_bachelor_graduates_in_percent                                                      0.734170
# number_of_high_school_graduates_in_percent                                                   0.778509
# number_of_high_school_students                                                               0.992327
# Registration_for_higher_education_within_8_year...                                           0.717225
# number_of_students_in_percent                                                                0.727796
# number_of_self_employees                                                                     0.761114
# number_of_employees                                                                          0.867937
# employees_average_monthly_wage                                                               0.033772
# employees_average_monthly_wage_change_in_percent                                             0.750062
# self_employees_average_monthly_wage                                                          0.046994
# self_employees_average_monthly_wage_change_in_p...                                           0.669939
#
#                                                     Percentage of population at the end of the year aged 20-29  \
# year                                                                                         0.080362
# population                                                                                   0.927924
# Percentage of population at the end of the year...                                           0.922222
# Percentage of population at the end of the year...                                           1.000000
# Percentage of population at the end of the year...                                           0.940401
# precent count Age 15-44                                                                      0.979407
# number_of_high_schools                                                                       0.908151
# number_of_bachelor_graduates_in_percent                                                      0.699947
# number_of_high_school_graduates_in_percent                                                   0.856929
# number_of_high_school_students                                                               0.928127
# Registration_for_higher_education_within_8_year...                                           0.772481
# number_of_students_in_percent                                                                0.660587
# number_of_self_employees                                                                     0.826654
# number_of_employees                                                                          0.874398
# employees_average_monthly_wage                                                               0.063648
# employees_average_monthly_wage_change_in_percent                                             0.653615
# self_employees_average_monthly_wage                                                          0.062590
# self_employees_average_monthly_wage_change_in_p...                                           0.446234
#
#                                                     Percentage of population at the end of the year aged 30-44  \
# year                                                                                         0.016768
# population                                                                                   0.970436
# Percentage of population at the end of the year...                                           0.903853
# Percentage of population at the end of the year...                                           0.940401
# Percentage of population at the end of the year...                                           1.000000
# precent count Age 15-44                                                                      0.983446
# number_of_high_schools                                                                       0.862137
# number_of_bachelor_graduates_in_percent                                                      0.841992
# number_of_high_school_graduates_in_percent                                                   0.894301
# number_of_high_school_students                                                               0.906460
# Registration_for_higher_education_within_8_year...                                           0.885859
# number_of_students_in_percent                                                                0.792976
# number_of_self_employees                                                                     0.937864
# number_of_employees                                                                          0.959652
# employees_average_monthly_wage                                                               0.135060
# employees_average_monthly_wage_change_in_percent                                             0.751812
# self_employees_average_monthly_wage                                                          0.126275
# self_employees_average_monthly_wage_change_in_p...                                           0.605638
#
#                                                     precent count Age 15-44   \
# year                                                                0.018015
# population                                                          0.977690
# Percentage of population at the end of the year...                  0.954230
# Percentage of population at the end of the year...                  0.979407
# Percentage of population at the end of the year...                  0.983446
# precent count Age 15-44                                             1.000000
# number_of_high_schools                                              0.924934
# number_of_bachelor_graduates_in_percent                             0.791618
# number_of_high_school_graduates_in_percent                          0.878005
# number_of_high_school_students                                      0.955663
# Registration_for_higher_education_within_8_year...                  0.832271
# number_of_students_in_percent                                       0.754232
# number_of_self_employees                                            0.884448
# number_of_employees                                                 0.934621
# employees_average_monthly_wage                                      0.091884
# employees_average_monthly_wage_change_in_percent                    0.737710
# self_employees_average_monthly_wage                                 0.090419
# self_employees_average_monthly_wage_change_in_p...                  0.582638
#
#                                                     number_of_high_schools  \
# year                                                             -0.046849
# population                                                        0.909857
# Percentage of population at the end of the year...                0.977378
# Percentage of population at the end of the year...                0.908151
# Percentage of population at the end of the year...                0.862137
# precent count Age 15-44                                           0.924934
# number_of_high_schools                                            1.000000
# number_of_bachelor_graduates_in_percent                           0.631939
# number_of_high_school_graduates_in_percent                        0.723511
# number_of_high_school_students                                    0.982327
# Registration_for_higher_education_within_8_year...                0.639465
# number_of_students_in_percent                                     0.648813
# number_of_self_employees                                          0.691207
# number_of_employees                                               0.795157
# employees_average_monthly_wage                                   -0.025807
# employees_average_monthly_wage_change_in_percent                  0.700809
# self_employees_average_monthly_wage                              -0.027692
# self_employees_average_monthly_wage_change_in_p...                0.603078
#
#                                                     number_of_bachelor_graduates_in_percent  \
# year                                                                              -0.181059
# population                                                                         0.868109
# Percentage of population at the end of the year...                                 0.734170
# Percentage of population at the end of the year...                                 0.699947
# Percentage of population at the end of the year...                                 0.841992
# precent count Age 15-44                                                            0.791618
# number_of_high_schools                                                             0.631939
# number_of_bachelor_graduates_in_percent                                            1.000000
# number_of_high_school_graduates_in_percent                                         0.674339
# number_of_high_school_students                                                     0.722594
# Registration_for_higher_education_within_8_year...                                 0.865664
# number_of_students_in_percent                                                      0.955793
# number_of_self_employees                                                           0.898676
# number_of_employees                                                                0.924259
# employees_average_monthly_wage                                                     0.285196
# employees_average_monthly_wage_change_in_percent                                   0.708517
# self_employees_average_monthly_wage                                                0.267764
# self_employees_average_monthly_wage_change_in_p...                                 0.698069
#
#                                                     number_of_high_school_graduates_in_percent  \
# year                                                                                  0.157593
# population                                                                            0.858997
# Percentage of population at the end of the year...                                    0.778509
# Percentage of population at the end of the year...                                    0.856929
# Percentage of population at the end of the year...                                    0.894301
# precent count Age 15-44                                                               0.878005
# number_of_high_schools                                                                0.723511
# number_of_bachelor_graduates_in_percent                                               0.674339
# number_of_high_school_graduates_in_percent                                            1.000000
# number_of_high_school_students                                                        0.785076
# Registration_for_higher_education_within_8_year...                                    0.878985
# number_of_students_in_percent                                                         0.557818
# number_of_self_employees                                                              0.862551
# number_of_employees                                                                   0.872196
# employees_average_monthly_wage                                                        0.195724
# employees_average_monthly_wage_change_in_percent                                      0.648806
# self_employees_average_monthly_wage                                                   0.190401
# self_employees_average_monthly_wage_change_in_p...                                    0.448437
#
#                                                     number_of_high_school_students  \
# year                                                                     -0.056666
# population                                                                0.955238
# Percentage of population at the end of the year...                        0.992327
# Percentage of population at the end of the year...                        0.928127
# Percentage of population at the end of the year...                        0.906460
# precent count Age 15-44                                                   0.955663
# number_of_high_schools                                                    0.982327
# number_of_bachelor_graduates_in_percent                                   0.722594
# number_of_high_school_graduates_in_percent                                0.785076
# number_of_high_school_students                                            1.000000
# Registration_for_higher_education_within_8_year...                        0.723887
# number_of_students_in_percent                                             0.716852
# number_of_self_employees                                                  0.762943
# number_of_employees                                                       0.866320
# employees_average_monthly_wage                                            0.037476
# employees_average_monthly_wage_change_in_percent                          0.743907
# self_employees_average_monthly_wage                                       0.046485
# self_employees_average_monthly_wage_change_in_p...                        0.646375
#
#                                                     Registration_for_higher_education_within_8_years_in_percent  \
# year                                                                                         0.034871
# population                                                                                   0.864781
# Percentage of population at the end of the year...                                           0.717225
# Percentage of population at the end of the year...                                           0.772481
# Percentage of population at the end of the year...                                           0.885859
# precent count Age 15-44                                                                      0.832271
# number_of_high_schools                                                                       0.639465
# number_of_bachelor_graduates_in_percent                                                      0.865664
# number_of_high_school_graduates_in_percent                                                   0.878985
# number_of_high_school_students                                                               0.723887
# Registration_for_higher_education_within_8_year...                                           1.000000
# number_of_students_in_percent                                                                0.783239
# number_of_self_employees                                                                     0.958670
# number_of_employees                                                                          0.928227
# employees_average_monthly_wage                                                               0.341490
# employees_average_monthly_wage_change_in_percent                                             0.703253
# self_employees_average_monthly_wage                                                          0.317767
# self_employees_average_monthly_wage_change_in_p...                                           0.540114
#
#                                                     number_of_students_in_percent  \
# year                                                                    -0.210976
# population                                                               0.834258
# Percentage of population at the end of the year...                       0.727796
# Percentage of population at the end of the year...                       0.660587
# Percentage of population at the end of the year...                       0.792976
# precent count Age 15-44                                                  0.754232
# number_of_high_schools                                                   0.648813
# number_of_bachelor_graduates_in_percent                                  0.955793
# number_of_high_school_graduates_in_percent                               0.557818
# number_of_high_school_students                                           0.716852
# Registration_for_higher_education_within_8_year...                       0.783239
# number_of_students_in_percent                                            1.000000
# number_of_self_employees                                                 0.822655
# number_of_employees                                                      0.862872
# employees_average_monthly_wage                                           0.177402
# employees_average_monthly_wage_change_in_percent                         0.691493
# self_employees_average_monthly_wage                                      0.173542
# self_employees_average_monthly_wage_change_in_p...                       0.720745
#
#                                                     number_of_self_employees  \
# year                                                               -0.000853
# population                                                          0.901801
# Percentage of population at the end of the year...                  0.761114
# Percentage of population at the end of the year...                  0.826654
# Percentage of population at the end of the year...                  0.937864
# precent count Age 15-44                                             0.884448
# number_of_high_schools                                              0.691207
# number_of_bachelor_graduates_in_percent                             0.898676
# number_of_high_school_graduates_in_percent                          0.862551
# number_of_high_school_students                                      0.762943
# Registration_for_higher_education_within_8_year...                  0.958670
# number_of_students_in_percent                                       0.822655
# number_of_self_employees                                            1.000000
# number_of_employees                                                 0.956671
# employees_average_monthly_wage                                      0.251081
# employees_average_monthly_wage_change_in_percent                    0.715900
# self_employees_average_monthly_wage                                 0.233860
# self_employees_average_monthly_wage_change_in_p...                  0.550670
#
#                                                     number_of_employees  \
# year                                                          -0.053654
# population                                                     0.971994
# Percentage of population at the end of the year...             0.867937
# Percentage of population at the end of the year...             0.874398
# Percentage of population at the end of the year...             0.959652
# precent count Age 15-44                                        0.934621
# number_of_high_schools                                         0.795157
# number_of_bachelor_graduates_in_percent                        0.924259
# number_of_high_school_graduates_in_percent                     0.872196
# number_of_high_school_students                                 0.866320
# Registration_for_higher_education_within_8_year...             0.928227
# number_of_students_in_percent                                  0.862872
# number_of_self_employees                                       0.956671
# number_of_employees                                            1.000000
# employees_average_monthly_wage                                 0.192179
# employees_average_monthly_wage_change_in_percent               0.790122
# self_employees_average_monthly_wage                            0.182853
# self_employees_average_monthly_wage_change_in_p...             0.659345
#
#                                                     employees_average_monthly_wage  \
# year                                                                      0.107812
# population                                                                0.124395
# Percentage of population at the end of the year...                        0.033772
# Percentage of population at the end of the year...                        0.063648
# Percentage of population at the end of the year...                        0.135060
# precent count Age 15-44                                                   0.091884
# number_of_high_schools                                                   -0.025807
# number_of_bachelor_graduates_in_percent                                   0.285196
# number_of_high_school_graduates_in_percent                                0.195724
# number_of_high_school_students                                            0.037476
# Registration_for_higher_education_within_8_year...                        0.341490
# number_of_students_in_percent                                             0.177402
# number_of_self_employees                                                  0.251081
# number_of_employees                                                       0.192179
# employees_average_monthly_wage                                            1.000000
# employees_average_monthly_wage_change_in_percent                          0.072664
# self_employees_average_monthly_wage                                       0.807112
# self_employees_average_monthly_wage_change_in_p...                        0.081441
#
#                                                     employees_average_monthly_wage_change_in_percent  \
# year                                                                                       -0.085848
# population                                                                                  0.795498
# Percentage of population at the end of the year...                                          0.750062
# Percentage of population at the end of the year...                                          0.653615
# Percentage of population at the end of the year...                                          0.751812
# precent count Age 15-44                                                                     0.737710
# number_of_high_schools                                                                      0.700809
# number_of_bachelor_graduates_in_percent                                                     0.708517
# number_of_high_school_graduates_in_percent                                                  0.648806
# number_of_high_school_students                                                              0.743907
# Registration_for_higher_education_within_8_year...                                          0.703253
# number_of_students_in_percent                                                               0.691493
# number_of_self_employees                                                                    0.715900
# number_of_employees                                                                         0.790122
# employees_average_monthly_wage                                                              0.072664
# employees_average_monthly_wage_change_in_percent                                            1.000000
# self_employees_average_monthly_wage                                                         0.095511
# self_employees_average_monthly_wage_change_in_p...                                          0.743222
#
#                                                     self_employees_average_monthly_wage  \
# year                                                                           0.051471
# population                                                                     0.122542
# Percentage of population at the end of the year...                             0.046994
# Percentage of population at the end of the year...                             0.062590
# Percentage of population at the end of the year...                             0.126275
# precent count Age 15-44                                                        0.090419
# number_of_high_schools                                                        -0.027692
# number_of_bachelor_graduates_in_percent                                        0.267764
# number_of_high_school_graduates_in_percent                                     0.190401
# number_of_high_school_students                                                 0.046485
# Registration_for_higher_education_within_8_year...                             0.317767
# number_of_students_in_percent                                                  0.173542
# number_of_self_employees                                                       0.233860
# number_of_employees                                                            0.182853
# employees_average_monthly_wage                                                 0.807112
# employees_average_monthly_wage_change_in_percent                               0.095511
# self_employees_average_monthly_wage                                            1.000000
# self_employees_average_monthly_wage_change_in_p...                             0.105304
#
#                                                     self_employees_average_monthly_wage_change_in_percent
# year                                                                                        -0.291445
# population                                                                                   0.685466
# Percentage of population at the end of the year...                                           0.669939
# Percentage of population at the end of the year...                                           0.446234
# Percentage of population at the end of the year...                                           0.605638
# precent count Age 15-44                                                                      0.582638
# number_of_high_schools                                                                       0.603078
# number_of_bachelor_graduates_in_percent                                                      0.698069
# number_of_high_school_graduates_in_percent                                                   0.448437
# number_of_high_school_students                                                               0.646375
# Registration_for_higher_education_within_8_year...                                           0.540114
# number_of_students_in_percent                                                                0.720745
# number_of_self_employees                                                                     0.550670
# number_of_employees                                                                          0.659345
# employees_average_monthly_wage                                                               0.081441
# employees_average_monthly_wage_change_in_percent                                             0.743222
# self_employees_average_monthly_wage                                                          0.105304
# self_employees_average_monthly_wage_change_in_p...                                           1.000000

# %%
final_DataFrame = pd.read_csv('data/finalDataFrame.csv')
# final_DataFrame.drop([2,3,4,6,])


# tempValue=-9999999999
# final_DataFrame = final_DataFrame.drop(columns=['city'])


# final_DataFrame = final_DataFrame.replace( '..', tempValue )
# final_DataFrame = final_DataFrame.replace( 'NaN', tempValue )
# final_DataFrame = final_DataFrame.replace( '-', tempValue )
# final_DataFrame = final_DataFrame.astype(float)
# final_DataFrame = final_DataFrame.replace( tempValue, np.nan)

# for column in final_DataFrame:
#     #Finding the mean of the column having NaN
#     mean_value=final_DataFrame[column].mean() 
#     final_DataFrame[column].fillna(value=mean_value, inplace=True)
# final_DataFrame


final_DataFrame = final_DataFrame.replace( '..', np.nan )
final_DataFrame = final_DataFrame.replace( 'NaN', np.nan )
final_DataFrame = final_DataFrame.replace( '-', np.nan )
final_DataFrame = final_DataFrame.drop(columns=['city'])
#final_DataFrame = final_DataFrame.filter(columns_names,axis=1)
final_DataFrame = final_DataFrame.dropna()
final_DataFrame = final_DataFrame.astype(float)
final_DataFrame



final_DataFrame.iloc[:,2]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,2]/100))
final_DataFrame.iloc[:,3]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,3]/100))
final_DataFrame.iloc[:,4]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,4]/100))
final_DataFrame.iloc[:,5]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,5]/100))

final_DataFrame.iloc[:,7]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,7]/100))
final_DataFrame.iloc[:,8]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,8]/100))
final_DataFrame.iloc[:,10]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,10]/100))
final_DataFrame.iloc[:,11]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,11]/100))
final_DataFrame.iloc[:,15]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,15]/100))
final_DataFrame.iloc[:,17]=((final_DataFrame.iloc[:,1])*(final_DataFrame.iloc[:,17]/100))
final_DataFrame = final_DataFrame.astype(int)


final_DataFrame.columns = final_DataFrame.columns.str.replace('precent count Age 15-44', 'precent_count_Age')



final_DataFrame
# Out:
#      year  population  \
# 1    2019       14099
# 2    2019       13826
# 3    2019       56109
# 4    2019       30662
# 5    2019       36813
# ..    ...         ...
# 793  2016       71700
# 796  2016       24000
# 800  2016       40500
# 801  2016      438800
# 803  2016       19200
#
#      Percentage of population at the end of the year aged 19-15  \
# 1                                                 1428
# 2                                                 1158
# 3                                                 6368
# 4                                                 2121
# 5                                                 2598
# ..                                                 ...
# 793                                               5520
# 796                                               1440
# 800                                               4090
# 801                                              21062
# 803                                               2880
#
#      Percentage of population at the end of the year aged 20-29  \
# 1                                                 2509
# 2                                                 1331
# 3                                                10206
# 4                                                 5068
# 5                                                 5190
# ..                                                 ...
# 793                                               5090
# 796                                               1752
# 800                                               4171
# 801                                              18429
# 803                                               2476
#
#      Percentage of population at the end of the year aged 30-44  \
# 1                                                 2863
# 2                                                 2474
# 3                                                10049
# 4                                                 5589
# 5                                                 7443
# ..                                                 ...
# 793                                               8819
# 796                                               4392
# 800                                               6682
# 801                                              62309
# 803                                               3110
#
#      precent_count_Age   number_of_high_schools  \
# 1                  6801                       3
# 2                  4964                       3
# 3                 26623                      13
# 4                 12779                      11
# 5                 15233                       7
# ..                  ...                     ...
# 793               19430                      14
# 796                7584                       4
# 800               14944                       9
# 801              101801                      64
# 803                8467                       5
#
#      number_of_bachelor_graduates_in_percent  \
# 1                                       1704
# 2                                       7685
# 3                                       4780
# 4                                       3759
# 5                                       5065
# ..                                       ...
# 793                                    58292
# 796                                    14688
# 800                                    16686
# 801                                   286975
# 803                                     4972
#
#      number_of_high_school_graduates_in_percent  \
# 1                                          9278
# 2                                         11608
# 3                                         33328
# 4                                         15404
# 5                                         26619
# ..                                          ...
# 793                                       18362
# 796                                        4615
# 800                                       10169
# 801                                      100353
# 803                                        4992
#
#      number_of_high_school_students  \
# 1                               592
# 2                              1087
# 3                              3838
# 4                              1551
# 5                              1244
# ..                              ...
# 793                            3637
# 796                             577
# 800                            2385
# 801                           13037
# 803                            1120
#
#      Registration_for_higher_education_within_8_years_in_percent  \
# 1                                                 4018
# 2                                                 6373
# 3                                                13073
# 4                                                 8156
# 5                                                14909
# ..                                                 ...
# 793                                              30329
# 796                                               3528
# 800                                               3928
# 801                                             180346
# 803                                               1209
#
#      number_of_students_in_percent  number_of_self_employees  \
# 1                              327                       626
# 2                              418                       899
# 3                             1183                      1918
# 4                              564                       295
# 5                              850                      1920
# ..                             ...                       ...
# 793                          12977                      3471
# 796                           3120                       634
# 800                           4819                      1161
# 801                          91270                     24447
# 803                           1440                       149
#
#      number_of_employees  employees_average_monthly_wage  \
# 1                   5841                            7071
# 2                   6265                           14054
# 3                  22149                            5869
# 4                   3342                            9398
# 5                  18941                            8953
# ..                   ...                             ...
# 793                32884                           12299
# 796                12417                            7201
# 800                16307                            6236
# 801               223935                           11017
# 803                 4543                            4983
#
#      employees_average_monthly_wage_change_in_percent  \
# 1                                                 274
# 2                                                 218
# 3                                                 650
# 4                                                 116
# 5                                                1689
# ..                                                ...
# 793                                               788
# 796                                               936
# 800                                               810
# 801                                             10970
# 803                                              -280
#
#      self_employees_average_monthly_wage  \
# 1                                   8456
# 2                                  12517
# 3                                   8883
# 4                                  11301
# 5                                  10284
# ..                                   ...
# 793                                13040
# 796                                 9693
# 800                                 8996
# 801                                11908
# 803                                11631
#
#      self_employees_average_monthly_wage_change_in_percent
# 1                                                 -105
# 2                                                 -237
# 3                                                 -465
# 4                                                 -401
# 5                                                  419
# ..                                                 ...
# 793                                              -1233
# 796                                               1665
# 800                                               2344
# 801                                              10618
# 803                                                168
#
# [542 rows x 18 columns]

# %%
from sklearn import linear_model
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
number_of_students='number_of_students_in_percent'

employees_average_monthly_wage_change_in_percent='employees_average_monthly_wage_change_in_percent'
self_employees_average_monthly_wage_change_in_percent='self_employees_average_monthly_wage_change_in_percent'
number_of_bachelor_graduates_in_percent='number_of_bachelor_graduates_in_percent'
number_of_high_school_graduates_in_percent='number_of_high_school_graduates_in_percent'
Registration_for_higher_education_within_8_years_in_percent='Registration_for_higher_education_within_8_years_in_percent'
precent_count_Age='precent_count_Age'

lr = linear_model.LinearRegression() # create a linear regression object
y = final_DataFrame[[number_of_students]].values.reshape(final_DataFrame[number_of_students].shape[0],1)

print(final_DataFrame)
generateGragh(employees_average_monthly_wage_change_in_percent,'r','tomato')
generateGragh(self_employees_average_monthly_wage_change_in_percent,'yellow','y')
generateGragh(number_of_bachelor_graduates_in_percent,'blue','darkblue')
generateGragh(number_of_high_school_graduates_in_percent,'green','lime')
generateGragh(Registration_for_higher_education_within_8_years_in_percent,'c','aqua')
# generateGragh(precent_count_Age,'b','b')

#take all columns for next blocks
# x = final_DataFrame[['number_of_bachelor_graduates_in_percent', 'number_of_high_school_graduates_in_percent', 'Registration_for_higher_education_within_8_years_in_percent']]#plt.scatter(x=x,y=y,c='b',marker='s',label='all')
x = final_DataFrame[['employees_average_monthly_wage_change_in_percent', 'self_employees_average_monthly_wage_change_in_percent','number_of_bachelor_graduates_in_percent', 'number_of_high_school_graduates_in_percent', 'Registration_for_higher_education_within_8_years_in_percent']]

m = lr.fit(X=x, y=y);

plt.xlabel('Referance columns')
plt.ylabel('number_of_students')
plt.show()
# Out:
#      year  population  \
# 1    2019       14099
# 2    2019       13826
# 3    2019       56109
# 4    2019       30662
# 5    2019       36813
# ..    ...         ...
# 793  2016       71700
# 796  2016       24000
# 800  2016       40500
# 801  2016      438800
# 803  2016       19200
#
#      Percentage of population at the end of the year aged 19-15  \
# 1                                                 1428
# 2                                                 1158
# 3                                                 6368
# 4                                                 2121
# 5                                                 2598
# ..                                                 ...
# 793                                               5520
# 796                                               1440
# 800                                               4090
# 801                                              21062
# 803                                               2880
#
#      Percentage of population at the end of the year aged 20-29  \
# 1                                                 2509
# 2                                                 1331
# 3                                                10206
# 4                                                 5068
# 5                                                 5190
# ..                                                 ...
# 793                                               5090
# 796                                               1752
# 800                                               4171
# 801                                              18429
# 803                                               2476
#
#      Percentage of population at the end of the year aged 30-44  \
# 1                                                 2863
# 2                                                 2474
# 3                                                10049
# 4                                                 5589
# 5                                                 7443
# ..                                                 ...
# 793                                               8819
# 796                                               4392
# 800                                               6682
# 801                                              62309
# 803                                               3110
#
#      precent_count_Age   number_of_high_schools  \
# 1                  6801                       3
# 2                  4964                       3
# 3                 26623                      13
# 4                 12779                      11
# 5                 15233                       7
# ..                  ...                     ...
# 793               19430                      14
# 796                7584                       4
# 800               14944                       9
# 801              101801                      64
# 803                8467                       5
#
#      number_of_bachelor_graduates_in_percent  \
# 1                                       1704
# 2                                       7685
# 3                                       4780
# 4                                       3759
# 5                                       5065
# ..                                       ...
# 793                                    58292
# 796                                    14688
# 800                                    16686
# 801                                   286975
# 803                                     4972
#
#      number_of_high_school_graduates_in_percent  \
# 1                                          9278
# 2                                         11608
# 3                                         33328
# 4                                         15404
# 5                                         26619
# ..                                          ...
# 793                                       18362
# 796                                        4615
# 800                                       10169
# 801                                      100353
# 803                                        4992
#
#      number_of_high_school_students  \
# 1                               592
# 2                              1087
# 3                              3838
# 4                              1551
# 5                              1244
# ..                              ...
# 793                            3637
# 796                             577
# 800                            2385
# 801                           13037
# 803                            1120
#
#      Registration_for_higher_education_within_8_years_in_percent  \
# 1                                                 4018
# 2                                                 6373
# 3                                                13073
# 4                                                 8156
# 5                                                14909
# ..                                                 ...
# 793                                              30329
# 796                                               3528
# 800                                               3928
# 801                                             180346
# 803                                               1209
#
#      number_of_students_in_percent  number_of_self_employees  \
# 1                              327                       626
# 2                              418                       899
# 3                             1183                      1918
# 4                              564                       295
# 5                              850                      1920
# ..                             ...                       ...
# 793                          12977                      3471
# 796                           3120                       634
# 800                           4819                      1161
# 801                          91270                     24447
# 803                           1440                       149
#
#      number_of_employees  employees_average_monthly_wage  \
# 1                   5841                            7071
# 2                   6265                           14054
# 3                  22149                            5869
# 4                   3342                            9398
# 5                  18941                            8953
# ..                   ...                             ...
# 793                32884                           12299
# 796                12417                            7201
# 800                16307                            6236
# 801               223935                           11017
# 803                 4543                            4983
#
#      employees_average_monthly_wage_change_in_percent  \
# 1                                                 274
# 2                                                 218
# 3                                                 650
# 4                                                 116
# 5                                                1689
# ..                                                ...
# 793                                               788
# 796                                               936
# 800                                               810
# 801                                             10970
# 803                                              -280
#
#      self_employees_average_monthly_wage  \
# 1                                   8456
# 2                                  12517
# 3                                   8883
# 4                                  11301
# 5                                  10284
# ..                                   ...
# 793                                13040
# 796                                 9693
# 800                                 8996
# 801                                11908
# 803                                11631
#
#      self_employees_average_monthly_wage_change_in_percent
# 1                                                 -105
# 2                                                 -237
# 3                                                 -465
# 4                                                 -401
# 5                                                  419
# ..                                                 ...
# 793                                              -1233
# 796                                               1665
# 800                                               2344
# 801                                              10618
# 803                                                168
#
# [542 rows x 18 columns]

# %%
print("R2:",lr.score(x,y))
print("R2:",r2_score(y,lr.predict(x)))
# Out:
# R2: 0.9336045571609072
# R2: 0.9336045571609072

# %%
print(final_DataFrame.corr())
pd.plotting.scatter_matrix(final_DataFrame, figsize=(20, 20), diagonal='kde')
plt.show()
# Out:
#                                                         year  population  \
# year                                                1.000000    0.009800
# population                                          0.009800    1.000000
# Percentage of population at the end of the year... -0.006243    0.960054
# Percentage of population at the end of the year...  0.118229    0.931944
# Percentage of population at the end of the year...  0.069728    0.972293
# precent_count_Age                                   0.070161    0.979035
# number_of_high_schools                             -0.048114    0.885549
# number_of_bachelor_graduates_in_percent            -0.088627    0.876932
# number_of_high_school_graduates_in_percent          0.189092    0.868332
# number_of_high_school_students                      0.032552    0.951853
# Registration_for_higher_education_within_8_year...  0.081039    0.872937
# number_of_students_in_percent                      -0.126787    0.841750
# number_of_self_employees                            0.055068    0.905619
# number_of_employees                                 0.020720    0.972841
# employees_average_monthly_wage                      0.098796    0.059819
# employees_average_monthly_wage_change_in_percent   -0.050586    0.207157
# self_employees_average_monthly_wage                 0.063893    0.063083
# self_employees_average_monthly_wage_change_in_p... -0.105739    0.189246
#
#                                                     Percentage of population at the end of the year aged 19-15  \
# year                                                                                        -0.006243
# population                                                                                   0.960054
# Percentage of population at the end of the year...                                           1.000000
# Percentage of population at the end of the year...                                           0.926488
# Percentage of population at the end of the year...                                           0.909498
# precent_count_Age                                                                            0.956859
# number_of_high_schools                                                                       0.955150
# number_of_bachelor_graduates_in_percent                                                      0.750732
# number_of_high_school_graduates_in_percent                                                   0.791894
# number_of_high_school_students                                                               0.987343
# Registration_for_higher_education_within_8_year...                                           0.733805
# number_of_students_in_percent                                                                0.740887
# number_of_self_employees                                                                     0.773129
# number_of_employees                                                                          0.874999
# employees_average_monthly_wage                                                              -0.003680
# employees_average_monthly_wage_change_in_percent                                             0.196771
# self_employees_average_monthly_wage                                                          0.015181
# self_employees_average_monthly_wage_change_in_p...                                           0.186450
#
#                                                     Percentage of population at the end of the year aged 20-29  \
# year                                                                                         0.118229
# population                                                                                   0.931944
# Percentage of population at the end of the year...                                           0.926488
# Percentage of population at the end of the year...                                           1.000000
# Percentage of population at the end of the year...                                           0.943775
# precent_count_Age                                                                            0.980494
# number_of_high_schools                                                                       0.888572
# number_of_bachelor_graduates_in_percent                                                      0.717790
# number_of_high_school_graduates_in_percent                                                   0.865407
# number_of_high_school_students                                                               0.927845
# Registration_for_higher_education_within_8_year...                                           0.785033
# number_of_students_in_percent                                                                0.676552
# number_of_self_employees                                                                     0.834542
# number_of_employees                                                                          0.880754
# employees_average_monthly_wage                                                               0.017773
# employees_average_monthly_wage_change_in_percent                                             0.171711
# self_employees_average_monthly_wage                                                          0.024467
# self_employees_average_monthly_wage_change_in_p...                                           0.124097
#
#                                                     Percentage of population at the end of the year aged 30-44  \
# year                                                                                         0.069728
# population                                                                                   0.972293
# Percentage of population at the end of the year...                                           0.909498
# Percentage of population at the end of the year...                                           0.943775
# Percentage of population at the end of the year...                                           1.000000
# precent_count_Age                                                                            0.984480
# number_of_high_schools                                                                       0.841284
# number_of_bachelor_graduates_in_percent                                                      0.851853
# number_of_high_school_graduates_in_percent                                                   0.901014
# number_of_high_school_students                                                               0.906620
# Registration_for_higher_education_within_8_year...                                           0.892003
# number_of_students_in_percent                                                                0.802703
# number_of_self_employees                                                                     0.939169
# number_of_employees                                                                          0.961024
# employees_average_monthly_wage                                                               0.065353
# employees_average_monthly_wage_change_in_percent                                             0.196672
# self_employees_average_monthly_wage                                                          0.062915
# self_employees_average_monthly_wage_change_in_p...                                           0.167896
#
#                                                     precent_count_Age   \
# year                                                          0.070161
# population                                                    0.979035
# Percentage of population at the end of the year...            0.956859
# Percentage of population at the end of the year...            0.980494
# Percentage of population at the end of the year...            0.984480
# precent_count_Age                                             1.000000
# number_of_high_schools                                        0.902299
# number_of_bachelor_graduates_in_percent                       0.804841
# number_of_high_school_graduates_in_percent                    0.885752
# number_of_high_school_students                                0.953098
# Registration_for_higher_education_within_8_year...            0.841951
# number_of_students_in_percent                                 0.766026
# number_of_self_employees                                      0.889221
# number_of_employees                                           0.937688
# employees_average_monthly_wage                                0.035624
# employees_average_monthly_wage_change_in_percent              0.193088
# self_employees_average_monthly_wage                           0.040948
# self_employees_average_monthly_wage_change_in_p...            0.161608
#
#                                                     number_of_high_schools  \
# year                                                             -0.048114
# population                                                        0.885549
# Percentage of population at the end of the year...                0.955150
# Percentage of population at the end of the year...                0.888572
# Percentage of population at the end of the year...                0.841284
# precent_count_Age                                                 0.902299
# number_of_high_schools                                            1.000000
# number_of_bachelor_graduates_in_percent                           0.618395
# number_of_high_school_graduates_in_percent                        0.705708
# number_of_high_school_students                                    0.963253
# Registration_for_higher_education_within_8_year...                0.626710
# number_of_students_in_percent                                     0.640424
# number_of_self_employees                                          0.676593
# number_of_employees                                               0.772276
# employees_average_monthly_wage                                   -0.020787
# employees_average_monthly_wage_change_in_percent                  0.187749
# self_employees_average_monthly_wage                              -0.015962
# self_employees_average_monthly_wage_change_in_p...                0.173738
#
#                                                     number_of_bachelor_graduates_in_percent  \
# year                                                                              -0.088627
# population                                                                         0.876932
# Percentage of population at the end of the year...                                 0.750732
# Percentage of population at the end of the year...                                 0.717790
# Percentage of population at the end of the year...                                 0.851853
# precent_count_Age                                                                  0.804841
# number_of_high_schools                                                             0.618395
# number_of_bachelor_graduates_in_percent                                            1.000000
# number_of_high_school_graduates_in_percent                                         0.695800
# number_of_high_school_students                                                     0.732234
# Registration_for_higher_education_within_8_year...                                 0.874226
# number_of_students_in_percent                                                      0.956424
# number_of_self_employees                                                           0.902258
# number_of_employees                                                                0.928231
# employees_average_monthly_wage                                                     0.185354
# employees_average_monthly_wage_change_in_percent                                   0.184400
# self_employees_average_monthly_wage                                                0.167362
# self_employees_average_monthly_wage_change_in_p...                                 0.192408
#
#                                                     number_of_high_school_graduates_in_percent  \
# year                                                                                  0.189092
# population                                                                            0.868332
# Percentage of population at the end of the year...                                    0.791894
# Percentage of population at the end of the year...                                    0.865407
# Percentage of population at the end of the year...                                    0.901014
# precent_count_Age                                                                     0.885752
# number_of_high_schools                                                                0.705708
# number_of_bachelor_graduates_in_percent                                               0.695800
# number_of_high_school_graduates_in_percent                                            1.000000
# number_of_high_school_students                                                        0.793224
# Registration_for_higher_education_within_8_year...                                    0.885589
# number_of_students_in_percent                                                         0.580662
# number_of_self_employees                                                              0.868727
# number_of_employees                                                                   0.879911
# employees_average_monthly_wage                                                        0.111646
# employees_average_monthly_wage_change_in_percent                                      0.169183
# self_employees_average_monthly_wage                                                   0.107201
# self_employees_average_monthly_wage_change_in_p...                                    0.123316
#
#                                                     number_of_high_school_students  \
# year                                                                      0.032552
# population                                                                0.951853
# Percentage of population at the end of the year...                        0.987343
# Percentage of population at the end of the year...                        0.927845
# Percentage of population at the end of the year...                        0.906620
# precent_count_Age                                                         0.953098
# number_of_high_schools                                                    0.963253
# number_of_bachelor_graduates_in_percent                                   0.732234
# number_of_high_school_graduates_in_percent                                0.793224
# number_of_high_school_students                                            1.000000
# Registration_for_higher_education_within_8_year...                        0.733604
# number_of_students_in_percent                                             0.724465
# number_of_self_employees                                                  0.770054
# number_of_employees                                                       0.867523
# employees_average_monthly_wage                                            0.014921
# employees_average_monthly_wage_change_in_percent                          0.192655
# self_employees_average_monthly_wage                                       0.027810
# self_employees_average_monthly_wage_change_in_p...                        0.177492
#
#                                                     Registration_for_higher_education_within_8_years_in_percent  \
# year                                                                                         0.081039
# population                                                                                   0.872937
# Percentage of population at the end of the year...                                           0.733805
# Percentage of population at the end of the year...                                           0.785033
# Percentage of population at the end of the year...                                           0.892003
# precent_count_Age                                                                            0.841951
# number_of_high_schools                                                                       0.626710
# number_of_bachelor_graduates_in_percent                                                      0.874226
# number_of_high_school_graduates_in_percent                                                   0.885589
# number_of_high_school_students                                                               0.733604
# Registration_for_higher_education_within_8_year...                                           1.000000
# number_of_students_in_percent                                                                0.793509
# number_of_self_employees                                                                     0.958128
# number_of_employees                                                                          0.931195
# employees_average_monthly_wage                                                               0.237692
# employees_average_monthly_wage_change_in_percent                                             0.181822
# self_employees_average_monthly_wage                                                          0.211334
# self_employees_average_monthly_wage_change_in_p...                                           0.147610
#
#                                                     number_of_students_in_percent  \
# year                                                                    -0.126787
# population                                                               0.841750
# Percentage of population at the end of the year...                       0.740887
# Percentage of population at the end of the year...                       0.676552
# Percentage of population at the end of the year...                       0.802703
# precent_count_Age                                                        0.766026
# number_of_high_schools                                                   0.640424
# number_of_bachelor_graduates_in_percent                                  0.956424
# number_of_high_school_graduates_in_percent                               0.580662
# number_of_high_school_students                                           0.724465
# Registration_for_higher_education_within_8_year...                       0.793509
# number_of_students_in_percent                                            1.000000
# number_of_self_employees                                                 0.828428
# number_of_employees                                                      0.867365
# employees_average_monthly_wage                                           0.108283
# employees_average_monthly_wage_change_in_percent                         0.182211
# self_employees_average_monthly_wage                                      0.104871
# self_employees_average_monthly_wage_change_in_p...                       0.201561
#
#                                                     number_of_self_employees  \
# year                                                                0.055068
# population                                                          0.905619
# Percentage of population at the end of the year...                  0.773129
# Percentage of population at the end of the year...                  0.834542
# Percentage of population at the end of the year...                  0.939169
# precent_count_Age                                                   0.889221
# number_of_high_schools                                              0.676593
# number_of_bachelor_graduates_in_percent                             0.902258
# number_of_high_school_graduates_in_percent                          0.868727
# number_of_high_school_students                                      0.770054
# Registration_for_higher_education_within_8_year...                  0.958128
# number_of_students_in_percent                                       0.828428
# number_of_self_employees                                            1.000000
# number_of_employees                                                 0.958023
# employees_average_monthly_wage                                      0.158806
# employees_average_monthly_wage_change_in_percent                    0.228314
# self_employees_average_monthly_wage                                 0.141078
# self_employees_average_monthly_wage_change_in_p...                  0.193517
#
#                                                     number_of_employees  \
# year                                                           0.020720
# population                                                     0.972841
# Percentage of population at the end of the year...             0.874999
# Percentage of population at the end of the year...             0.880754
# Percentage of population at the end of the year...             0.961024
# precent_count_Age                                              0.937688
# number_of_high_schools                                         0.772276
# number_of_bachelor_graduates_in_percent                        0.928231
# number_of_high_school_graduates_in_percent                     0.879911
# number_of_high_school_students                                 0.867523
# Registration_for_higher_education_within_8_year...             0.931195
# number_of_students_in_percent                                  0.867365
# number_of_self_employees                                       0.958023
# number_of_employees                                            1.000000
# employees_average_monthly_wage                                 0.111456
# employees_average_monthly_wage_change_in_percent               0.205402
# self_employees_average_monthly_wage                            0.106314
# self_employees_average_monthly_wage_change_in_p...             0.181593
#
#                                                     employees_average_monthly_wage  \
# year                                                                      0.098796
# population                                                                0.059819
# Percentage of population at the end of the year...                       -0.003680
# Percentage of population at the end of the year...                        0.017773
# Percentage of population at the end of the year...                        0.065353
# precent_count_Age                                                         0.035624
# number_of_high_schools                                                   -0.020787
# number_of_bachelor_graduates_in_percent                                   0.185354
# number_of_high_school_graduates_in_percent                                0.111646
# number_of_high_school_students                                            0.014921
# Registration_for_higher_education_within_8_year...                        0.237692
# number_of_students_in_percent                                             0.108283
# number_of_self_employees                                                  0.158806
# number_of_employees                                                       0.111456
# employees_average_monthly_wage                                            1.000000
# employees_average_monthly_wage_change_in_percent                         -0.049859
# self_employees_average_monthly_wage                                       0.829150
# self_employees_average_monthly_wage_change_in_p...                       -0.044967
#
#                                                     employees_average_monthly_wage_change_in_percent  \
# year                                                                                       -0.050586
# population                                                                                  0.207157
# Percentage of population at the end of the year...                                          0.196771
# Percentage of population at the end of the year...                                          0.171711
# Percentage of population at the end of the year...                                          0.196672
# precent_count_Age                                                                           0.193088
# number_of_high_schools                                                                      0.187749
# number_of_bachelor_graduates_in_percent                                                     0.184400
# number_of_high_school_graduates_in_percent                                                  0.169183
# number_of_high_school_students                                                              0.192655
# Registration_for_higher_education_within_8_year...                                          0.181822
# number_of_students_in_percent                                                               0.182211
# number_of_self_employees                                                                    0.228314
# number_of_employees                                                                         0.205402
# employees_average_monthly_wage                                                             -0.049859
# employees_average_monthly_wage_change_in_percent                                            1.000000
# self_employees_average_monthly_wage                                                        -0.073999
# self_employees_average_monthly_wage_change_in_p...                                          0.979759
#
#                                                     self_employees_average_monthly_wage  \
# year                                                                           0.063893
# population                                                                     0.063083
# Percentage of population at the end of the year...                             0.015181
# Percentage of population at the end of the year...                             0.024467
# Percentage of population at the end of the year...                             0.062915
# precent_count_Age                                                              0.040948
# number_of_high_schools                                                        -0.015962
# number_of_bachelor_graduates_in_percent                                        0.167362
# number_of_high_school_graduates_in_percent                                     0.107201
# number_of_high_school_students                                                 0.027810
# Registration_for_higher_education_within_8_year...                             0.211334
# number_of_students_in_percent                                                  0.104871
# number_of_self_employees                                                       0.141078
# number_of_employees                                                            0.106314
# employees_average_monthly_wage                                                 0.829150
# employees_average_monthly_wage_change_in_percent                              -0.073999
# self_employees_average_monthly_wage                                            1.000000
# self_employees_average_monthly_wage_change_in_p...                            -0.068808
#
#                                                     self_employees_average_monthly_wage_change_in_percent
# year                                                                                        -0.105739
# population                                                                                   0.189246
# Percentage of population at the end of the year...                                           0.186450
# Percentage of population at the end of the year...                                           0.124097
# Percentage of population at the end of the year...                                           0.167896
# precent_count_Age                                                                            0.161608
# number_of_high_schools                                                                       0.173738
# number_of_bachelor_graduates_in_percent                                                      0.192408
# number_of_high_school_graduates_in_percent                                                   0.123316
# number_of_high_school_students                                                               0.177492
# Registration_for_higher_education_within_8_year...                                           0.147610
# number_of_students_in_percent                                                                0.201561
# number_of_self_employees                                                                     0.193517
# number_of_employees                                                                          0.181593
# employees_average_monthly_wage                                                              -0.044967
# employees_average_monthly_wage_change_in_percent                                             0.979759
# self_employees_average_monthly_wage                                                         -0.068808
# self_employees_average_monthly_wage_change_in_p...                                           1.000000
