# %%
from bs4 import BeautifulSoup
import re
import requests
import pandas as pd
import numpy as np
import os
from csv import writer

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from selenium.webdriver.support.ui import Select
import time
import json
import urllib
from csv import DictWriter
                      
from sklearn import linear_model
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from scipy import stats

import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
PATH = 'C:/Users/shake/Sdata/chromedriver.exe'
dataPath = 'C:/Users/shake/Sdata/data/'

# %%
#df_2020 = pd.DataFrame()
df_2019 = pd.DataFrame()
df_2018 = pd.DataFrame()
df_2017 = pd.DataFrame()
df_2016 = pd.DataFrame()

dic_years = {'2019':df_2019, '2018':df_2018, '2017':df_2017, '2016':df_2016}

# %%
#/////////////////////fix duplicates columns////////////////////////////////////////////////////////////////////////////////

def get_tables():
    i = 0
    arr = []
    driver.execute_script("""
    document.querySelectorAll("a[aria-hidden=true],span[aria-hidden=true]").forEach(function(e) {
        e.parentElement.removeChild(e);
    });
    """)
    time.sleep(5)
    temp_html = driver.find_element(By.CSS_SELECTOR, "html").get_attribute('outerHTML')
    df_school = pd.read_html(temp_html, attrs = {'class':'zebraTable ng-scope'})[0]
    for columns in df_school:
        arr.append(df_school.columns[i][0])
        i = i + 1
    df_school.columns = arr
    return df_school

# %%
def GetYearsDemography(fileName,url):
    try:
        driver.get(url)
        driver.implicitly_wait(20)
        driver.maximize_window()
        selectSubtext = driver.find_element(By.ID, "select2-chosen-4")
        selectSubtext.click()
        driver.find_element(By.XPATH, "//*[@id=\"select2-results-4\"]/li[" + "7" + "]").click()
        time.sleep(10)
        selectCity = driver.find_element(By.ID, "select2-chosen-8")
        selectCity.click()
        time.sleep(1)
        options = driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]")
        AllOpt = options.find_elements_by_css_selector("li")

        countOpt=len(AllOpt)
        driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]/li[" + "1" + "]").click()

        dfData = pd.DataFrame()
        firstTime = True
        for i in range(1, countOpt):

            driver.find_element(By.ID, "select2-chosen-4").click()
            driver.find_element(By.XPATH, "//*[@id=\"select2-results-4\"]/li[" + "7" + "]").click()
            selectCity = driver.find_element(By.ID, "select2-chosen-8")
            selectCity.click()
            driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]/li[" + str(i) + "]").click()
            year = selectCity.text
            temp = get_tables()
            temp.insert(0, "Years", year, True)
            print(temp)
            dfData = dfData.append(temp, ignore_index=True)
            if firstTime:
                temp.to_csv(fileName, mode='a', encoding='utf-8-sig',index=False)
                firstTime = False
            else:
                temp.to_csv(fileName, mode='a', encoding='utf-8-sig',index=False, header=False)


    except BaseException as e:
        print("Invalid URL")
    driver.quit()
    return dfData

# %%
#/////////////education status//////////////////////////////////////////////////////////////////////////////////////////////

options = webdriver.ChromeOptions() 
options.add_argument("--enable-webgl-developer-extensions") 
options.add_argument("--enable-webgl-draft-extensions") 
driver = webdriver.Chrome(PATH,options=options)
driver.vars = {}
url = "https://boardsgenerator.cbs.gov.il/pages/WebParts/YishuvimPage.aspx?level_1=%D7%A9%D7%9B%D7%A8%20/%20%D7%94%D7%9B%D7%A0%D7%A1%D7%95%D7%AA"
driver.get(url)
element = driver.find_element(By.ID, "select2-chosen-4")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
element = driver.find_element(By.CSS_SELECTOR, "body")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
element = driver.find_element(By.ID, "select2-chosen-4")
actions = ActionChains(driver)
actions.move_to_element(element).click_and_hold().perform()
element = driver.find_element(By.ID, "select2-drop-mask")
actions = ActionChains(driver)
actions.move_to_element(element).release().perform()
driver.find_element(By.XPATH, "//*[@id=\"select2-results-4\"]/li[10]").click()
time.sleep(5)
for i in range(2, 6):
    selectCity = driver.find_element(By.ID, "select2-chosen-8")
    selectCity.click()
    time.sleep(10)
    driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]/li[" + str(i) + "]").click()
    time.sleep(10)
    df_temp = get_tables()
    year = selectCity.text
    #print(year)
    dic_years[year] = df_temp
    
    dic_years[year].insert(0, "year", year, True)
driver.quit()
dic_years[year]
# Out:
# <ipython-input-241-98b0e700871a>:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH,options=options)
#      year  סמל היישוב      שם יישוב  \
# 0    2016         472       אבו גוש
# 1    2016         473      אבו סנאן
# 2    2016         182     אבן יהודה
# 3    2016        2710    אום אל-פחם
# 4    2016          31        אופקים
# ..    ...         ...           ...
# 196  2016         538           שעב
# 197  2016        8800         שפרעם
# 198  2016        5000  תל אביב -יפו
# 199  2016         154       תל מונד
# 200  2016        1054        תל שבע
#
#      ילדים בגנים של משרד החינוך סה"כ תשע"ו 2015/16  \
# 0                                              375
# 1                                              670
# 2                                              740
# 3                                             3588
# 4                                             1754
# ..                                             ...
# 196                                            427
# 197                                           2012
# 198                                          17327
# 199                                            625
# 200                                           1725
#
#      ילדים בגנים של משרד החינוך גיל 3 תשע"ו 2015/16  \
# 0                                               148
# 1                                               224
# 2                                               215
# 3                                              1151
# 4                                               566
# ..                                              ...
# 196                                             149
# 197                                             634
# 198                                            5168
# 199                                             171
# 200                                             538
#
#      ילדים בגנים של משרד החינוך גיל 4 תשע"ו 2015/16  \
# 0                                               113
# 1                                               207
# 2                                               244
# 3                                              1144
# 4                                               553
# ..                                              ...
# 196                                             148
# 197                                             665
# 198                                            5786
# 199                                             200
# 200                                             573
#
#      ילדים בגנים של משרד החינוך גיל 5 תשע"ו 2015/16  \
# 0                                               112
# 1                                               230
# 2                                               255
# 3                                              1183
# 4                                               525
# ..                                              ...
# 196                                             127
# 197                                             676
# 198                                            5733
# 199                                             223
# 200                                             573
#
#     ילדים בגנים של משרד החינוך גיל 6 תשע"ו 2015/16 בתי ספר סה"כ תשע"ו 2015/16  \
# 0                                               ..                          5
# 1                                                9                          6
# 2                                               26                          8
# 3                                              110                         29
# 4                                              110                         25
# ..                                             ...                        ...
# 196                                              3                          3
# 197                                             37                         24
# 198                                            640                        163
# 199                                             31                          5
# 200                                             41                         11
#
#     בתי ספר יסודיים (כולל חינוך מיוחד) תשע"ו 2015/16  ...  \
# 0                                                  4  ...
# 1                                                  4  ...
# 2                                                  6  ...
# 3                                                 18  ...
# 4                                                 18  ...
# ..                                               ...  ...
# 196                                               ..  ...
# 197                                               15  ...
# 198                                              103  ...
# 199                                                4  ...
# 200                                                8  ...
#
#     תלמידים בבתי ספר על-יסודיים תשע"ו 2015/16  \
# 0                                         700
# 1                                        1384
# 2                                        1906
# 3                                        7292
# 4                                        1978
# ..                                        ...
# 196                                       756
# 197                                      4238
# 198                                     23370
# 199                                      1751
# 200                                      2674
#
#     תלמידים בחטיבות ביניים תשע"ו 2015/16  \
# 0                                    323
# 1                                    723
# 2                                    613
# 3                                   3563
# 4                                    582
# ..                                   ...
# 196                                  427
# 197                                 1853
# 198                                10333
# 199                                  725
# 200                                 1554
#
#     תלמידים בבתי ספר תיכוניים תשע"ו 2015/16  \
# 0                                       377
# 1                                       661
# 2                                      1293
# 3                                      3729
# 4                                      1396
# ..                                      ...
# 196                                     329
# 197                                    2385
# 198                                   13037
# 199                                    1026
# 200                                    1120
#
#      ממוצע תלמידים לכיתה סה"כ תשע"ו 2015/16  \
# 0                                     20.00
# 1                                     23.00
# 2                                     28.00
# 3                                     25.79
# 4                                     20.42
# ..                                      ...
# 196                                   25.00
# 197                                   26.14
# 198                                   24.03
# 199                                   31.00
# 200                                   26.00
#
#      ממוצע תלמידים לכיתה בבתי ספר יסודיים (כולל חינוך מיוחד) תשע"ו 2015/16  \
# 0                                                19.00
# 1                                                22.00
# 2                                                27.00
# 3                                                24.85
# 4                                                19.95
# ..                                                 ...
# 196                                              24.00
# 197                                              25.56
# 198                                              23.63
# 199                                              28.00
# 200                                              24.00
#
#      ממוצע תלמידים לכיתה בבתי ספר על-יסודיים תשע"ו 2015/16  \
# 0                                                20.00
# 1                                                25.00
# 2                                                31.00
# 3                                                26.81
# 4                                                21.27
# ..                                                 ...
# 196                                              26.00
# 197                                              26.82
# 198                                              24.57
# 199                                              35.00
# 200                                              28.00
#
#      ממוצע תלמידים לכיתה בחטיבות ביניים תשע"ו 2015/16  \
# 0                                                  27
# 1                                                  26
# 2                                                  34
# 3                                                  29
# 4                                                  22
# ..                                                ...
# 196                                                27
# 197                                                29
# 198                                                27
# 199                                                38
# 200                                                30
#
#      ממוצע תלמידים לכיתה בבתי ספר תיכוניים תשע"ו 2015/16  \
# 0                                                16.00
# 1                                                24.00
# 2                                                29.00
# 3                                                25.20
# 4                                                20.84
# ..                                                 ...
# 196                                              25.00
# 197                                              25.11
# 198                                              22.87
# 199                                              33.00
# 200                                              26.00
#
#      אחוז זכאים לתעודת בגרות מבין תלמידי כיתות יב תשע"ו 2015/16  \
# 0                                                49.20
# 1                                                56.10
# 2                                                81.10
# 3                                                52.90
# 4                                                51.70
# ..                                                 ...
# 196                                                 64
# 197                                              47.70
# 198                                                 74
# 199                                              89.40
# 200                                              37.90
#
#      אחוז זכאים לתעודת בגרות שעמדו בדרישות הסף של האוניברסיטאות מבין תלמידי כיתות יב תשע"ו 2015/16
# 0                                                35.80
# 1                                                39.20
# 2                                                71.70
# 3                                                32.40
# 4                                                34.80
# ..                                                 ...
# 196                                              52.30
# 197                                              41.20
# 198                                              65.40
# 199                                              84.30
# 200                                              25.90
#
# [201 rows x 30 columns]

# %%
df_years_temp = pd.DataFrame(columns=['year', 'city', 'number_of_high_schools', 'number_of_bachelor_graduates_in_percent', 'number_of_high_school_graduates_in_percent', 'number_of_high_school_students', 'number_of_high_school_graduates_with_potential_in_percent', 'Registration_for_higher_education_within_8_years_in_percent', 'number_of_students_in_percent'])
df_education = pd.DataFrame()
for i in dic_years:
    #print(i)
    if(i == '2015'):
        break
    df_temp = dic_years[i]
    df_years_temp['year'] = df_temp.iloc[:,0].values
    df_years_temp['city'] = df_temp.iloc[:,2].values
    df_years_temp['number_of_high_schools'] =  df_temp.iloc[:,12].values
    df_years_temp['number_of_bachelor_graduates_in_percent'] = df_temp.iloc[:,29].values
    df_years_temp['number_of_high_school_graduates_with_potential_in_percent'] = df_temp.iloc[:,28].values
    df_years_temp['number_of_high_school_graduates_in_percent'] = df_temp.iloc[:,27].values
    df_years_temp['number_of_high_school_students'] = df_temp.iloc[:,22].values
    if(i != '2016'):
        df_years_temp['Registration_for_higher_education_within_8_years_in_percent'] = df_temp.iloc[:,30].values
        df_years_temp['number_of_students_in_percent'] = df_temp.iloc[:,32].values
    df_education = df_education.append(df_years_temp)
df_education.to_csv(dataPath + 'dfEducation.csv', mode='w+', encoding='utf-8-sig',index=False)    
df_education
# Out:
#      year          city number_of_high_schools  \
# 0    2019       אבו גוש                      3
# 1    2019      אבו סנאן                      3
# 2    2019     אבן יהודה                      3
# 3    2019    אום אל-פחם                     13
# 4    2019        אופקים                     11
# ..    ...           ...                    ...
# 196  2016           שעב                     ..
# 197  2016         שפרעם                      9
# 198  2016  תל אביב -יפו                     64
# 199  2016       תל מונד                     ..
# 200  2016        תל שבע                      5
#
#     number_of_bachelor_graduates_in_percent  \
# 0                                     13.03
# 1                                     12.09
# 2                                     55.59
# 3                                      8.52
# 4                                     12.26
# ..                                      ...
# 196                                   52.30
# 197                                   41.20
# 198                                   65.40
# 199                                   84.30
# 200                                   25.90
#
#     number_of_high_school_graduates_in_percent number_of_high_school_students  \
# 0                                        59.29                            361
# 1                                        65.81                            592
# 2                                        83.96                           1087
# 3                                        59.40                           3838
# 4                                        50.24                           1551
# ..                                         ...                            ...
# 196                                         25                            329
# 197                                      25.11                           2385
# 198                                      22.87                          13037
# 199                                         33                           1026
# 200                                         26                           1120
#
#     number_of_high_school_graduates_with_potential_in_percent  \
# 0                                                37.17
# 1                                                52.56
# 2                                                76.89
# 3                                                44.16
# 4                                                39.81
# ..                                                 ...
# 196                                                 64
# 197                                              47.70
# 198                                                 74
# 199                                              89.40
# 200                                              37.90
#
#     Registration_for_higher_education_within_8_years_in_percent  \
# 0                                                   ..
# 1                                                28.50
# 2                                                46.10
# 3                                                23.30
# 4                                                26.60
# ..                                                 ...
# 196                                                8.5
# 197                                                9.7
# 198                                               41.1
# 199                                               51.3
# 200                                                6.3
#
#      number_of_students_in_percent
# 0                             3.74
# 1                             2.32
# 2                             3.03
# 3                             2.11
# 4                             1.84
# ..                             ...
# 196                          14.40
# 197                          11.90
# 198                          20.80
# 199                          13.60
# 200                           7.50
#
# [804 rows x 9 columns]

# %%
options = webdriver.ChromeOptions() 
options.add_argument("--enable-webgl-developer-extensions") 
options.add_argument("--enable-webgl-draft-extensions") 
driver = webdriver.Chrome(PATH,options=options)
driver.vars = {}
url = "https://boardsgenerator.cbs.gov.il/pages/WebParts/YishuvimPage.aspx?level_1=%D7%A9%D7%9B%D7%A8%20/%20%D7%94%D7%9B%D7%A0%D7%A1%D7%95%D7%AA"
driver.get(url)
time.sleep(2)
element = driver.find_element(By.ID, "select2-chosen-4")
actions = ActionChains(driver)
time.sleep(2)
actions.move_to_element(element).perform()
element = driver.find_element(By.CSS_SELECTOR, "body")
actions = ActionChains(driver)
actions.move_to_element(element).perform()
element = driver.find_element(By.ID, "select2-chosen-4")
actions = ActionChains(driver)
time.sleep(2)
actions.move_to_element(element).click_and_hold().perform()
element = driver.find_element(By.ID, "select2-drop-mask")
actions = ActionChains(driver)
time.sleep(2)
actions.move_to_element(element).release().perform()
driver.find_element(By.XPATH, "//*[@id=\"select2-results-4\"]/li[8]").click()
time.sleep(5)
for i in range(1, 6):
    selectCity = driver.find_element(By.ID, "select2-chosen-8")
    selectCity.click()
    time.sleep(10)
    driver.find_element(By.XPATH, "//*[@id=\"select2-results-8\"]/li[" + str(i) + "]").click()
    time.sleep(12)
    df_temp = get_tables()
    year = selectCity.text
    #print(year)
    dic_years[year] = df_temp
    dic_years[year].insert(0, "year", year, True)
driver.quit()
dic_years[year]
# Out:
# <ipython-input-120-12c16bc868df>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH,options=options)
#      year  סמל היישוב      שם יישוב  \
# 0    2015         472       אבו גוש
# 1    2015         473      אבו סנאן
# 2    2015         182     אבן יהודה
# 3    2015        2710    אום אל-פחם
# 4    2015          31        אופקים
# ..    ...         ...           ...
# 219  2015         538           שעב
# 220  2015        8800         שפרעם
# 221  2015        5000  תל אביב -יפו
# 222  2015         154       תל מונד
# 223  2015        1054        תל שבע
#
#      שכר ממוצע לחודש של שכירים (ש"ח) כלל השכירים  \
# 0                                        6275.59
# 1                                        6060.40
# 2                                       13502.86
# 3                                        5289.00
# 4                                        9496.00
# ..                                           ...
# 219                                      5312.02
# 220                                      6142.00
# 221                                     10808.00
# 222                                     14056.74
# 223                                      5083.17
#
#      שכר ממוצע לחודש של שכירים (ש"ח) גברים  \
# 0                                  6928.63
# 1                                  7314.21
# 2                                 16816.52
# 3                                  6096.00
# 4                                 12155.00
# ..                                     ...
# 219                                6020.50
# 220                                7286.00
# 221                               12888.00
# 222                               17904.35
# 223                                5869.36
#
#      שכר ממוצע לחודש של שכירים (ש"ח) נשים  \
# 0                                 5240.03
# 1                                 4302.60
# 2                                10097.43
# 3                                 3811.00
# 4                                 7006.00
# ..                                    ...
# 219                               4112.21
# 220                               4489.00
# 221                               8667.00
# 222                              10202.37
# 223                               3530.30
#
#      אחוז שינוי ריאלי לעומת השנה הקודמת של שכר ממוצע לחודש של שכירים כלל השכירים  \
# 0                                                  4.7
# 1                                                  4.3
# 2                                                  5.2
# 3                                                  3.0
# 4                                                  6.4
# ..                                                 ...
# 219                                                4.7
# 220                                                3.7
# 221                                                5.8
# 222                                                4.1
# 223                                               -0.3
#
#      אחוז שינוי ריאלי לעומת השנה הקודמת של שכר ממוצע לחודש של שכירים גברים  \
# 0                                                  3.9
# 1                                                  5.3
# 2                                                  3.6
# 3                                                  2.4
# 4                                                  6.7
# ..                                                 ...
# 219                                                4.1
# 220                                                4.8
# 221                                                6.0
# 222                                                4.3
# 223                                               -1.2
#
#      אחוז שינוי ריאלי לעומת השנה הקודמת של שכר ממוצע לחודש של שכירים נשים  \
# 0                                                  6.3
# 1                                                  2.3
# 2                                                  5.7
# 3                                                  5.9
# 4                                                  5.0
# ..                                                 ...
# 219                                                6.9
# 220                                                2.2
# 221                                                4.5
# 222                                                2.9
# 223                                                2.2
#
#      מספר השכירים  אחוז השכירים המשתכרים עד שכר מינימום  מספר העצמאים  \
# 0            2728                                  42.2           130
# 1            4900                                  49.7           435
# 2            6077                                  27.6           660
# 3           16739                                  56.9          1487
# 4            2967                                  38.1           231
# ..            ...                                   ...           ...
# 219          2443                                  52.6           150
# 220         15471                                  48.8          1109
# 221        224083                                  31.9         23222
# 222          5699                                  28.5           603
# 223          3954                                  55.7           135
#
#      הכנסה ממוצעת לחודש של העצמאים (ש"ח)  \
# 0                                6656.52
# 1                                7940.37
# 2                               12913.98
# 3                                7864.00
# 4                                9128.00
# ..                                   ...
# 219                              6452.12
# 220                              8546.00
# 221                             11685.00
# 222                             13015.24
# 223                             11588.19
#
#      אחוז שינוי ריאלי של הכנסה ממוצעת לחודש של העצמאים לעומת השנה הקודמת  \
# 0                                                 -0.8
# 1                                                  9.8
# 2                                                 -1.3
# 3                                                  3.0
# 4                                                 19.6
# ..                                                 ...
# 219                                                3.8
# 220                                                7.1
# 221                                                6.2
# 222                                                5.9
# 223                                                1.2
#
#      אחוז העצמאים המשתכרים עד מחצית השכר הממוצע  \
# 0                                          53.1
# 1                                          44.6
# 2                                          32.3
# 3                                          44.5
# 4                                          39.4
# ..                                          ...
# 219                                        60.0
# 220                                        41.8
# 221                                        37.5
# 222                                        31.0
# 223                                        38.5
#
#      מדד אי-השוויון שכירים (מדד ג'יני, 0 שוויון מלא)
# 0                                               0.34
# 1                                               0.39
# 2                                               0.48
# 3                                               0.38
# 4                                               0.45
# ..                                               ...
# 219                                             0.35
# 220                                             0.38
# 221                                             0.47
# 222                                             0.50
# 223                                             0.36
#
# [224 rows x 16 columns]

# %%
df_employees_info = pd.DataFrame()
df_years_temp = pd.DataFrame(columns=['year', 'city','number_of_self_employees', 'number_of_employees', 'employees_average_monthly_wage', 'employees_average_monthly_wage_change_in_percent', 'self_employees_average_monthly_wage'])
for i in dic_years:
    #print(i)
    if(i == '2015'):
        break
    df_temp = dic_years[i]
    df_years_temp['year'] = df_temp.iloc[:,0].values
    df_years_temp['city'] = df_temp.iloc[:,2].values
    df_years_temp['number_of_self_employees'] =  df_temp.iloc[:,11].values
    df_years_temp['number_of_employees'] = df_temp.iloc[:,9].values
    df_years_temp['employees_average_monthly_wage'] = df_temp.iloc[:,3].values
    df_years_temp['employees_average_monthly_wage_change_in_percent'] = df_temp.iloc[:,6].values
    df_years_temp['self_employees_average_monthly_wage'] = df_temp.iloc[:,12].values
    df_employees_info = df_employees_info.append(df_years_temp)

# drop שעב 2016 row/////////////////////////////////////////////////         
df_employees_info.drop
df_employees_info.drop(df_employees_info.index[219], inplace=True)
#//////////////////////////////////////////////////////////////////
        
    
df_employees_info.to_csv(dataPath + 'dfEmployees.csv', mode='w+', encoding='utf-8-sig',index=False)
df_employees_info
# Out:
#      year          city  number_of_self_employees  number_of_employees  \
# 0    2019       אבו גוש                       151                 3393
# 1    2019      אבו סנאן                       626                 5841
# 2    2019     אבן יהודה                       899                 6265
# 3    2019    אום אל-פחם                      1918                22149
# 4    2019        אופקים                       295                 3342
# ..    ...           ...                       ...                  ...
# 218  2016         שלומי                       218                 3157
# 220  2016         שפרעם                      1161                16307
# 221  2016  תל אביב -יפו                     24447               223935
# 222  2016       תל מונד                       660                 5819
# 223  2016        תל שבע                       149                 4543
#
#      employees_average_monthly_wage  \
# 0                           7294.03
# 1                           7071.17
# 2                          14054.00
# 3                           5869.82
# 4                           9398.05
# ..                              ...
# 218                         8164.68
# 220                         6236.00
# 221                        11017.00
# 222                        13983.03
# 223                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 218                                              1.59
# 220                                              2.00
# 221                                              2.50
# 222                                             -0.02
# 223                                             -1.46
#
#      self_employees_average_monthly_wage
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 218                             10706.09
# 220                              8996.00
# 221                             11908.00
# 222                             13735.86
# 223                             11631.40
#
# [892 rows x 7 columns]

# %%
df_education = pd.read_csv(dataPath + 'dfEducation.csv')
df_employees_info = pd.read_csv(dataPath + 'dfEmployees.csv')

df_eduoEmplo = [df_education, df_employees_info]
df_eduoEmplo = pd.merge(df_education, df_employees_info,  how='left', left_on=['year','city'], right_on = ['year','city'])
df_eduoEmplo
# Out:
#      year          city number_of_high_schools  \
# 0    2019       אבו גוש                      3
# 1    2019      אבו סנאן                      3
# 2    2019     אבן יהודה                      3
# 3    2019    אום אל-פחם                     13
# 4    2019        אופקים                     11
# ..    ...           ...                    ...
# 799  2016           שעב                     ..
# 800  2016         שפרעם                      9
# 801  2016  תל אביב -יפו                     64
# 802  2016       תל מונד                     ..
# 803  2016        תל שבע                      5
#
#     number_of_bachelor_graduates_in_percent  \
# 0                                     13.03
# 1                                     12.09
# 2                                     55.59
# 3                                      8.52
# 4                                     12.26
# ..                                      ...
# 799                                   52.30
# 800                                   41.20
# 801                                   65.40
# 802                                   84.30
# 803                                   25.90
#
#     number_of_high_school_graduates_in_percent number_of_high_school_students  \
# 0                                        59.29                            361
# 1                                        65.81                            592
# 2                                        83.96                           1087
# 3                                        59.40                           3838
# 4                                        50.24                           1551
# ..                                         ...                            ...
# 799                                       25.0                            329
# 800                                      25.11                           2385
# 801                                      22.87                          13037
# 802                                       33.0                           1026
# 803                                       26.0                           1120
#
#     number_of_high_school_graduates_with_potential_in_percent  \
# 0                                                37.17
# 1                                                52.56
# 2                                                76.89
# 3                                                44.16
# 4                                                39.81
# ..                                                 ...
# 799                                                 64
# 800                                              47.70
# 801                                                 74
# 802                                              89.40
# 803                                              37.90
#
#     Registration_for_higher_education_within_8_years_in_percent  \
# 0                                                   ..
# 1                                                28.50
# 2                                                46.10
# 3                                                23.30
# 4                                                26.60
# ..                                                 ...
# 799                                                8.5
# 800                                                9.7
# 801                                               41.1
# 802                                               51.3
# 803                                                6.3
#
#      number_of_students_in_percent  number_of_self_employees  \
# 0                             3.74                     151.0
# 1                             2.32                     626.0
# 2                             3.03                     899.0
# 3                             2.11                    1918.0
# 4                             1.84                     295.0
# ..                             ...                       ...
# 799                          14.40                       NaN
# 800                          11.90                    1161.0
# 801                          20.80                   24447.0
# 802                          13.60                     660.0
# 803                           7.50                     149.0
#
#      number_of_employees  employees_average_monthly_wage  \
# 0                 3393.0                         7294.03
# 1                 5841.0                         7071.17
# 2                 6265.0                        14054.00
# 3                22149.0                         5869.82
# 4                 3342.0                         9398.05
# ..                   ...                             ...
# 799                  NaN                             NaN
# 800              16307.0                         6236.00
# 801             223935.0                        11017.00
# 802               5819.0                        13983.03
# 803               4543.0                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 799                                               NaN
# 800                                              2.00
# 801                                              2.50
# 802                                             -0.02
# 803                                             -1.46
#
#      self_employees_average_monthly_wage
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 799                                  NaN
# 800                              8996.00
# 801                             11908.00
# 802                             13735.86
# 803                             11631.40
#
# [804 rows x 14 columns]

# %%
fileName= dataPath + 'YearsDemography.csv'

if os.path.isfile(fileName):
    dfDemography = pd.read_csv(fileName)
else:
    url = "https://boardsgenerator.cbs.gov.il/pages/WebParts/YishuvimPage.aspx?level_1=%D7%A9%D7%9B%D7%A8%20/%20%D7%94%D7%9B%D7%A0%D7%A1%D7%95%D7%AA"
    driver = webdriver.Chrome(PATH)
    dfDemography = GetYearsDemography(fileName,url)
    
dfDemography
# Out:
#       Years      שם יישוב  סמל היישוב  \
# 0      2020       אבו גוש         472
# 1      2020      אבו סנאן         473
# 2      2020     אבן יהודה         182
# 3      2020    אום אל-פחם        2710
# 4      2020        אופקים          31
# ...     ...           ...         ...
# 3592   2003           שעב         538
# 3593   2003         שפרעם        8800
# 3594   2003  תל אביב -יפו        5000
# 3595   2003       תל מונד         154
# 3596   2003        תל שבע        1054
#
#      צפיפות אוכלוסייה לקמ''ר ביישובים שמנו 5,000 תושבים ויותר  \
# 0                                                4114.4
# 1                                                2136.9
# 2                                                1696.2
# 3                                                2187.4
# 4                                                1990.8
# ...                                                 ...
# 3592                                                2.9
# 3593                                               15.7
# 3594                                              173.8
# 3595                                                  4
# 3596                                                5.9
#
#       סה"כ אוכלוסייה בסוף השנה יהודים ואחרים (אחוזים)  \
# 0                       7771.0                      -
# 1                      14306.0                      -
# 2                      14020.0                    100
# 3                      56777.0                      -
# 4                      32555.0                   99.3
# ...                        ...                    ...
# 3592                       2.8                  14.04
# 3593                      15.5                   13.2
# 3594                     189.6                      7
# 3595                       3.9                  11.43
# 3596                       6.0                  24.35
#
#      יהודים (אחוזים מתוך יהודים ואחרים) ערבים (אחוזים)  \
# 0                                     -           98.9
# 1                                     -           99.8
# 2                                  98.4              -
# 3                                     -           99.9
# 4                                  93.4              -
# ...                                 ...            ...
# 3592                              13.56          13.17
# 3593                               12.5           10.9
# 3594                                5.5            4.8
# 3595                              10.62           9.73
# 3596                              17.33          14.33
#
#      מוסלמים (אחוזים מתוך האוכלוסייה הערבית)  \
# 0                                       99.8
# 1                                       54.6
# 2                                          -
# 3                                        100
# 4                                          -
# ...                                      ...
# 3592                                    9.43
# 3593                                    8.33
# 3594                                     5.2
# 3595                                    7.77
# 3596                                   10.57
#
#      נוצרים (אחוזים מתוך האוכלוסייה הערבית)  ...  \
# 0                                         -  ...
# 1                                      15.2  ...
# 2                                         -  ...
# 3                                         -  ...
# 4                                         -  ...
# ...                                     ...  ...
# 3592                                  17.07  ...
# 3593                                  16.22  ...
# 3594                                   18.5  ...
# 3595                                  12.77  ...
# 3596                                  16.44  ...
#
#      נישאים שיעור ל-1,000 תושבים לא נשואים בני 15 ומעלה 2019  \
# 0                                                  44.6
# 1                                                  42.2
# 2                                                    20
# 3                                                  53.7
# 4                                                  44.5
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       מתגרשים סה"כ גברים ונשים 2019  \
# 0                                26
# 1                                29
# 2                                40
# 3                               104
# 4                               119
# ...                             ...
# 3592                            NaN
# 3593                            NaN
# 3594                            NaN
# 3595                            NaN
# 3596                            NaN
#
#       מתגרשים שיעור ל-1,000 תושבים נשואים בני 15 ומעלה 2019  \
# 0                                                   8.1
# 1                                                   4.7
# 2                                                     7
# 3                                                   4.5
# 4                                                  10.7
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) סך מוסדות דיור משותף ברשות  \
# 0                                                     4
# 1                                                     -
# 2                                                     5
# 3                                                    ..
# 4                                                     6
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) סך דיירי דיור משותף ברשות  \
# 0                                                    31
# 1                                                     -
# 2                                                   347
# 3                                                    ..
# 4                                                   559
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים בבתי אבות ובדיור מוגן  \
# 0                                                     -
# 1                                                     -
# 2                                                  1.35
# 3                                                    ..
# 4                                                  0.87
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות חינוך  \
# 0                                                   0.3
# 1                                                     -
# 2                                                   0.3
# 3                                                    ..
# 4                                                  0.58
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות דת  \
# 0                                                  0.04
# 1                                                     -
# 2                                                     -
# 3                                                    ..
# 4                                                  0.17
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות אשפוז כולל הוסטלים  \
# 0                                                  0.06
# 1                                                     -
# 2                                                  0.83
# 3                                                    ..
# 4                                                     -
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות אחרים
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                    ..
# 4                                                  0.09
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
# [3597 rows x 68 columns]

# %%
dfDemography=dfDemography.rename(columns={"Years":"year"})
dfDemography=dfDemography.rename(columns={"שם יישוב":"city"})
dfDemography=dfDemography.rename(columns={'סה"כ אוכלוסייה בסוף השנה':"population"})
dfDemography=dfDemography.rename(columns={'אחוז באוכלוסייה בסוף השנה בני 19-15':"Percentage of population at the end of the year aged 19-15"})
dfDemography=dfDemography.rename(columns={'אחוז באוכלוסייה בסוף השנה בני 29-20':"Percentage of population at the end of the year aged 20-29"})
dfDemography=dfDemography.rename(columns={'אחוז באוכלוסייה בסוף השנה בני 44-30':"Percentage of population at the end of the year aged 30-44"})

dfYearsCityPop=dfDemography

populationList = dfYearsCityPop['population'].tolist()
for i in range(len(populationList)):
    if (populationList[i] <= 1000) :
            populationList[i] = populationList[i] * 1000

dfYearsCityPop['population'] = populationList
dfYearsCityPop.to_csv(dataPath + 'dfYearsCityPop.csv', mode='w+', encoding='utf-8-sig',index=False)
dfYearsCityPop
# Out:
#       year          city  סמל היישוב  \
# 0     2020       אבו גוש         472
# 1     2020      אבו סנאן         473
# 2     2020     אבן יהודה         182
# 3     2020    אום אל-פחם        2710
# 4     2020        אופקים          31
# ...    ...           ...         ...
# 3592  2003           שעב         538
# 3593  2003         שפרעם        8800
# 3594  2003  תל אביב -יפו        5000
# 3595  2003       תל מונד         154
# 3596  2003        תל שבע        1054
#
#      צפיפות אוכלוסייה לקמ''ר ביישובים שמנו 5,000 תושבים ויותר  population  \
# 0                                                4114.4            7771.0
# 1                                                2136.9           14306.0
# 2                                                1696.2           14020.0
# 3                                                2187.4           56777.0
# 4                                                1990.8           32555.0
# ...                                                 ...               ...
# 3592                                                2.9            2800.0
# 3593                                               15.7           15500.0
# 3594                                              173.8          189600.0
# 3595                                                  4            3900.0
# 3596                                                5.9            6000.0
#
#      יהודים ואחרים (אחוזים) יהודים (אחוזים מתוך יהודים ואחרים) ערבים (אחוזים)  \
# 0                         -                                  -           98.9
# 1                         -                                  -           99.8
# 2                       100                               98.4              -
# 3                         -                                  -           99.9
# 4                      99.3                               93.4              -
# ...                     ...                                ...            ...
# 3592                  14.04                              13.56          13.17
# 3593                   13.2                               12.5           10.9
# 3594                      7                                5.5            4.8
# 3595                  11.43                              10.62           9.73
# 3596                  24.35                              17.33          14.33
#
#      מוסלמים (אחוזים מתוך האוכלוסייה הערבית)  \
# 0                                       99.8
# 1                                       54.6
# 2                                          -
# 3                                        100
# 4                                          -
# ...                                      ...
# 3592                                    9.43
# 3593                                    8.33
# 3594                                     5.2
# 3595                                    7.77
# 3596                                   10.57
#
#      נוצרים (אחוזים מתוך האוכלוסייה הערבית)  ...  \
# 0                                         -  ...
# 1                                      15.2  ...
# 2                                         -  ...
# 3                                         -  ...
# 4                                         -  ...
# ...                                     ...  ...
# 3592                                  17.07  ...
# 3593                                  16.22  ...
# 3594                                   18.5  ...
# 3595                                  12.77  ...
# 3596                                  16.44  ...
#
#      נישאים שיעור ל-1,000 תושבים לא נשואים בני 15 ומעלה 2019  \
# 0                                                  44.6
# 1                                                  42.2
# 2                                                    20
# 3                                                  53.7
# 4                                                  44.5
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       מתגרשים סה"כ גברים ונשים 2019  \
# 0                                26
# 1                                29
# 2                                40
# 3                               104
# 4                               119
# ...                             ...
# 3592                            NaN
# 3593                            NaN
# 3594                            NaN
# 3595                            NaN
# 3596                            NaN
#
#       מתגרשים שיעור ל-1,000 תושבים נשואים בני 15 ומעלה 2019  \
# 0                                                   8.1
# 1                                                   4.7
# 2                                                     7
# 3                                                   4.5
# 4                                                  10.7
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) סך מוסדות דיור משותף ברשות  \
# 0                                                     4
# 1                                                     -
# 2                                                     5
# 3                                                    ..
# 4                                                     6
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) סך דיירי דיור משותף ברשות  \
# 0                                                    31
# 1                                                     -
# 2                                                   347
# 3                                                    ..
# 4                                                   559
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים בבתי אבות ובדיור מוגן  \
# 0                                                     -
# 1                                                     -
# 2                                                  1.35
# 3                                                    ..
# 4                                                  0.87
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות חינוך  \
# 0                                                   0.3
# 1                                                     -
# 2                                                   0.3
# 3                                                    ..
# 4                                                  0.58
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות דת  \
# 0                                                  0.04
# 1                                                     -
# 2                                                     -
# 3                                                    ..
# 4                                                  0.17
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות אשפוז כולל הוסטלים  \
# 0                                                  0.06
# 1                                                     -
# 2                                                  0.83
# 3                                                    ..
# 4                                                     -
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
#       אוכלוסיית דיור משותף (אחוז מתוך אוכלוסיית הרשות) אחוז דיירים במוסדות אחרים
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                    ..
# 4                                                  0.09
# ...                                                 ...
# 3592                                                NaN
# 3593                                                NaN
# 3594                                                NaN
# 3595                                                NaN
# 3596                                                NaN
#
# [3597 rows x 68 columns]

# %%
dfYearsCityPop = pd.read_csv(dataPath + 'dfYearsCityPop.csv')

Sum_filterdfDemograph =dfYearsCityPop.iloc[:, [16,17,18]]
Sum_filterdfDemograph['precent count Age 15-44 '] = Sum_filterdfDemograph.sum(axis=1, numeric_only= True)
Sum_filterdfDemograph.insert(loc=0, column='year', value=dfYearsCityPop['year'].values)
Sum_filterdfDemograph.insert(loc=1, column='city', value=dfYearsCityPop['city'].values)
Sum_filterdfDemograph.insert(loc=2, column='population', value=dfYearsCityPop['population'].values)

Sum_filterdfDemograph = Sum_filterdfDemograph.drop(columns=['Percentage of population at the end of the year aged 19-15'])
Sum_filterdfDemograph = Sum_filterdfDemograph.drop(columns=['Percentage of population at the end of the year aged 20-29'])
Sum_filterdfDemograph = Sum_filterdfDemograph.drop(columns=['Percentage of population at the end of the year aged 30-44'])
Sum_filterdfDemograph.columns = Sum_filterdfDemograph.columns.str.replace('precent count Age 15-44', 'percent_count_Age')
Sum_filterdfDemograph["percent_count_Age"]=Sum_filterdfDemograph.iloc[:,[3]].apply(pd.to_numeric)
Sum_filterdfDemograph=Sum_filterdfDemograph.iloc[:, [0,1,2,4]]
#final_DataFrame["percent_count_Age"]
Sum_filterdfDemograph
# Out:
# <ipython-input-246-4ebd23b8249d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Sum_filterdfDemograph['precent count Age 15-44 '] = Sum_filterdfDemograph.sum(axis=1, numeric_only= True)
#       year          city  population  percent_count_Age
# 0     2020       אבו גוש      7771.0              45.97
# 1     2020      אבו סנאן     14306.0              48.03
# 2     2020     אבן יהודה     14020.0              35.39
# 3     2020    אום אל-פחם     56777.0              47.55
# 4     2020        אופקים     32555.0              41.65
# ...    ...           ...         ...                ...
# 3592  2003           שעב      2800.0             342.00
# 3593  2003         שפרעם     15500.0            1692.00
# 3594  2003  תל אביב -יפו    189600.0           12676.00
# 3595  2003       תל מונד      3900.0             298.00
# 3596  2003        תל שבע      6000.0            1290.00
#
# [3597 rows x 4 columns]

# %%
      
final_DataFrame = pd.merge(Sum_filterdfDemograph,df_eduoEmplo, how='inner', left_on=['year','city'], right_on = ['year','city'])

final_DataFrame.to_csv(dataPath + 'finalDataFrame.csv', mode='w+', encoding='utf-8-sig',index=False)  
final_DataFrame
# Out:
#      year          city  population  percent_count_Age number_of_high_schools  \
# 0    2019       אבו גוש      7698.0              46.76                      3
# 1    2019      אבו סנאן     14099.0              48.24                      3
# 2    2019     אבן יהודה     13826.0              35.91                      3
# 3    2019    אום אל-פחם     56109.0              47.45                     13
# 4    2019        אופקים     30662.0              41.68                     11
# ..    ...           ...         ...                ...                    ...
# 799  2016           שעב      6700.0              39.50                     ..
# 800  2016         שפרעם     40500.0              36.90                      9
# 801  2016  תל אביב -יפו    438800.0              23.20                     64
# 802  2016       תל מונד     12200.0              33.10                     ..
# 803  2016        תל שבע     19200.0              44.10                      5
#
#     number_of_bachelor_graduates_in_percent  \
# 0                                     13.03
# 1                                     12.09
# 2                                     55.59
# 3                                      8.52
# 4                                     12.26
# ..                                      ...
# 799                                   52.30
# 800                                   41.20
# 801                                   65.40
# 802                                   84.30
# 803                                   25.90
#
#     number_of_high_school_graduates_in_percent number_of_high_school_students  \
# 0                                        59.29                            361
# 1                                        65.81                            592
# 2                                        83.96                           1087
# 3                                        59.40                           3838
# 4                                        50.24                           1551
# ..                                         ...                            ...
# 799                                       25.0                            329
# 800                                      25.11                           2385
# 801                                      22.87                          13037
# 802                                       33.0                           1026
# 803                                       26.0                           1120
#
#     number_of_high_school_graduates_with_potential_in_percent  \
# 0                                                37.17
# 1                                                52.56
# 2                                                76.89
# 3                                                44.16
# 4                                                39.81
# ..                                                 ...
# 799                                                 64
# 800                                              47.70
# 801                                                 74
# 802                                              89.40
# 803                                              37.90
#
#     Registration_for_higher_education_within_8_years_in_percent  \
# 0                                                   ..
# 1                                                28.50
# 2                                                46.10
# 3                                                23.30
# 4                                                26.60
# ..                                                 ...
# 799                                                8.5
# 800                                                9.7
# 801                                               41.1
# 802                                               51.3
# 803                                                6.3
#
#      number_of_students_in_percent  number_of_self_employees  \
# 0                             3.74                     151.0
# 1                             2.32                     626.0
# 2                             3.03                     899.0
# 3                             2.11                    1918.0
# 4                             1.84                     295.0
# ..                             ...                       ...
# 799                          14.40                       NaN
# 800                          11.90                    1161.0
# 801                          20.80                   24447.0
# 802                          13.60                     660.0
# 803                           7.50                     149.0
#
#      number_of_employees  employees_average_monthly_wage  \
# 0                 3393.0                         7294.03
# 1                 5841.0                         7071.17
# 2                 6265.0                        14054.00
# 3                22149.0                         5869.82
# 4                 3342.0                         9398.05
# ..                   ...                             ...
# 799                  NaN                             NaN
# 800              16307.0                         6236.00
# 801             223935.0                        11017.00
# 802               5819.0                        13983.03
# 803               4543.0                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 799                                               NaN
# 800                                              2.00
# 801                                              2.50
# 802                                             -0.02
# 803                                             -1.46
#
#      self_employees_average_monthly_wage
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 799                                  NaN
# 800                              8996.00
# 801                             11908.00
# 802                             13735.86
# 803                             11631.40
#
# [804 rows x 16 columns]

# %% [markdown]
# # Cleaning data

# %%
final_DataFrame = pd.read_csv(dataPath + 'finalDataFrame.csv')
final_DataFrame
# Out:
#      year          city  population  percent_count_Age number_of_high_schools  \
# 0    2019       אבו גוש      7698.0              46.76                      3
# 1    2019      אבו סנאן     14099.0              48.24                      3
# 2    2019     אבן יהודה     13826.0              35.91                      3
# 3    2019    אום אל-פחם     56109.0              47.45                     13
# 4    2019        אופקים     30662.0              41.68                     11
# ..    ...           ...         ...                ...                    ...
# 799  2016           שעב      6700.0              39.50                     ..
# 800  2016         שפרעם     40500.0              36.90                      9
# 801  2016  תל אביב -יפו    438800.0              23.20                     64
# 802  2016       תל מונד     12200.0              33.10                     ..
# 803  2016        תל שבע     19200.0              44.10                      5
#
#     number_of_bachelor_graduates_in_percent  \
# 0                                     13.03
# 1                                     12.09
# 2                                     55.59
# 3                                      8.52
# 4                                     12.26
# ..                                      ...
# 799                                   52.30
# 800                                   41.20
# 801                                   65.40
# 802                                   84.30
# 803                                   25.90
#
#     number_of_high_school_graduates_in_percent number_of_high_school_students  \
# 0                                        59.29                            361
# 1                                        65.81                            592
# 2                                        83.96                           1087
# 3                                        59.40                           3838
# 4                                        50.24                           1551
# ..                                         ...                            ...
# 799                                       25.0                            329
# 800                                      25.11                           2385
# 801                                      22.87                          13037
# 802                                       33.0                           1026
# 803                                       26.0                           1120
#
#     number_of_high_school_graduates_with_potential_in_percent  \
# 0                                                37.17
# 1                                                52.56
# 2                                                76.89
# 3                                                44.16
# 4                                                39.81
# ..                                                 ...
# 799                                                 64
# 800                                              47.70
# 801                                                 74
# 802                                              89.40
# 803                                              37.90
#
#     Registration_for_higher_education_within_8_years_in_percent  \
# 0                                                   ..
# 1                                                28.50
# 2                                                46.10
# 3                                                23.30
# 4                                                26.60
# ..                                                 ...
# 799                                                8.5
# 800                                                9.7
# 801                                               41.1
# 802                                               51.3
# 803                                                6.3
#
#      number_of_students_in_percent  number_of_self_employees  \
# 0                             3.74                     151.0
# 1                             2.32                     626.0
# 2                             3.03                     899.0
# 3                             2.11                    1918.0
# 4                             1.84                     295.0
# ..                             ...                       ...
# 799                          14.40                       NaN
# 800                          11.90                    1161.0
# 801                          20.80                   24447.0
# 802                          13.60                     660.0
# 803                           7.50                     149.0
#
#      number_of_employees  employees_average_monthly_wage  \
# 0                 3393.0                         7294.03
# 1                 5841.0                         7071.17
# 2                 6265.0                        14054.00
# 3                22149.0                         5869.82
# 4                 3342.0                         9398.05
# ..                   ...                             ...
# 799                  NaN                             NaN
# 800              16307.0                         6236.00
# 801             223935.0                        11017.00
# 802               5819.0                        13983.03
# 803               4543.0                         4983.94
#
#      employees_average_monthly_wage_change_in_percent  \
# 0                                                1.35
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# ..                                                ...
# 799                                               NaN
# 800                                              2.00
# 801                                              2.50
# 802                                             -0.02
# 803                                             -1.46
#
#      self_employees_average_monthly_wage
# 0                               10064.79
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# ..                                   ...
# 799                                  NaN
# 800                              8996.00
# 801                             11908.00
# 802                             13735.86
# 803                             11631.40
#
# [804 rows x 16 columns]

# %%
final_DataFrame.isna().sum()
# Out:
# year                                                           0
# city                                                           0
# population                                                     0
# percent_count_Age                                              0
# number_of_high_schools                                         0
# number_of_bachelor_graduates_in_percent                        0
# number_of_high_school_graduates_in_percent                     0
# number_of_high_school_students                                 0
# number_of_high_school_graduates_with_potential_in_percent      0
# Registration_for_higher_education_within_8_years_in_percent    0
# number_of_students_in_percent                                  0
# number_of_self_employees                                       4
# number_of_employees                                            4
# employees_average_monthly_wage                                 4
# employees_average_monthly_wage_change_in_percent               4
# self_employees_average_monthly_wage                            4
# dtype: int64

# %%
missingData=[len(final_DataFrame[final_DataFrame[x]==".."]) for x in final_DataFrame.columns]
missingData
# Out:
# [0, 0, 0, 0, 187, 14, 0, 0, 14, 45, 0, 0, 0, 0, 0, 0]

# %%
missingData=[len(final_DataFrame[final_DataFrame[x]=="-"]) for x in final_DataFrame.columns]
missingData
# Out:
# [0, 0, 0, 0, 48, 0, 30, 49, 5, 0, 0, 0, 0, 0, 0, 0]

# %%
final_DataFrame = final_DataFrame.replace( '..', np.nan )
final_DataFrame = final_DataFrame.replace( 'NaN', np.nan )
final_DataFrame = final_DataFrame.replace( '-', np.nan )

# %%
final_DataFrame.isna().sum()
# Out:
# year                                                             0
# city                                                             0
# population                                                       0
# percent_count_Age                                                0
# number_of_high_schools                                         235
# number_of_bachelor_graduates_in_percent                         14
# number_of_high_school_graduates_in_percent                      30
# number_of_high_school_students                                  49
# number_of_high_school_graduates_with_potential_in_percent       19
# Registration_for_higher_education_within_8_years_in_percent     45
# number_of_students_in_percent                                    0
# number_of_self_employees                                         4
# number_of_employees                                              4
# employees_average_monthly_wage                                   4
# employees_average_monthly_wage_change_in_percent                 4
# self_employees_average_monthly_wage                              4
# dtype: int64

# %% [markdown]
# # Filling average value instead of null cells

# %%
def FillingAveValue(final_DataFrame):

    df_test = pd.read_csv(dataPath + 'finalDataFrame.csv')
    fixed_data = pd.DataFrame()

    year_col = final_DataFrame['year']
    city_col = final_DataFrame['city']
    df_test = df_test.drop(columns=['city', 'year'])
    df_test = df_test.replace( '..', np.nan )
    df_test = df_test.replace( 'NaN', np.nan )
    df_test = df_test.replace( '-', np.nan )
    df_test = df_test.astype(float)
    df_test.insert(loc=0, column='city', value=city_col)
    df_test.insert(loc=0, column='year', value=year_col)

    df_null_val=df_test[df_test.isna().any(axis=1)] 
    df_null_val
    for cityName in df_null_val['city']:
        df_city = df_test[df_test['city'].str.contains(cityName)]
        df_test = df_test[df_test['city'].str.contains(cityName) == False]
        for column in df_city:
            if column != 'city' and df_city[column].isnull().any():
                mean_value = df_city[column].mean()
                df_city[column].fillna(value=mean_value, inplace=True)
        fixed_data = fixed_data.append(df_city)

    df_test = df_test.append(fixed_data)
    df_test.fillna(value=0, inplace=True)
    return df_test

# %%
final_DataFrame=FillingAveValue(final_DataFrame)
final_DataFrame
# Out:
# C:\Users\shake\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\Users\shake\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\Users\shake\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\Users\shake\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# C:\Users\shake\anaconda3\lib\site-packages\pandas\core\strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
#      year        city  population  percent_count_Age  number_of_high_schools  \
# 1    2019    אבו סנאן     14099.0              48.24                     3.0
# 2    2019   אבן יהודה     13826.0              35.91                     3.0
# 3    2019  אום אל-פחם     56109.0              47.45                    13.0
# 4    2019      אופקים     30662.0              41.68                    11.0
# 5    2019   אור יהודה     36813.0              41.38                     7.0
# ..    ...         ...         ...                ...                     ...
# 747  2016    עין מאהל     12600.0              40.60                     3.0
# 192  2019    שגב-שלום     10936.0              45.00                     3.0
# 393  2018    שגב-שלום     10362.0              44.77                     3.0
# 594  2017    שגב-שלום      9900.0              44.05                     3.0
# 795  2016    שגב-שלום      9500.0              44.00                     3.0
#
#      number_of_bachelor_graduates_in_percent  \
# 1                                      12.09
# 2                                      55.59
# 3                                       8.52
# 4                                      12.26
# 5                                      13.76
# ..                                       ...
# 747                                    37.40
# 192                                     7.60
# 393                                    29.03
# 594                                    40.30
# 795                                    27.00
#
#      number_of_high_school_graduates_in_percent  \
# 1                                         65.81
# 2                                         83.96
# 3                                         59.40
# 4                                         50.24
# 5                                         72.31
# ..                                          ...
# 747                                       27.00
# 192                                       36.41
# 393                                       29.50
# 594                                       28.00
# 795                                       28.00
#
#      number_of_high_school_students  \
# 1                             592.0
# 2                            1087.0
# 3                            3838.0
# 4                            1551.0
# 5                            1244.0
# ..                              ...
# 747                           829.0
# 192                          1383.0
# 393                          1357.0
# 594                          1268.0
# 795                          1145.0
#
#      number_of_high_school_graduates_with_potential_in_percent  \
# 1                                                52.56
# 2                                                76.89
# 3                                                44.16
# 4                                                39.81
# 5                                                57.85
# ..                                                 ...
# 747                                              50.60
# 192                                              30.98
# 393                                              42.47
# 594                                              57.10
# 795                                              43.40
#
#      Registration_for_higher_education_within_8_years_in_percent  \
# 1                                                 28.5
# 2                                                 46.1
# 3                                                 23.3
# 4                                                 26.6
# 5                                                 40.5
# ..                                                 ...
# 747                                                7.7
# 192                                               12.2
# 393                                                6.0
# 594                                                6.2
# 795                                                6.2
#
#      number_of_students_in_percent  number_of_self_employees  \
# 1                             2.32                     626.0
# 2                             3.03                     899.0
# 3                             2.11                    1918.0
# 4                             1.84                     295.0
# 5                             2.31                    1920.0
# ..                             ...                       ...
# 747                          10.30                     277.0
# 192                           1.30                     102.0
# 393                           5.60                      90.0
# 594                           4.90                      81.0
# 795                           4.90                      71.0
#
#      number_of_employees  employees_average_monthly_wage  \
# 1                 5841.0                         7071.17
# 2                 6265.0                        14054.00
# 3                22149.0                         5869.82
# 4                 3342.0                         9398.05
# 5                18941.0                         8953.88
# ..                   ...                             ...
# 747               4845.0                         5132.41
# 192               3209.0                         5532.97
# 393               3084.0                         5716.08
# 594               2835.0                         5412.12
# 795               2637.0                         5090.99
#
#      employees_average_monthly_wage_change_in_percent  \
# 1                                                1.95
# 2                                                1.58
# 3                                                1.16
# 4                                                0.38
# 5                                                4.59
# ..                                                ...
# 747                                              4.45
# 192                                             -0.87
# 393                                              4.78
# 594                                              6.10
# 795                                              4.25
#
#      self_employees_average_monthly_wage
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# 5                               10284.18
# ..                                   ...
# 747                              7448.14
# 192                              9615.59
# 393                              8802.54
# 594                              7788.10
# 795                              6857.88
#
# [804 rows x 16 columns]

# %%
final_DataFrame.isna().sum()
# Out:
# year                                                           0
# city                                                           0
# population                                                     0
# percent_count_Age                                              0
# number_of_high_schools                                         0
# number_of_bachelor_graduates_in_percent                        0
# number_of_high_school_graduates_in_percent                     0
# number_of_high_school_students                                 0
# number_of_high_school_graduates_with_potential_in_percent      0
# Registration_for_higher_education_within_8_years_in_percent    0
# number_of_students_in_percent                                  0
# number_of_self_employees                                       0
# number_of_employees                                            0
# employees_average_monthly_wage                                 0
# employees_average_monthly_wage_change_in_percent               0
# self_employees_average_monthly_wage                            0
# dtype: int64

# %% [markdown]
# # Visualiation

# %%
visul_df = final_DataFrame
visul_df = visul_df.drop(columns=['year'])
visul_df.describe()
# Out:
#          population  percent_count_Age  number_of_high_schools  \
# count     804.00000          804.00000               804.00000
# mean    39324.47015           37.89410                 8.56343
# std     83457.18861            7.00739                26.61533
# min      1200.00000           19.37000                 0.00000
# 25%      7522.50000           33.13750                 1.00000
# 50%     17001.00000           38.51000                 3.00000
# 75%     38164.50000           42.35750                 7.00000
# max    936425.00000           52.96000               353.00000
#
#        number_of_bachelor_graduates_in_percent  \
# count                                804.00000
# mean                                  48.29835
# std                                   22.82114
# min                                    0.70000
# 25%                                   32.40000
# 50%                                   51.63000
# 75%                                   63.70500
# max                                   94.40000
#
#        number_of_high_school_graduates_in_percent  \
# count                                   804.00000
# mean                                     34.28704
# std                                      22.99077
# min                                       0.00000
# 25%                                      23.00000
# 50%                                      26.58500
# 75%                                      33.30250
# max                                      96.83000
#
#        number_of_high_school_students  \
# count                       804.00000
# mean                       1880.45813
# std                        4554.25079
# min                           0.00000
# 25%                         358.75000
# 50%                         839.00000
# 75%                        1692.00000
# max                       58932.00000
#
#        number_of_high_school_graduates_with_potential_in_percent  \
# count                                          804.00000
# mean                                            66.31307
# std                                             17.60464
# min                                              1.30000
# 25%                                             56.96750
# 50%                                             68.85000
# 75%                                             78.53250
# max                                             98.30000
#
#        Registration_for_higher_education_within_8_years_in_percent  \
# count                                          804.00000
# mean                                            24.72349
# std                                             16.34752
# min                                              0.00000
# 25%                                             11.30000
# 50%                                             19.40000
# 75%                                             37.00000
# max                                             69.10000
#
#        number_of_students_in_percent  number_of_self_employees  \
# count                      804.00000                 804.00000
# mean                        11.02205                1414.61940
# std                          6.92087                3057.80981
# min                          0.43000                   0.00000
# 25%                          4.67000                 240.75000
# 50%                         11.15000                 581.50000
# 75%                         15.02500                1183.25000
# max                         52.90000               32674.00000
#
#        number_of_employees  employees_average_monthly_wage  \
# count            804.00000                       804.00000
# mean           17433.02985                      8668.78439
# std            33971.48961                      2948.23090
# min                0.00000                         0.00000
# 25%             3392.50000                      6435.05750
# 50%             6281.00000                      7769.27000
# 75%            16654.50000                     10498.45250
# max           331224.00000                     17941.35000
#
#        employees_average_monthly_wage_change_in_percent  \
# count                                         804.00000
# mean                                            2.95979
# std                                             2.65303
# min                                            -9.03000
# 25%                                             1.22750
# 50%                                             2.65000
# 75%                                             4.49000
# max                                            15.65000
#
#        self_employees_average_monthly_wage
# count                            804.00000
# mean                            9807.25204
# std                             2409.86464
# min                                0.00000
# 25%                             8220.00500
# 50%                             9394.29000
# 75%                            11185.99250
# max                            21871.11000

# %%
final_DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804 entries, 1 to 795
# Data columns (total 16 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   year                                                         804 non-null    int64
#  1   city                                                         804 non-null    object
#  2   population                                                   804 non-null    float64
#  3   percent_count_Age                                            804 non-null    float64
#  4   number_of_high_schools                                       804 non-null    float64
#  5   number_of_bachelor_graduates_in_percent                      804 non-null    float64
#  6   number_of_high_school_graduates_in_percent                   804 non-null    float64
#  7   number_of_high_school_students                               804 non-null    float64
#  8   number_of_high_school_graduates_with_potential_in_percent    804 non-null    float64
#  9   Registration_for_higher_education_within_8_years_in_percent  804 non-null    float64
#  10  number_of_students_in_percent                                804 non-null    float64
#  11  number_of_self_employees                                     804 non-null    float64
#  12  number_of_employees                                          804 non-null    float64
#  13  employees_average_monthly_wage                               804 non-null    float64
#  14  employees_average_monthly_wage_change_in_percent             804 non-null    float64
#  15  self_employees_average_monthly_wage                          804 non-null    float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 106.8+ KB

# %%
final_DataFrame['city']= final_DataFrame['city'].astype('string')
final_DataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 804 entries, 1 to 795
# Data columns (total 16 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   year                                                         804 non-null    int64
#  1   city                                                         804 non-null    string
#  2   population                                                   804 non-null    float64
#  3   percent_count_Age                                            804 non-null    float64
#  4   number_of_high_schools                                       804 non-null    float64
#  5   number_of_bachelor_graduates_in_percent                      804 non-null    float64
#  6   number_of_high_school_graduates_in_percent                   804 non-null    float64
#  7   number_of_high_school_students                               804 non-null    float64
#  8   number_of_high_school_graduates_with_potential_in_percent    804 non-null    float64
#  9   Registration_for_higher_education_within_8_years_in_percent  804 non-null    float64
#  10  number_of_students_in_percent                                804 non-null    float64
#  11  number_of_self_employees                                     804 non-null    float64
#  12  number_of_employees                                          804 non-null    float64
#  13  employees_average_monthly_wage                               804 non-null    float64
#  14  employees_average_monthly_wage_change_in_percent             804 non-null    float64
#  15  self_employees_average_monthly_wage                          804 non-null    float64
# dtypes: float64(14), int64(1), string(1)
# memory usage: 106.8 KB

# %%
#changing all precent value
dataInPercent = final_DataFrame.filter(regex='percent|Percentage|precent').columns
for i in dataInPercent:
    print(final_DataFrame[i])
    final_DataFrame[i] = ((final_DataFrame.loc[:,'population'])*(final_DataFrame[i]/100))
    print(final_DataFrame[i])

final_DataFrame.rename(columns = {'percent_count_Age':'count_Age', 
                                  'number_of_bachelor_graduates_in_percent':'number_of_bachelor_graduates',
                                  'number_of_high_school_graduates_in_percent':'number_of_high_school_graduates',
                                  'Registration_for_higher_education_within_8_years_in_percent':'Registration_for_higher_education_within_8_years',
                                  'number_of_students_in_percent':'number_of_students',
                                  'employees_average_monthly_wage_change_in_percent':'employees_average_monthly_wage_change',
                                  'number_of_high_school_graduates_with_potential_in_percent':'number_of_high_school_graduates_with_potential'
                                 }, inplace = True)  
    
final_DataFrame
# Out:
# 1      48.24
# 2      35.91
# 3      47.45
# 4      41.68
# 5      41.38
#        ...
# 747    40.60
# 192    45.00
# 393    44.77
# 594    44.05
# 795    44.00
# Name: percent_count_Age, Length: 804, dtype: float64
# 1       6801.3576
# 2       4964.9166
# 3      26623.7205
# 4      12779.9216
# 5      15233.2194
#           ...
# 747     5115.6000
# 192     4921.2000
# 393     4639.0674
# 594     4360.9500
# 795     4180.0000
# Name: percent_count_Age, Length: 804, dtype: float64
# 1      12.09
# 2      55.59
# 3       8.52
# 4      12.26
# 5      13.76
#        ...
# 747    37.40
# 192     7.60
# 393    29.03
# 594    40.30
# 795    27.00
# Name: number_of_bachelor_graduates_in_percent, Length: 804, dtype: float64
# 1      1704.5691
# 2      7685.8734
# 3      4780.4868
# 4      3759.1612
# 5      5065.4688
#          ...
# 747    4712.4000
# 192     831.1360
# 393    3008.0886
# 594    3989.7000
# 795    2565.0000
# Name: number_of_bachelor_graduates_in_percent, Length: 804, dtype: float64
# 1      65.81
# 2      83.96
# 3      59.40
# 4      50.24
# 5      72.31
#        ...
# 747    27.00
# 192    36.41
# 393    29.50
# 594    28.00
# 795    28.00
# Name: number_of_high_school_graduates_in_percent, Length: 804, dtype: float64
# 1       9278.5519
# 2      11608.3096
# 3      33328.7460
# 4      15404.5888
# 5      26619.4803
#           ...
# 747     3402.0000
# 192     3981.7976
# 393     3056.7900
# 594     2772.0000
# 795     2660.0000
# Name: number_of_high_school_graduates_in_percent, Length: 804, dtype: float64
# 1      52.56
# 2      76.89
# 3      44.16
# 4      39.81
# 5      57.85
#        ...
# 747    50.60
# 192    30.98
# 393    42.47
# 594    57.10
# 795    43.40
# Name: number_of_high_school_graduates_with_potential_in_percent, Length: 804, dtype: float64
# 1       7410.4344
# 2      10630.8114
# 3      24777.7344
# 4      12206.5422
# 5      21296.3205
#           ...
# 747     6375.6000
# 192     3387.9728
# 393     4400.7414
# 594     5652.9000
# 795     4123.0000
# Name: number_of_high_school_graduates_with_potential_in_percent, Length: 804, dtype: float64
# 1      28.5
# 2      46.1
# 3      23.3
# 4      26.6
# 5      40.5
#        ...
# 747     7.7
# 192    12.2
# 393     6.0
# 594     6.2
# 795     6.2
# Name: Registration_for_higher_education_within_8_years_in_percent, Length: 804, dtype: float64
# 1       4018.215
# 2       6373.786
# 3      13073.397
# 4       8156.092
# 5      14909.265
#          ...
# 747      970.200
# 192     1334.192
# 393      621.720
# 594      613.800
# 795      589.000
# Name: Registration_for_higher_education_within_8_years_in_percent, Length: 804, dtype: float64
# 1       2.32
# 2       3.03
# 3       2.11
# 4       1.84
# 5       2.31
#        ...
# 747    10.30
# 192     1.30
# 393     5.60
# 594     4.90
# 795     4.90
# Name: number_of_students_in_percent, Length: 804, dtype: float64
# 1       327.0968
# 2       418.9278
# 3      1183.8999
# 4       564.1808
# 5       850.3803
#          ...
# 747    1297.8000
# 192     142.1680
# 393     580.2720
# 594     485.1000
# 795     465.5000
# Name: number_of_students_in_percent, Length: 804, dtype: float64
# 1      1.95
# 2      1.58
# 3      1.16
# 4      0.38
# 5      4.59
#        ...
# 747    4.45
# 192   -0.87
# 393    4.78
# 594    6.10
# 795    4.25
# Name: employees_average_monthly_wage_change_in_percent, Length: 804, dtype: float64
# 1       274.9305
# 2       218.4508
# 3       650.8644
# 4       116.5156
# 5      1689.7167
#          ...
# 747     560.7000
# 192     -95.1432
# 393     495.3036
# 594     603.9000
# 795     403.7500
# Name: employees_average_monthly_wage_change_in_percent, Length: 804, dtype: float64
#      year        city  population   count_Age  number_of_high_schools  \
# 1    2019    אבו סנאן     14099.0   6801.3576                     3.0
# 2    2019   אבן יהודה     13826.0   4964.9166                     3.0
# 3    2019  אום אל-פחם     56109.0  26623.7205                    13.0
# 4    2019      אופקים     30662.0  12779.9216                    11.0
# 5    2019   אור יהודה     36813.0  15233.2194                     7.0
# ..    ...         ...         ...         ...                     ...
# 747  2016    עין מאהל     12600.0   5115.6000                     3.0
# 192  2019    שגב-שלום     10936.0   4921.2000                     3.0
# 393  2018    שגב-שלום     10362.0   4639.0674                     3.0
# 594  2017    שגב-שלום      9900.0   4360.9500                     3.0
# 795  2016    שגב-שלום      9500.0   4180.0000                     3.0
#
#      number_of_bachelor_graduates  number_of_high_school_graduates  \
# 1                       1704.5691                        9278.5519
# 2                       7685.8734                       11608.3096
# 3                       4780.4868                       33328.7460
# 4                       3759.1612                       15404.5888
# 5                       5065.4688                       26619.4803
# ..                            ...                              ...
# 747                     4712.4000                        3402.0000
# 192                      831.1360                        3981.7976
# 393                     3008.0886                        3056.7900
# 594                     3989.7000                        2772.0000
# 795                     2565.0000                        2660.0000
#
#      number_of_high_school_students  \
# 1                             592.0
# 2                            1087.0
# 3                            3838.0
# 4                            1551.0
# 5                            1244.0
# ..                              ...
# 747                           829.0
# 192                          1383.0
# 393                          1357.0
# 594                          1268.0
# 795                          1145.0
#
#      number_of_high_school_graduates_with_potential  \
# 1                                         7410.4344
# 2                                        10630.8114
# 3                                        24777.7344
# 4                                        12206.5422
# 5                                        21296.3205
# ..                                              ...
# 747                                       6375.6000
# 192                                       3387.9728
# 393                                       4400.7414
# 594                                       5652.9000
# 795                                       4123.0000
#
#      Registration_for_higher_education_within_8_years  number_of_students  \
# 1                                            4018.215            327.0968
# 2                                            6373.786            418.9278
# 3                                           13073.397           1183.8999
# 4                                            8156.092            564.1808
# 5                                           14909.265            850.3803
# ..                                                ...                 ...
# 747                                           970.200           1297.8000
# 192                                          1334.192            142.1680
# 393                                           621.720            580.2720
# 594                                           613.800            485.1000
# 795                                           589.000            465.5000
#
#      number_of_self_employees  number_of_employees  \
# 1                       626.0               5841.0
# 2                       899.0               6265.0
# 3                      1918.0              22149.0
# 4                       295.0               3342.0
# 5                      1920.0              18941.0
# ..                        ...                  ...
# 747                     277.0               4845.0
# 192                     102.0               3209.0
# 393                      90.0               3084.0
# 594                      81.0               2835.0
# 795                      71.0               2637.0
#
#      employees_average_monthly_wage  employees_average_monthly_wage_change  \
# 1                           7071.17                               274.9305
# 2                          14054.00                               218.4508
# 3                           5869.82                               650.8644
# 4                           9398.05                               116.5156
# 5                           8953.88                              1689.7167
# ..                              ...                                    ...
# 747                         5132.41                               560.7000
# 192                         5532.97                               -95.1432
# 393                         5716.08                               495.3036
# 594                         5412.12                               603.9000
# 795                         5090.99                               403.7500
#
#      self_employees_average_monthly_wage
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# 5                               10284.18
# ..                                   ...
# 747                              7448.14
# 192                              9615.59
# 393                              8802.54
# 594                              7788.10
# 795                              6857.88
#
# [804 rows x 16 columns]

# %% [markdown]
# # EDA

# %%
city = final_DataFrame[['year', 'city', 'number_of_high_school_graduates']]
city = city[city['city'] == 'תל אביב -יפו']
potential_grad = city
#potential_grad = potential_grad.groupby(['number_of_high_school_graduates'])
potential_grad.plot(x='year', y=['number_of_high_school_graduates'],linewidth=3, color='b')


# labels and title
plt.xlabel('year', fontsize=14)
plt.ylabel('Number of high school graduates', fontsize=14)
plt.title('Potential graduate students', fontsize=20);

city
# Out:
#      year          city  number_of_high_school_graduates
# 198  2019  תל אביב -יפו                      342650.0107
# 399  2018  תל אביב -יפו                      111435.6296
# 600  2017  תל אביב -יפו                       97658.0000
# 801  2016  תל אביב -יפו                      100353.5600

# %%
potential_grad = final_DataFrame[['city', 'number_of_students']]

potential_grad = potential_grad.groupby(['city']).mean()

potential_grad.head(20).plot(kind='barh')
#plt.text(0.5, 0.5, potential_grad , name = 'Arial')
# labels and title
plt.xlabel('city', fontsize=14)
plt.ylabel('Number of graduates', fontsize=14)
plt.title('Graduates students', fontsize=20);

plt.show()

# %%
# final_DataFrame=FillingAveValue(final_DataFrame)
number_of_high_school_graduates_with_potential='number_of_high_school_graduates_with_potential'
number_of_high_school_graduates='number_of_high_school_graduates'
Registration_for_higher_education_within_8_years='Registration_for_higher_education_within_8_years'
number_of_self_employees = 'number_of_self_employees'
number_of_bachelor_graduates = 'number_of_bachelor_graduates'
number_of_students='number_of_students'

# %%
# New dataframe to calculate correlation between numeric features

corr_df = final_DataFrame[[number_of_high_school_graduates_with_potential, 
              number_of_high_school_graduates, 
             Registration_for_higher_education_within_8_years, number_of_self_employees,  number_of_students]]

corr=corr_df.corr(method='pearson')
print(corr)
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
#                                                   number_of_high_school_graduates_with_potential  \
# number_of_high_school_graduates_with_potential                                           1.00000
# number_of_high_school_graduates                                                          0.83027
# Registration_for_higher_education_within_8_years                                         0.93553
# number_of_self_employees                                                                 0.94733
# number_of_students                                                                       0.89733
#
#                                                   number_of_high_school_graduates  \
# number_of_high_school_graduates_with_potential                            0.83027
# number_of_high_school_graduates                                           1.00000
# Registration_for_higher_education_within_8_years                          0.88561
# number_of_self_employees                                                  0.86965
# number_of_students                                                        0.58074
#
#                                                   Registration_for_higher_education_within_8_years  \
# number_of_high_school_graduates_with_potential                                             0.93553
# number_of_high_school_graduates                                                            0.88561
# Registration_for_higher_education_within_8_years                                           1.00000
# number_of_self_employees                                                                   0.95913
# number_of_students                                                                         0.79347
#
#                                                   number_of_self_employees  \
# number_of_high_school_graduates_with_potential                     0.94733
# number_of_high_school_graduates                                    0.86965
# Registration_for_higher_education_within_8_years                   0.95913
# number_of_self_employees                                           1.00000
# number_of_students                                                 0.82920
#
#                                                   number_of_students
# number_of_high_school_graduates_with_potential               0.89733
# number_of_high_school_graduates                              0.58074
# Registration_for_higher_education_within_8_years             0.79347
# number_of_self_employees                                     0.82920
# number_of_students                                           1.00000
# <style  type="text/css" >
# #T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col0,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col1,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col2,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col3,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col4{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col1{
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col2,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col0,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col1{
#             background-color:  #f7b093;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col3{
#             background-color:  #f7af91;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col4{
#             background-color:  #f39778;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col0,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col4,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col1,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col2,#T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col2{
#             background-color:  #cedaeb;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col3{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col0{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col1{
#             background-color:  #f6a283;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col3{
#             background-color:  #f39577;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col4{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col2{
#             background-color:  #ed8366;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col4{
#             background-color:  #f1cdba;
#             color:  #000000;
#         }#T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col0{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }</style><table id="T_fa526ef1_02da_11ed_a720_d0c63700bca1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number_of_high_school_graduates_with_potential</th>        <th class="col_heading level0 col1" >number_of_high_school_graduates</th>        <th class="col_heading level0 col2" >Registration_for_higher_education_within_8_years</th>        <th class="col_heading level0 col3" >number_of_self_employees</th>        <th class="col_heading level0 col4" >number_of_students</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fa526ef1_02da_11ed_a720_d0c63700bca1level0_row0" class="row_heading level0 row0" >number_of_high_school_graduates_with_potential</th>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col1" class="data row0 col1" >0.83</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col2" class="data row0 col2" >0.94</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col3" class="data row0 col3" >0.95</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row0_col4" class="data row0 col4" >0.90</td>
#             </tr>
#             <tr>
#                         <th id="T_fa526ef1_02da_11ed_a720_d0c63700bca1level0_row1" class="row_heading level0 row1" >number_of_high_school_graduates</th>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col0" class="data row1 col0" >0.83</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col2" class="data row1 col2" >0.89</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col3" class="data row1 col3" >0.87</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row1_col4" class="data row1 col4" >0.58</td>
#             </tr>
#             <tr>
#                         <th id="T_fa526ef1_02da_11ed_a720_d0c63700bca1level0_row2" class="row_heading level0 row2" >Registration_for_higher_education_within_8_years</th>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col0" class="data row2 col0" >0.94</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col1" class="data row2 col1" >0.89</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col3" class="data row2 col3" >0.96</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row2_col4" class="data row2 col4" >0.79</td>
#             </tr>
#             <tr>
#                         <th id="T_fa526ef1_02da_11ed_a720_d0c63700bca1level0_row3" class="row_heading level0 row3" >number_of_self_employees</th>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col0" class="data row3 col0" >0.95</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col1" class="data row3 col1" >0.87</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col2" class="data row3 col2" >0.96</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row3_col4" class="data row3 col4" >0.83</td>
#             </tr>
#             <tr>
#                         <th id="T_fa526ef1_02da_11ed_a720_d0c63700bca1level0_row4" class="row_heading level0 row4" >number_of_students</th>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col0" class="data row4 col0" >0.90</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col1" class="data row4 col1" >0.58</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col2" class="data row4 col2" >0.79</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col3" class="data row4 col3" >0.83</td>
#                         <td id="T_fa526ef1_02da_11ed_a720_d0c63700bca1row4_col4" class="data row4 col4" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
def generateGragh(columnsName,color1,color2):
    x = reshapeCol(final_DataFrame,columnsName)
    plt.scatter(x=x,y=y,c=color1,marker='s',label=columnsName)
    m = lr.fit(X=x, y=y)
    plt.plot(x,m.predict(x),color2,linewidth=3)

# %%
def reshapeCol(final_DataFrame,str):
  return final_DataFrame[[str]].values.reshape(final_DataFrame[str].shape[0],1)

# %%
plt.scatter(x=final_DataFrame[number_of_high_school_graduates_with_potential],
            y=final_DataFrame[number_of_students],c='r',marker='s',label='potential to be student')

plt.scatter(x=final_DataFrame[number_of_high_school_graduates],
            y=final_DataFrame[number_of_students],c='b',marker='o',label='high school graduates')

plt.scatter(x=final_DataFrame[Registration_for_higher_education_within_8_years],
            y=final_DataFrame[number_of_students],c='k',marker='*',label='Registration as student')

plt.legend(numpoints=1,loc=4)
plt.xlabel('Potentional to be Students')
plt.ylabel('number_of_students')
plt.show()

# %%
columns_names =['number_of_bachelor_graduates', 
                'number_of_high_school_graduates', 
                'Registration_for_higher_education_within_8_years', 
                'number_of_students']

lr = linear_model.LinearRegression() # create a linear regression object

y = final_DataFrame[[number_of_students]].values.reshape(final_DataFrame[number_of_students].shape[0],1)


generateGragh(number_of_high_school_graduates_with_potential,'r','tomato')

#take all columns for next blocks
x = final_DataFrame[['number_of_bachelor_graduates']]


m = lr.fit(X=x, y=y);

plt.legend(numpoints=1,loc=4)
plt.xlabel('number_of_potentional_student')
plt.ylabel(number_of_students)
plt.show()

# %%
print("Slope: ",m.coef_)
print("intercept: ",m.intercept_)
print("R2: ", m.score(x,y))
# Out:
# Slope:  [[0.27065722]]
# intercept:  [-736.19582507]
# R2:  0.9147407694475965

# %%
def sse(Y, Y_HAT):  
    sse = sum([(y - y_hat)**2 for y,y_hat in zip(Y, Y_HAT)])
    return sse

# print(final_DataFrame.iloc[:,0:1])
SSE = sse(final_DataFrame.number_of_bachelor_graduates.tolist(),m.predict(final_DataFrame.iloc[:,0:1]).flatten())

print(SSE)
# Out:
# 1337303854310.7095

# %%
#/////////////////////////////////////////test 1////////////////////////////////////////////////////

lr = linear_model.LinearRegression() # create a linear regression object

y = final_DataFrame[[number_of_bachelor_graduates]].values.reshape(final_DataFrame[number_of_bachelor_graduates].shape[0],1)


generateGragh(number_of_high_school_graduates,'yellow','y')
generateGragh(number_of_self_employees,'k','k')

#take all columns for next blocks
x = final_DataFrame[[number_of_high_school_graduates, number_of_self_employees]]


m = lr.fit(X=x, y=y);

plt.legend(numpoints=1,loc=2)
plt.xlabel('Referance columns')
plt.ylabel("Number of graduates students")
plt.show()

# %%
print("R2:",lr.score(x,y))
print("R2:",r2_score(y,lr.predict(x)))
# Out:
# R2: 0.8487467937817528
# R2: 0.8487467937817528

# %%
#print(final_DataFrame.corr())
pd.plotting.scatter_matrix(final_DataFrame, figsize=(20,20), diagonal='kde')
plt.show()

# %%
from sklearn import linear_model
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

number_of_high_school_graduates_with_potential='number_of_high_school_graduates_with_potential'
number_of_high_school_graduates='number_of_high_school_graduates'
Registration_for_higher_education_within_8_years='Registration_for_higher_education_within_8_years'
number_of_self_employees = 'number_of_self_employees'
number_of_bachelor_graduates = 'number_of_bachelor_graduates'


lr = linear_model.LinearRegression() # create a linear regression object
y = final_DataFrame[[number_of_students]].values.reshape(final_DataFrame[number_of_students].shape[0],1)

#print(final_DataFrame)
generateGragh(number_of_self_employees,'r','r')
generateGragh(number_of_high_school_graduates,'green','green')
generateGragh(Registration_for_higher_education_within_8_years,'c','c')
generateGragh(number_of_high_school_graduates_with_potential,'orange','orange')

x = final_DataFrame[['number_of_high_school_graduates_with_potential','number_of_high_school_graduates','Registration_for_higher_education_within_8_years',
                     'number_of_self_employees']]

m = lr.fit(X=x, y=y);

plt.legend(numpoints=1,loc=1)
plt.xlabel('Referance columns')
plt.ylabel('Number of graduates student')
plt.show()

# %%
print("R2:",lr.score(x,y))
print("R2:",r2_score(y,lr.predict(x)))
# Out:
# R2: 0.8987382239168415
# R2: 0.8987382239168415

# %%
#print(final_DataFrame.corr())
pd.plotting.scatter_matrix(final_DataFrame, figsize=(20, 20), diagonal='kde')
plt.show()

# %%
final_DataFrame
# Out:
#      year        city  population   count_Age  number_of_high_schools  \
# 1    2019    אבו סנאן     14099.0   6801.3576                     3.0
# 2    2019   אבן יהודה     13826.0   4964.9166                     3.0
# 3    2019  אום אל-פחם     56109.0  26623.7205                    13.0
# 4    2019      אופקים     30662.0  12779.9216                    11.0
# 5    2019   אור יהודה     36813.0  15233.2194                     7.0
# ..    ...         ...         ...         ...                     ...
# 747  2016    עין מאהל     12600.0   5115.6000                     3.0
# 192  2019    שגב-שלום     10936.0   4921.2000                     3.0
# 393  2018    שגב-שלום     10362.0   4639.0674                     3.0
# 594  2017    שגב-שלום      9900.0   4360.9500                     3.0
# 795  2016    שגב-שלום      9500.0   4180.0000                     3.0
#
#      number_of_bachelor_graduates  number_of_high_school_graduates  \
# 1                       1704.5691                        9278.5519
# 2                       7685.8734                       11608.3096
# 3                       4780.4868                       33328.7460
# 4                       3759.1612                       15404.5888
# 5                       5065.4688                       26619.4803
# ..                            ...                              ...
# 747                     4712.4000                        3402.0000
# 192                      831.1360                        3981.7976
# 393                     3008.0886                        3056.7900
# 594                     3989.7000                        2772.0000
# 795                     2565.0000                        2660.0000
#
#      number_of_high_school_students  \
# 1                             592.0
# 2                            1087.0
# 3                            3838.0
# 4                            1551.0
# 5                            1244.0
# ..                              ...
# 747                           829.0
# 192                          1383.0
# 393                          1357.0
# 594                          1268.0
# 795                          1145.0
#
#      number_of_high_school_graduates_with_potential  \
# 1                                         7410.4344
# 2                                        10630.8114
# 3                                        24777.7344
# 4                                        12206.5422
# 5                                        21296.3205
# ..                                              ...
# 747                                       6375.6000
# 192                                       3387.9728
# 393                                       4400.7414
# 594                                       5652.9000
# 795                                       4123.0000
#
#      Registration_for_higher_education_within_8_years  number_of_students  \
# 1                                            4018.215            327.0968
# 2                                            6373.786            418.9278
# 3                                           13073.397           1183.8999
# 4                                            8156.092            564.1808
# 5                                           14909.265            850.3803
# ..                                                ...                 ...
# 747                                           970.200           1297.8000
# 192                                          1334.192            142.1680
# 393                                           621.720            580.2720
# 594                                           613.800            485.1000
# 795                                           589.000            465.5000
#
#      number_of_self_employees  number_of_employees  \
# 1                       626.0               5841.0
# 2                       899.0               6265.0
# 3                      1918.0              22149.0
# 4                       295.0               3342.0
# 5                      1920.0              18941.0
# ..                        ...                  ...
# 747                     277.0               4845.0
# 192                     102.0               3209.0
# 393                      90.0               3084.0
# 594                      81.0               2835.0
# 795                      71.0               2637.0
#
#      employees_average_monthly_wage  employees_average_monthly_wage_change  \
# 1                           7071.17                               274.9305
# 2                          14054.00                               218.4508
# 3                           5869.82                               650.8644
# 4                           9398.05                               116.5156
# 5                           8953.88                              1689.7167
# ..                              ...                                    ...
# 747                         5132.41                               560.7000
# 192                         5532.97                               -95.1432
# 393                         5716.08                               495.3036
# 594                         5412.12                               603.9000
# 795                         5090.99                               403.7500
#
#      self_employees_average_monthly_wage
# 1                                8456.80
# 2                               12517.09
# 3                                8883.18
# 4                               11301.74
# 5                               10284.18
# ..                                   ...
# 747                              7448.14
# 192                              9615.59
# 393                              8802.54
# 594                              7788.10
# 795                              6857.88
#
# [804 rows x 16 columns]
